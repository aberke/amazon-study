# %% [markdown]
# # Probe behavioral data
#
# Also consider this a data check:
# - is the number of completions consistent across experiment arms?
# - what is the overall share rate?
# - how does the share rate differ by experiment arm?

# %%
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import chisquare
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Downloaded from Qualtrics indicated by date in filename
# This data was filtered to responses that were considered completed (included attention check at the end)
# data_filepath = '../data/amazon-purchases-survey-v0-completed-11-30-2022-raw.csv'
# data_filepath = '../data/amazon-purchases-survey-v0-completed-11-22-2022-raw.csv'
# This datafile downloaded to only include data from Prolific participants who passed the attention check
# data_filepath = '../data/amazon-purchases-survey-v0-completed-12-08-2022-raw.csv'
data_filepath = '../data/amazon-purchases-survey-v0-completed-1-10-2023-raw.csv'

# %%
pd.set_option('max_columns', None)

df = pd.read_csv(data_filepath)
print('shape:', df.shape)
print('all fields:', df.columns)
df.head(2)
# Out:
# shape: (3321, 93)
# all fields: Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q43_Id', 'Q43_Name', 'Q43_Size',
#        'Q43_Type', 'Q-requirements-1', 'Q-requirements-2', 'intro-1',
#        'intro-2', 'Q-prolific', 'Q-prolific-mturk', 'Q-mturk-account',
#        'Q-accnt-attn-check', 'download', 'download-fail-expl',
#        'download-fail-screen_Id', 'download-fail-screen_Name',
#        'download-fail-screen_Size', 'download-fail-screen_Type', 'q-demos-age',
#        'Q-demos-hispanic', 'Q-demos-race', 'Q-demos-education',
#        'Q-demos-income', 'Q-demos-gender', 'Q-sexual-orientation',
#        'Q-demos-state', 'Q-amazon-use-howmany', 'Q-amazon-use-hh-size',
#        'Q-amazon-use-how-oft', 'Q-substance-use_1', 'Q-substance-use_2',
#        'Q-substance-use_3', 'Q-personal_1', 'Q-personal_2', 'Q-life-changes',
#        'Q-data-download', 'Q-share-error-1', 'Q-share-error-2-a',
#        'Q-share-error-2-b', 'Q-share-error-2-c0', 'Q-share-error-2-c',
#        'share-error-3', 'share-error-4_Id', 'share-error-4_Name',
#        'share-error-4_Size', 'share-error-4_Type', 'Q-control', 'Q-altruism',
#        'Q-bonus-05', 'Q-bonus-20', 'Q-bonus-50', 'Q-data-value-05',
#        'Q-data-value-20', 'Q-data-value-50', 'Q-data-value-100',
#        'Q-data-value-any', 'Q-data-value-any_1_TEXT', 'Q-sell-YOUR-data',
#        'Q-sell-consumer-data', 'Q-small-biz-use', 'Q-census-use',
#        'Q-research-society', 'Q-attn-check', 'Q-comments', 'SurveyID',
#        'ResponseID', 'FQID', 'API_TOKEN', 'BATCH', 'RandomID', 'PROLIFIC_PID',
#        'STUDY_ID', 'SESSION_ID', 'showdata', 'incentive', 'consent'],
#       dtype='object')
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# 1  {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}
#
#                   Finished                                       RecordedDate  \
# 0                 Finished                                      Recorded Date
# 1  {"ImportId":"finished"}  {"ImportId":"recordedDate","timeZone":"America...
#
#                  ResponseId                 RecipientLastName  \
# 0               Response ID               Recipient Last Name
# 1  {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}
#
#                   RecipientFirstName                 RecipientEmail  \
# 0               Recipient First Name                Recipient Email
# 1  {"ImportId":"recipientFirstName"}  {"ImportId":"recipientEmail"}
#
#                       ExternalReference                 LocationLatitude  \
# 0               External Data Reference                Location Latitude
# 1  {"ImportId":"externalDataReference"}  {"ImportId":"locationLatitude"}
#
#                   LocationLongitude                 DistributionChannel  \
# 0                Location Longitude                Distribution Channel
# 1  {"ImportId":"locationLongitude"}  {"ImportId":"distributionChannel"}
#
#                   UserLanguage  \
# 0                User Language
# 1  {"ImportId":"userLanguage"}
#
#                                               Q43_Id  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                       {"ImportId":"QID47_FILE_ID"}
#
#                                             Q43_Name  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                     {"ImportId":"QID47_FILE_NAME"}
#
#                                             Q43_Size  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                     {"ImportId":"QID47_FILE_SIZE"}
#
#                                             Q43_Type  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                     {"ImportId":"QID47_FILE_TYPE"}
#
#                         Q-requirements-1  \
# 0  Do you have an active Amazon account?
# 1                   {"ImportId":"QID90"}
#
#                                     Q-requirements-2  \
# 0  Have you used your Amazon account to make purc...
# 1                               {"ImportId":"QID91"}
#
#                                              intro-1  \
# 0  Introduction\n\n \nThis survey is part of a MI...
# 1                               {"ImportId":"QID20"}
#
#                                              intro-2  \
# 0  Survey questions and data collection\n\nWe wil...
# 1                               {"ImportId":"QID25"}
#
#                    Q-prolific  \
# 0   What is your Prolific ID?
# 1  {"ImportId":"QID107_TEXT"}
#
#                                     Q-prolific-mturk  \
# 0  Do you also complete surveys (or HITs) using A...
# 1                              {"ImportId":"QID108"}
#
#                                      Q-mturk-account  \
# 0  Is the Amazon.com account that you use to comp...
# 1                               {"ImportId":"QID96"}
#
#                                   Q-accnt-attn-check  \
# 0  Since you have different Amazon accounts, will...
# 1                              {"ImportId":"QID106"}
#
#                                             download  \
# 0  Start the data download process\n\n \nGo to th...
# 1                               {"ImportId":"QID26"}
#
#                                   download-fail-expl  \
# 0  Please explain below why you were not able to ...
# 1                          {"ImportId":"QID45_TEXT"}
#
#                              download-fail-screen_Id  \
# 0  Upload a screenshot displaying the issue here....
# 1                       {"ImportId":"QID46_FILE_ID"}
#
#                            download-fail-screen_Name  \
# 0  Upload a screenshot displaying the issue here....
# 1                     {"ImportId":"QID46_FILE_NAME"}
#
#                            download-fail-screen_Size  \
# 0  Upload a screenshot displaying the issue here....
# 1                     {"ImportId":"QID46_FILE_SIZE"}
#
#                            download-fail-screen_Type              q-demos-age  \
# 0  Upload a screenshot displaying the issue here....  What is your age group?
# 1                     {"ImportId":"QID46_FILE_TYPE"}     {"ImportId":"QID35"}
#
#                                   Q-demos-hispanic  \
# 0  Are you of Spanish, Hispanic, or Latino origin?
# 1                             {"ImportId":"QID76"}
#
#                                         Q-demos-race  \
# 0  Choose one or more races that you consider you...
# 1                               {"ImportId":"QID34"}
#
#                                    Q-demos-education  \
# 0  What is the highest level of education you hav...
# 1                               {"ImportId":"QID80"}
#
#                                       Q-demos-income  \
# 0  What was your total household income before ta...
# 1                               {"ImportId":"QID77"}
#
#                   Q-demos-gender  \
# 0  How do you describe yourself?
# 1           {"ImportId":"QID79"}
#
#                             Q-sexual-orientation  \
# 0  Which best describes your sexual orientation?
# 1                           {"ImportId":"QID89"}
#
#                      Q-demos-state  \
# 0  50 States, D.C. and Puerto Rico
# 1             {"ImportId":"QID88"}
#
#                                 Q-amazon-use-howmany  \
# 0  How many people do you share your Amazon accou...
# 1                               {"ImportId":"QID37"}
#
#                        Q-amazon-use-hh-size  \
# 0  How many people are in your "household"?
# 1                      {"ImportId":"QID38"}
#
#                                 Q-amazon-use-how-oft  \
# 0  How often do you (+ anyone you share your acco...
# 1                               {"ImportId":"QID39"}
#
#                                    Q-substance-use_1  \
# 0  Are any of the following the case for:\n\nYou ...
# 1                             {"ImportId":"QID36_2"}
#
#                                    Q-substance-use_2  \
# 0  Are any of the following the case for:\n\nYou ...
# 1                             {"ImportId":"QID36_3"}
#
#                                    Q-substance-use_3  \
# 0  Are any of the following the case for:\n\nYou ...
# 1                             {"ImportId":"QID36_4"}
#
#                                         Q-personal_1  \
# 0  Are any of the following the case for:\n\nYou ...
# 1                             {"ImportId":"QID81_1"}
#
#                                         Q-personal_2  \
# 0  Are any of the following the case for:\n\nYou ...
# 1                             {"ImportId":"QID81_5"}
#
#                                       Q-life-changes  \
# 0  In 2021 did you, or someone you share your Ama...
# 1                               {"ImportId":"QID40"}
#
#                                      Q-data-download       Q-share-error-1  \
# 0  Amazon data\n \n\nGo back to the Amazon page w...   What was the issue?
# 1                               {"ImportId":"QID41"}  {"ImportId":"QID92"}
#
#                                    Q-share-error-2-a  \
# 0  Do you have an active Amazon account that you ...
# 1                              {"ImportId":"QID100"}
#
#                                    Q-share-error-2-b  \
# 0  Can you log into that Amazon account during th...
# 1                              {"ImportId":"QID101"}
#
#                                   Q-share-error-2-c0  \
# 0  Do you also complete surveys or HITs on Amazon...
# 1                              {"ImportId":"QID109"}
#
#                                    Q-share-error-2-c  \
# 0  Is the Amazon.com account that you use to comp...
# 1                               {"ImportId":"QID97"}
#
#                      share-error-3  \
# 0  Please describe the issue here.
# 1        {"ImportId":"QID94_TEXT"}
#
#                                     share-error-4_Id  \
# 0  Please upload a screenshot displaying the issu...
# 1                       {"ImportId":"QID95_FILE_ID"}
#
#                                   share-error-4_Name  \
# 0  Please upload a screenshot displaying the issu...
# 1                     {"ImportId":"QID95_FILE_NAME"}
#
#                                   share-error-4_Size  \
# 0  Please upload a screenshot displaying the issu...
# 1                     {"ImportId":"QID95_FILE_SIZE"}
#
#                                   share-error-4_Type  \
# 0  Please upload a screenshot displaying the issu...
# 1                     {"ImportId":"QID95_FILE_TYPE"}
#
#                                            Q-control  \
# 0  Click to insert the file from Amazon below.\n ...
# 1                               {"ImportId":"QID43"}
#
#                                           Q-altruism  \
# 0  Click to insert the file from Amazon below.\n ...
# 1                               {"ImportId":"QID68"}
#
#                                           Q-bonus-05  \
# 0  Click to insert the file from Amazon below.\n ...
# 1                               {"ImportId":"QID69"}
#
#                                           Q-bonus-20  \
# 0  Click to insert the file from Amazon below.\n ...
# 1                               {"ImportId":"QID70"}
#
#                                           Q-bonus-50  \
# 0  Click to insert the file from Amazon below.\n ...
# 1                               {"ImportId":"QID71"}
#
#                                      Q-data-value-05  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID59"}
#
#                                      Q-data-value-20  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID60"}
#
#                                      Q-data-value-50  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID61"}
#
#                                     Q-data-value-100  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID62"}
#
#                                     Q-data-value-any  \
# 0  How much would you share your data for? - Sele...
# 1                               {"ImportId":"QID64"}
#
#                              Q-data-value-any_1_TEXT  \
# 0  How much would you share your data for? - More...
# 1                        {"ImportId":"QID64_1_TEXT"}
#
#                                     Q-sell-YOUR-data  \
# 0  Do you think Amazon should be able to sell YOU...
# 1                               {"ImportId":"QID84"}
#
#                                 Q-sell-consumer-data  \
# 0  Do you think companies should be able to sell ...
# 1                               {"ImportId":"QID44"}
#
#                                      Q-small-biz-use  \
# 0  Big companies currently collect and sell consu...
# 1                               {"ImportId":"QID73"}
#
#                                         Q-census-use  \
# 0  Do you think the U.S. Census Bureau should use...
# 1                               {"ImportId":"QID74"}
#
#                                   Q-research-society  \
# 0  Do you think researchers should be able to use...
# 1                               {"ImportId":"QID75"}
#
#                                         Q-attn-check  \
# 0  This is an attention check. Help us find peopl...
# 1                               {"ImportId":"QID85"}
#
#                   Q-comments                 SurveyID  \
# 0       Comments? (optional)                 SurveyID
# 1  {"ImportId":"QID48_TEXT"}  {"ImportId":"SurveyID"}
#
#                       ResponseID                 FQID  \
# 0                     ResponseID                 FQID
# 1  {"ImportId":"QSEDResponseID"}  {"ImportId":"FQID"}
#
#                   API_TOKEN                 BATCH                 RandomID  \
# 0                 API_TOKEN                 BATCH                 RandomID
# 1  {"ImportId":"API_TOKEN"}  {"ImportId":"BATCH"}  {"ImportId":"RandomID"}
#
#                   PROLIFIC_PID                 STUDY_ID  \
# 0                 PROLIFIC_PID                 STUDY_ID
# 1  {"ImportId":"PROLIFIC_PID"}  {"ImportId":"STUDY_ID"}
#
#                   SESSION_ID                 showdata  \
# 0                 SESSION_ID                 showdata
# 1  {"ImportId":"SESSION_ID"}  {"ImportId":"showdata"}
#
#                   incentive                 consent
# 0                 incentive                 consent
# 1  {"ImportId":"incentive"}  {"ImportId":"consent"}

# %% [markdown]
# Codebook

# %%
"""
Utility for importing into notebooks. (Move me to a library .py file)
"""

# This is a dump from the recode values exported from qualtrics Q-demos-state.
# Qualtrics put the states in alphabetical order for their recode value, did not code by FIPs
states_recode_text = '1\nAlabama\n2\nAlaska\n3\nArizona\n4\nArkansas\n5\nCalifornia\n6\nColorado\n7\nConnecticut\n8\nDelaware\n9\nDistrict of Columbia\n10\nFlorida\n11\nGeorgia\n12\nHawaii\n13\nIdaho\n14\nIllinois\n15\nIndiana\n16\nIowa\n17\nKansas\n18\nKentucky\n19\nLouisiana\n20\nMaine\n21\nMaryland\n22\nMassachusetts\n23\nMichigan\n24\nMinnesota\n25\nMississippi\n26\nMissouri\n27\nMontana\n28\nNebraska\n29\nNevada\n30\nNew Hampshire\n31\nNew Jersey\n32\nNew Mexico\n33\nNew York\n34\nNorth Carolina\n35\nNorth Dakota\n36\nOhio\n37\nOklahoma\n38\nOregon\n39\nPennsylvania\n40\nPuerto Rico\n41\nRhode Island\n42\nSouth Carolina\n43\nSouth Dakota\n44\nTennessee\n45\nTexas\n46\nUtah\n47\nVermont\n48\nVirginia\n49\nWashington\n50\nWest Virginia\n51\nWisconsin\n52\nWyoming\n53\nI do not reside in the United States'
states_recode_list = states_recode_text.split('\n')
states_choices_map = {states_recode_list[i]: states_recode_list[i+1] for i in range(0, len(states_recode_list), 2)}

# {QID: {Q: Q text, choices: map}}
codebook = {
    'q-demos-age': {
        'Q': 'How old are you?',
        'choices': {
            '1':'18 - 24 years',
            '2':'25 - 34 years',
            '3':'35 - 44 years',
            '4':'45 - 54 years',
            '5':'55 - 64 years',
            '6':'65 or older'
        },
    },
    'Q-demos-race': {
        'Q': 'Choose one or more races that you consider yourself to be',
        'choices': {
            '1':'White',
            '2':'Black or African American',
            '3':'American Indian or Alaska Native',
            '4':'Asian',
            '5':'Native Hawaiian or Pacific Islander',
            '6':'Other'
        },
    },
    'Q-demos-education': {
        'Q':'What is the highest level of education you have completed?',
        'choices': {
            '1':'Some high school or less',
            '2':'High school diploma or GED',
            '3':'Bachelor\'s degree',
            '4':'Graduate or professional degree (MA, MS, MBA, PhD, JD, MD, DDS, etc)',
            '5':'Prefer not to say'
        }
        
    },
    'Q-demos-income': {
        'Q': 'What was your total household income in the previous year before taxes?',
        'choices': {
            '1':'Less than \$25,000','2':'\$25,000 to \$49,999',
            '3':'\$50,000 to $74,999','4':'\$75,000 to \$99,999',
            '5':'\$100,000 to $149,999','6':'\$150,000 or more',
            '7':'Prefer not to say',
        },
    },
    'Q-demos-gender': {
        'Q':'How do you describe yourself?',
        'choices': {'1':'Male','2':'Female','3':'Other', '4':'Prefer not to say'},
    },
    'Q-sexual-orientation': {
      'Q':'Which best describes your sexual orientation?',
        'choices':{
            '1':'heterosexual (straight)',
            '2':'LGBTQ+',
            '3':'prefer not to say'
        },
    },
    'Q-demos-state': {
        'Q':'In which state do you currently reside?',
        'choices': states_choices_map,
    },
    'Q-amazon-use-how-oft': {
        'Q': 'How often do you (+ anyone you share your account with) order deliveries from Amazon?',
        'choices': {
            '1': 'Less than 5 times per month',
            '2': '5 - 10 times per month',
            '3': 'More than 10 times per month'
        }
    }
}

# %%
# Drop the Qualtrics metadata
df = df.drop([0,1])

# %% [markdown]
# ## Sharing behavior

# %% [markdown]
# Set up dataframe to have boolean indicating whether participant shared

# %%
df[
    ['Q-control', 'Q-altruism', 'Q-bonus-05', 'Q-bonus-20', 'Q-bonus-50', 'showdata', 'incentive']
].head()
# Out:
#   Q-control Q-altruism Q-bonus-05 Q-bonus-20 Q-bonus-50 showdata incentive
# 2       NaN        NaN        NaN          1        NaN    false  bonus-20
# 3       NaN        NaN        NaN        NaN          1     true  bonus-50
# 4       NaN          1        NaN        NaN        NaN    false  altruism
# 5       NaN        NaN          1        NaN        NaN     true  bonus-05
# 6       NaN        NaN        NaN          1        NaN    false  bonus-20

# %%
# add boolean indicating share
df['share'] = df[
    ['Q-control', 'Q-altruism', 'Q-bonus-05', 'Q-bonus-20', 'Q-bonus-50']
].astype(float).fillna(0).sum(axis=1)
# rename incentives
df['incentive'] = df['incentive'].map({
    'control':'control', 'altruism':'altruism',
    'bonus-05':'bonus $.05', 'bonus-20':'bonus $.20', 'bonus-50':'bonus $.50'
})
df[['Q-control', 'Q-altruism', 'Q-bonus-05', 'Q-bonus-20', 'Q-bonus-50', 'showdata', 'incentive', 'share']].head()
# Out:
#   Q-control Q-altruism Q-bonus-05 Q-bonus-20 Q-bonus-50 showdata   incentive  \
# 2       NaN        NaN        NaN          1        NaN    false  bonus $.20
# 3       NaN        NaN        NaN        NaN          1     true  bonus $.50
# 4       NaN          1        NaN        NaN        NaN    false    altruism
# 5       NaN        NaN          1        NaN        NaN     true  bonus $.05
# 6       NaN        NaN        NaN          1        NaN    false  bonus $.20
#
#    share
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0

# %% [markdown]
# Aggregate the data
#
# Make a table:
#
# ```
# incentive, showdata, count, share rate
# ```

# %%
def get_aggregate_share_df(df):
    return df.groupby(['incentive','showdata'])['share'].agg(['count','mean']).round(3).reset_index()

# %%
agg_share_df = get_aggregate_share_df(df)
agg_share_df
# Out:
#     incentive showdata  count   mean
# 0    altruism    false    334  0.766
# 1    altruism     true    346  0.841
# 2  bonus $.05    false    340  0.726
# 3  bonus $.05     true    316  0.807
# 4  bonus $.20    false    340  0.779
# 5  bonus $.20     true    326  0.871
# 6  bonus $.50    false    332  0.867
# 7  bonus $.50     true    327  0.905
# 8     control    false    314  0.783
# 9     control     true    344  0.826

# %%
# overall
N = agg_share_df['count'].sum()
overall_share_rate = df['share'].mean().round(3)

print('N = %s' % N)
print('overall share rate: %s' % overall_share_rate)
# Out:
# N = 3319
# overall share rate: 0.817

# %%
# What about for just the control condition?
def get_control_df(df=df):
    return df[df['incentive']=='control']
control_df = get_control_df(df)
control_N = len(control_df)
control_share_rate = control_df['share'].mean().round(3)
print('control N = %s' % control_N)
print('control share rate: %s' % control_share_rate)
# Out:
# control N = 658
# control share rate: 0.805

# %%
def plot_count(pdf, ax):
    width = 0.4
    (pdf[pdf['showdata']=='true']['count']
     .plot(
        kind='bar', color='lightgray', edgecolor='black', #hatch='//',
        label='show data = true',
        ax=ax, width=width, position=1
    ))
    (pdf[pdf['showdata']=='false']['count']
     .plot(
        kind='bar', color='black', 
        edgecolor='black', 
        label='show data = false',
        ax=ax, width=width, position=0)
    )
    ax.set_ylabel('Completions')
    ax.set_xlabel('incentive (random experiment arm)')
    ax.set_xlim([-0.5,4.5])
    ax.legend(facecolor='white', framealpha=0.98, loc='lower right')
    _ = ax.set_xticklabels(pdf[pdf['showdata']=='true']['incentive'], rotation=0)

# %% [markdown]
# Check: is the number of completions consistent across experiment arms?
#
# Use chi-square test of homogeneity.
#
# Null hypothesis: Completions count is the same across experimental arms

# %%
# plot count
fig,ax = plt.subplots(1,1)#, dpi=150)
ax.set_title('Completions by experimental arm')
plot_count(agg_share_df, ax)
# chi-square test
(statistic, pvalue) = chisquare(agg_share_df['count'])
print('chi-square test null hypothesis: Completions count is the same across experimental arms')
print('chi-square test result: stat=%0.3f, p-value=%0.3f' % (statistic, pvalue))
if pvalue > 0.05:
    print('We do not reject the null hypothesis')
else:
    print('We reject the null hypothesis')
# Out:
# chi-square test null hypothesis: Completions count is the same across experimental arms
# chi-square test result: stat=3.353, p-value=0.949
# We do not reject the null hypothesis

# %%
def plot_share_rate(pdf, ax, overall_share_rate=overall_share_rate):
    width = 0.4
    (pdf[pdf['showdata']=='true']['mean']
     .plot(
        kind='bar', color='lightgray', edgecolor='black', #hatch='//',
        label='show data = true',
        ax=ax, width=width, position=1
    ))
    (pdf[pdf['showdata']=='false']['mean']
     .plot(
        kind='bar', color='black', 
        edgecolor='black', 
        label='show data = false',
        ax=ax, width=width, position=0)
    )
    if overall_share_rate is not None:
        ax.hlines(overall_share_rate, -1, 5, color='gray', label='overall')
    ax.set_ylabel('Share rate')
    ax.set_xlabel('incentive (random experiment arm)')
    ax.set_xlim([-0.5,4.5])
    ax.legend(facecolor='white', framealpha=0.98, loc='lower right')
    ax.set_ylim([0,1])
    _ = ax.set_xticklabels(pdf[pdf['showdata']=='true']['incentive'], rotation=0)

# %%
fig,ax = plt.subplots(1,1)#, dpi=150)
ax.set_title('Share rate by experimental arm')
plot_share_rate(agg_share_df, ax)

# %% [markdown]
# observations:
# - showdata=true consistently higher share rate (like before, more consistent)
# - incentive bonus: $0.05 has negative effect compared to control
# - incentive: altruism has no noticeable effect over control

# %% [markdown]
# ### Model

# %%
formula = "share ~ C(incentive, Treatment(reference='control'))"
res = smf.logit(formula=formula, data=df).fit()
print('\n',formula)
res.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.470283
#          Iterations 6
#
#  share ~ C(incentive, Treatment(reference='control'))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  share   No. Observations:                 3319
# Model:                          Logit   Df Residuals:                     3314
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jan 2023   Pseudo R-squ.:                 0.01147
# Time:                        22:54:05   Log-Likelihood:                -1560.9
# converged:                       True   LL-Null:                       -1579.0
# Covariance Type:            nonrobust   LLR p-value:                 2.588e-07
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                      1.4208      0.098     14.427      0.000       1.228       1.614
# C(incentive, Treatment(reference='control'))[T.altruism]      -0.0067      0.138     -0.049      0.961      -0.277       0.264
# C(incentive, Treatment(reference='control'))[T.bonus $.05]    -0.2392      0.135     -1.774      0.076      -0.504       0.025
# C(incentive, Treatment(reference='control'))[T.bonus $.20]     0.1251      0.142      0.883      0.377      -0.153       0.403
# C(incentive, Treatment(reference='control'))[T.bonus $.50]     0.6316      0.157      4.015      0.000       0.323       0.940
# ==============================================================================================================================
# """

# %%
formula = "share ~ C(showdata, Treatment(reference='true'))"
smf.logit(formula=formula, data=df).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.472129
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  share   No. Observations:                 3319
# Model:                          Logit   Df Residuals:                     3317
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 10 Jan 2023   Pseudo R-squ.:                0.007594
# Time:                        22:54:06   Log-Likelihood:                -1567.0
# converged:                       True   LL-Null:                       -1579.0
# Covariance Type:            nonrobust   LLR p-value:                 9.726e-07
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             1.7339      0.069     25.224      0.000       1.599       1.869
# C(showdata, Treatment(reference='true'))[T.false]    -0.4428      0.091     -4.864      0.000      -0.621      -0.264
# =====================================================================================================================
# """

# %%
formula = "share ~ C(incentive, Treatment(reference='control'))*showdata"
smf.logit(formula=formula, data=df).fit().summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.466371
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  share   No. Observations:                 3319
# Model:                          Logit   Df Residuals:                     3309
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 10 Jan 2023   Pseudo R-squ.:                 0.01970
# Time:                        22:54:06   Log-Likelihood:                -1547.9
# converged:                       True   LL-Null:                       -1579.0
# Covariance Type:            nonrobust   LLR p-value:                 5.032e-10
# ===============================================================================================================================================
#                                                                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                       1.2858      0.137      9.385      0.000       1.017       1.554
# C(incentive, Treatment(reference='control'))[T.altruism]                       -0.0974      0.188     -0.517      0.605      -0.467       0.272
# C(incentive, Treatment(reference='control'))[T.bonus $.05]                     -0.3090      0.183     -1.687      0.092      -0.668       0.050
# C(incentive, Treatment(reference='control'))[T.bonus $.20]                     -0.0236      0.189     -0.125      0.901      -0.395       0.348
# C(incentive, Treatment(reference='control'))[T.bonus $.50]                      0.5929      0.212      2.796      0.005       0.177       1.009
# showdata[T.true]                                                                0.2688      0.197      1.362      0.173      -0.118       0.656
# C(incentive, Treatment(reference='control'))[T.altruism]:showdata[T.true]       0.2087      0.278      0.751      0.453      -0.336       0.754
# C(incentive, Treatment(reference='control'))[T.bonus $.05]:showdata[T.true]     0.1848      0.272      0.679      0.497      -0.349       0.718
# C(incentive, Treatment(reference='control'))[T.bonus $.20]:showdata[T.true]     0.3803      0.289      1.317      0.188      -0.186       0.946
# C(incentive, Treatment(reference='control'))[T.bonus $.50]:showdata[T.true]     0.1088      0.317      0.343      0.732      -0.513       0.731
# ===============================================================================================================================================
# """

# %% [markdown]
# ## By demographic groups

# %%
def add_n_labels(ax, values):
    for rect, val in zip(ax.patches, values):
        # Get X and Y placement of label from rect.
        y_value = rect.get_y() + rect.get_height() / 2
        x_value = 0.02
        ax.annotate(
            'n=%s'%val, 
            (x_value, y_value),
            va='center',
        )

def plot_share_by_demo(plt_df, demo_col, ax, control_only=False):
    plt_df.set_index(demo_col)['share rate'].plot.barh(
        ax=ax, 
        color='lightgray',  edgecolor='black'
    )
    ax.set_xlim([0,1])
    ax.set_xlabel('Share rate')
    ax.set_ylabel('')
    ax.set_title('Share rate by %s%s' % (demo_col, ' (control only)' if control_only else ''))
    share_rate = control_share_rate if control_only else overall_share_rate
    ax.axvline(share_rate, color='black')
    # annotate with labels
    add_n_labels(ax, plt_df['n'])

# %%
def get_share_rate_by_Q_df(Q, new_col_name, df=df):
    share_df = (
        df.groupby([Q])['share']
        .agg(['count','mean']).round(3).reset_index()
        .rename(columns={'count':'n', 'mean':'share rate'})
    )
    share_df[new_col_name] = share_df[Q].map(codebook[Q]['choices'])
    return share_df

# %% [markdown]
# ### By gender

# %%
Q = 'Q-demos-gender'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
fig,ax = plt.subplots(figsize=(3,1.5))
ax.set_title(codebook[Q]['Q'])
_ = df[Q].value_counts().sort_index().rename(codebook[Q]['choices']).plot.barh(ax=ax)
plt.show()
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df)
# Out:
# How do you describe yourself?
# {'1': 'Male', '2': 'Female', '3': 'Other', '4': 'Prefer not to say'}
#                index  count    pct
# 0               Male   1511  45.53
# 1             Female   1714  51.64
# 2              Other     80   2.41
# 3  Prefer not to say     14   0.42

# %%
Q = 'Q-demos-gender'
colname = 'gender'
gender_share_df = get_share_rate_by_Q_df(Q, colname)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(gender_share_df)))
plot_share_by_demo(gender_share_df, colname, ax)
gender_share_df
# Out:
#   Q-demos-gender     n  share rate             gender
# 0              1  1511       0.795               Male
# 1              2  1714       0.842             Female
# 2              3    80       0.775              Other
# 3              4    14       0.357  Prefer not to say

# %%
gender_share_df = get_share_rate_by_Q_df(Q, colname, df=control_df)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(gender_share_df)))
plot_share_by_demo(gender_share_df, colname, ax, control_only=True)
gender_share_df
# Out:
#   Q-demos-gender    n  share rate             gender
# 0              1  290       0.807               Male
# 1              2  349       0.814             Female
# 2              3   17       0.706              Other
# 3              4    2       0.000  Prefer not to say

# %% [markdown]
# Model: Are females significantly more likely to share versus males?
#
# Answer:
# - Yes when we include all experimental arms
# - No when just the control arm

# %%
Q = 'Q-demos-gender'
df['gender'] = df[Q].map(codebook[Q]['choices'])
control_df = get_control_df(df)
df[['share','gender']].head(3)
# Out:
#    share  gender
# 2    1.0  Female
# 3    1.0  Female
# 4    1.0  Female

# %%
# limit to just male/female
model_df = df[df['gender'].isin(['Male','Female'])]
formula = "share ~ gender"
res = smf.logit(formula=formula, data=model_df).fit()
print('\n',formula)
display(res.summary())
# check for just the control group too
res = smf.logit(formula=formula, data=get_control_df(model_df)).fit()
print('\nControl arm:\n',formula)
display(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.469345
#          Iterations 6
#
#  share ~ gender
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  share   No. Observations:                 3225
# Model:                          Logit   Df Residuals:                     3223
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 10 Jan 2023   Pseudo R-squ.:                0.003848
# Time:                        22:54:06   Log-Likelihood:                -1513.6
# converged:                       True   LL-Null:                       -1519.5
# Covariance Type:            nonrobust   LLR p-value:                 0.0006269
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          1.6724      0.066     25.261      0.000       1.543       1.802
# gender[T.Male]    -0.3140      0.092     -3.415      0.001      -0.494      -0.134
# ==================================================================================
# """
# Optimization terminated successfully.
#          Current function value: 0.485253
#          Iterations 5
#
# Control arm:
#  share ~ gender
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  share   No. Observations:                  639
# Model:                          Logit   Df Residuals:                      637
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 10 Jan 2023   Pseudo R-squ.:               7.816e-05
# Time:                        22:54:06   Log-Likelihood:                -310.08
# converged:                       True   LL-Null:                       -310.10
# Covariance Type:            nonrobust   LLR p-value:                    0.8257
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          1.4746      0.137     10.724      0.000       1.205       1.744
# gender[T.Male]    -0.0446      0.203     -0.220      0.826      -0.442       0.352
# ==================================================================================
# """

# %%
codebook_male_female = {'1': 'Male', '2': 'Female'}
figsize=(6,4)
fig,axes = plt.subplots(2,1,figsize=(figsize[0],figsize[1]*2))
plt.subplots_adjust(hspace=0.35)
for i, (k,v) in enumerate(codebook_male_female.items()):
    demo_df = df[df[Q]==k]
    demo_agg_share_df = get_aggregate_share_df(demo_df)
    display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(v)
# Out:
#     incentive showdata  count   mean
# 0    altruism    false    157  0.707
# 1    altruism     true    171  0.813
# 2  bonus $.05    false    160  0.725
# 3  bonus $.05     true    147  0.776
# 4  bonus $.20    false    153  0.778
# 5  bonus $.20     true    137  0.818
# 6  bonus $.50    false    142  0.838
# 7  bonus $.50     true    154  0.896
# 8     control    false    136  0.779
# 9     control     true    154  0.831
#     incentive showdata  count   mean
# 0    altruism    false    167  0.826
# 1    altruism     true    167  0.874
# 2  bonus $.05    false    174  0.730
# 3  bonus $.05     true    159  0.843
# 4  bonus $.20    false    177  0.791
# 5  bonus $.20     true    178  0.910
# 6  bonus $.50    false    179  0.894
# 7  bonus $.50     true    164  0.927
# 8     control    false    169  0.781
# 9     control     true    180  0.844

# %% [markdown]
# Observations:
# - overall females share more
# - incentive: altruism has no noticiable effect for males but seems to have positive share effect on females
# - all incentives (vs control) seem to have a larger positive effect on female share rate

# %% [markdown]
# ### By income

# %%
Q = 'Q-demos-income'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
fig,ax = plt.subplots(figsize=(4,2))
_ = df[Q].value_counts().sort_index().rename(codebook[Q]['choices']).plot.barh(ax=ax)
ax.set_title('Participant reported household income')
plt.show()
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df)
# Out:
# What was your total household income in the previous year before taxes?
# {'1': 'Less than \\$25,000', '2': '\\$25,000 to \\$49,999', '3': '\\$50,000 to $74,999', '4': '\\$75,000 to \\$99,999', '5': '\\$100,000 to $149,999', '6': '\\$150,000 or more', '7': 'Prefer not to say'}
#                    index  count    pct
# 0     Less than \$25,000    467  14.07
# 1   \$25,000 to \$49,999    775  23.35
# 2    \$50,000 to $74,999    657  19.80
# 3   \$75,000 to \$99,999    525  15.82
# 4  \$100,000 to $149,999    508  15.31
# 5      \$150,000 or more    326   9.82
# 6      Prefer not to say     61   1.84

# %%
print(Q)
print(codebook[Q]['choices'])
colname = 'income'
income_share_df = get_share_rate_by_Q_df(Q, colname)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(income_share_df)))
plot_share_by_demo(income_share_df, colname, ax)
income_share_df
# Out:
# Q-demos-income
# {'1': 'Less than \\$25,000', '2': '\\$25,000 to \\$49,999', '3': '\\$50,000 to $74,999', '4': '\\$75,000 to \\$99,999', '5': '\\$100,000 to $149,999', '6': '\\$150,000 or more', '7': 'Prefer not to say'}
#   Q-demos-income    n  share rate                 income
# 0              1  467       0.805     Less than \$25,000
# 1              2  775       0.848   \$25,000 to \$49,999
# 2              3  657       0.805    \$50,000 to $74,999
# 3              4  525       0.834   \$75,000 to \$99,999
# 4              5  508       0.831  \$100,000 to $149,999
# 5              6  326       0.779      \$150,000 or more
# 6              7   61       0.590      Prefer not to say

# %%
income_share_df = get_share_rate_by_Q_df(Q, colname, df=control_df)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(income_share_df)))
plot_share_by_demo(income_share_df, colname, ax, control_only=True)
income_share_df
# Out:
#   Q-demos-income    n  share rate                 income
# 0              1   97       0.773     Less than \$25,000
# 1              2  150       0.847   \$25,000 to \$49,999
# 2              3  115       0.809    \$50,000 to $74,999
# 3              4  107       0.804   \$75,000 to \$99,999
# 4              5   99       0.859  \$100,000 to $149,999
# 5              6   72       0.778      \$150,000 or more
# 6              7   18       0.444      Prefer not to say

# %%
figsize=(6,4)
choices = codebook[Q]['choices']
fig,axes = plt.subplots(len(choices),1,figsize=(figsize[0],figsize[1]*len(choices)))
plt.subplots_adjust(hspace=0.35)
for i, (k,v) in enumerate(codebook[Q]['choices'].items()):
    demo_df = df[df[Q]==k]
    demo_agg_share_df = get_aggregate_share_df(demo_df)
    #display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(v)

# %% [markdown]
# ### By age

# %%
Q = 'q-demos-age'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
fig,ax = plt.subplots(figsize=(4,2))
_ = df[Q].value_counts().sort_index().rename(codebook[Q]['choices']).plot.barh(ax=ax)
ax.set_title('Participant reported age')
plt.show()
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df)
# Out:
# How old are you?
# {'1': '18 - 24 years', '2': '25 - 34 years', '3': '35 - 44 years', '4': '45 - 54 years', '5': '55 - 64 years', '6': '65 or older'}
#            index  count    pct
# 0  18 - 24 years    544  16.39
# 1  25 - 34 years   1231  37.09
# 2  35 - 44 years    788  23.74
# 3  45 - 54 years    424  12.77
# 4  55 - 64 years    229   6.90
# 5    65 or older    103   3.10

# %%
colname = 'age'
age_share_df = get_share_rate_by_Q_df(Q, colname)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(age_share_df)))
plot_share_by_demo(age_share_df, colname, ax)
age_share_df
# Out:
#   q-demos-age     n  share rate            age
# 0           1   544       0.781  18 - 24 years
# 1           2  1231       0.803  25 - 34 years
# 2           3   788       0.844  35 - 44 years
# 3           4   424       0.833  45 - 54 years
# 4           5   229       0.860  55 - 64 years
# 5           6   103       0.816    65 or older

# %%
age_share_df = get_share_rate_by_Q_df(Q, colname, df=control_df)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(age_share_df)))
plot_share_by_demo(age_share_df, colname, ax, control_only=True)
age_share_df
# Out:
#   q-demos-age    n  share rate            age
# 0           1  106       0.679  18 - 24 years
# 1           2  246       0.809  25 - 34 years
# 2           3  140       0.864  35 - 44 years
# 3           4   86       0.791  45 - 54 years
# 4           5   54       0.833  55 - 64 years
# 5           6   26       0.962    65 or older

# %%
figsize=(6,4)
# exclude categories with N < 60
demo_df = demo_df[demo_df['count']>60]
fig,axes = plt.subplots(len(demo_df),1,figsize=(figsize[0],figsize[1]*len(demo_df)))
plt.subplots_adjust(hspace=0.35)
i = 0
for (k,v) in codebook[Q]['choices'].items():
    if v not in demo_df['index'].values:
        continue
    demo_agg_share_df = get_aggregate_share_df(df[df[Q]==k])
    #display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(v)
    i += 1

# %% [markdown]
# ### By education

# %%
Q = 'Q-demos-education'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
fig,ax = plt.subplots(figsize=(5,2))
_ = df[Q].value_counts().sort_index().rename(codebook[Q]['choices']).plot.barh(ax=ax)
ax.set_title(codebook[Q]['Q'])
plt.show()
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df)
# Out:
# What is the highest level of education you have completed?
# {'1': 'Some high school or less', '2': 'High school diploma or GED', '3': "Bachelor's degree", '4': 'Graduate or professional degree (MA, MS, MBA, PhD, JD, MD, DDS, etc)', '5': 'Prefer not to say'}
#                                                index  count    pct
# 0                           Some high school or less     35   1.05
# 1                         High school diploma or GED   1216  36.64
# 2                                  Bachelor's degree   1466  44.17
# 3  Graduate or professional degree (MA, MS, MBA, ...    568  17.11
# 4                                  Prefer not to say     34   1.02

# %%
colname = 'education'
education_share_df = get_share_rate_by_Q_df(Q, colname)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(education_share_df)))
plot_share_by_demo(education_share_df, colname, ax)
education_share_df
# Out:
#   Q-demos-education     n  share rate  \
# 0                 1    35       0.829
# 1                 2  1216       0.831
# 2                 3  1466       0.806
# 3                 4   568       0.833
# 4                 5    34       0.529
#
#                                            education
# 0                           Some high school or less
# 1                         High school diploma or GED
# 2                                  Bachelor's degree
# 3  Graduate or professional degree (MA, MS, MBA, ...
# 4                                  Prefer not to say

# %%
education_share_df = get_share_rate_by_Q_df(Q, colname, df=control_df)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(education_share_df)))
plot_share_by_demo(education_share_df, colname, ax, control_only=True)
education_share_df
# Out:
#   Q-demos-education    n  share rate  \
# 0                 1    9       1.000
# 1                 2  223       0.803
# 2                 3  297       0.785
# 3                 4  121       0.868
# 4                 5    8       0.500
#
#                                            education
# 0                           Some high school or less
# 1                         High school diploma or GED
# 2                                  Bachelor's degree
# 3  Graduate or professional degree (MA, MS, MBA, ...
# 4                                  Prefer not to say

# %%
figsize=(6,4)
# exclude categories with N < 60
demo_df = demo_df[demo_df['count']>60]
fig,axes = plt.subplots(len(demo_df),1,figsize=(figsize[0],figsize[1]*len(demo_df)))
plt.subplots_adjust(hspace=0.35)
i = 0
for (k,v) in codebook[Q]['choices'].items():
    if v not in demo_df['index'].values:
        continue
    demo_agg_share_df = get_aggregate_share_df(df[df[Q]==k])
    #display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(v)
    i += 1

# %% [markdown]
# ### By sexual orientation

# %%
Q = 'Q-sexual-orientation'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
fig,ax = plt.subplots(figsize=(5,2))
_ = df[Q].value_counts().sort_index().rename(codebook[Q]['choices']).plot.barh(ax=ax)
ax.set_title(codebook[Q]['Q'])
plt.show()
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df)
# Out:
# Which best describes your sexual orientation?
# {'1': 'heterosexual (straight)', '2': 'LGBTQ+', '3': 'prefer not to say'}
#                      index  count    pct
# 0  heterosexual (straight)   2511  75.66
# 1                   LGBTQ+    753  22.69
# 2        prefer not to say     55   1.66

# %%
colname = 'LGBTQ+ status'
lgbtq_share_df = get_share_rate_by_Q_df(Q, colname)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(lgbtq_share_df)))
plot_share_by_demo(lgbtq_share_df, colname, ax)
lgbtq_share_df
# Out:
#   Q-sexual-orientation     n  share rate            LGBTQ+ status
# 0                    1  2511       0.819  heterosexual (straight)
# 1                    2   753       0.829                   LGBTQ+
# 2                    3    55       0.564        prefer not to say

# %%
lgbtq_share_df = get_share_rate_by_Q_df(Q, colname, df=control_df)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(lgbtq_share_df)))
plot_share_by_demo(lgbtq_share_df, colname, ax, control_only=True)
lgbtq_share_df
# Out:
#   Q-sexual-orientation    n  share rate            LGBTQ+ status
# 0                    1  499       0.804  heterosexual (straight)
# 1                    2  151       0.821                   LGBTQ+
# 2                    3    8       0.625        prefer not to say

# %%
figsize=(6,4)
# exclude categories with N < 60
demo_df = demo_df[demo_df['count']>60]
fig,axes = plt.subplots(len(demo_df),1,figsize=(figsize[0],figsize[1]*len(demo_df)))
plt.subplots_adjust(hspace=0.35)
i = 0
for (k,v) in codebook[Q]['choices'].items():
    if v not in demo_df['index'].values:
        continue
    demo_agg_share_df = get_aggregate_share_df(df[df[Q]==k])
    #display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(v)
    i += 1

# %% [markdown]
# ### Race
#
# Hypothesis: participants who identify as white-only will be more likely to share data
#
# Note U.S. population ~75% white
#
#
# Result:
# - White participants more likely to share in control arm
# - Other participants more likely to share in non-control arms

# %%
Q = 'Q-demos-race'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df.sort_values('count', ascending=False))
# Out:
# Choose one or more races that you consider yourself to be
# {'1': 'White', '2': 'Black or African American', '3': 'American Indian or Alaska Native', '4': 'Asian', '5': 'Native Hawaiian or Pacific Islander', '6': 'Other'}
#                                   index  count    pct
# 0                                 White   2571  77.46
# 18                                Asian    264   7.95
# 12            Black or African American    223   6.72
# 21                                Other     64   1.93
# 9                                   1,4     51   1.54
# 1                                   1,2     39   1.18
# 6                                   1,3     38   1.14
# 17     American Indian or Alaska Native     21   0.63
# 11                                  1,6     13   0.39
# 2                                 1,2,3      8   0.24
# 15                                  2,4      5   0.15
# 13                                  2,3      5   0.15
# 20  Native Hawaiian or Pacific Islander      4   0.12
# 3                                 1,2,4      3   0.09
# 5                                 1,2,6      2   0.06
# 19                                  4,5      2   0.06
# 14                                2,3,4      1   0.03
# 10                                  1,5      1   0.03
# 16                                  2,6      1   0.03
# 8                                 1,3,6      1   0.03
# 7                                 1,3,4      1   0.03
# 4                               1,2,4,6      1   0.03

# %%
# Make column race where 1=white; 0=otherwise
colname = 'white status'
df[colname] = df[Q].apply(lambda r: 'White only' if r=='1' else 'Otherwise')
white_share_df = (
    df.groupby([colname])['share']
    .agg(['count','mean']).round(3).reset_index()
    .rename(columns={'count':'n', 'mean':'share rate'})
)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(white_share_df)))
plot_share_by_demo(white_share_df, colname, ax)
white_share_df
# Out:
#   white status     n  share rate
# 0    Otherwise   748       0.774
# 1   White only  2571       0.830

# %%
# For just control condition
control_df = get_control_df(df)
c_white_share_df = (
    control_df.groupby([colname])['share']
    .agg(['count','mean']).round(3).reset_index()
    .rename(columns={'count':'n', 'mean':'share rate'})
)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(white_share_df)))
plot_share_by_demo(c_white_share_df, colname, ax, control_only=True)
ax.set_title('Share by white status (control only)')
c_white_share_df
# Out:
#   white status    n  share rate
# 0    Otherwise  151       0.748
# 1   White only  507       0.822

# %%
figsize=(6,4)
fig,axes = plt.subplots(2,1,figsize=(figsize[0],figsize[1]*2))
plt.subplots_adjust(hspace=0.35)
for i, r in enumerate(['White only', 'Otherwise']):
    demo_df = df[df[colname]==r]
    demo_agg_share_df = get_aggregate_share_df(demo_df)
    display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(r)
# Out:
#     incentive showdata  count   mean
# 0    altruism    false    250  0.788
# 1    altruism     true    270  0.837
# 2  bonus $.05    false    263  0.745
# 3  bonus $.05     true    254  0.815
# 4  bonus $.20    false    273  0.791
# 5  bonus $.20     true    250  0.880
# 6  bonus $.50    false    247  0.887
# 7  bonus $.50     true    257  0.914
# 8     control    false    242  0.785
# 9     control     true    265  0.857
#     incentive showdata  count   mean
# 0    altruism    false     84  0.702
# 1    altruism     true     76  0.855
# 2  bonus $.05    false     77  0.662
# 3  bonus $.05     true     62  0.774
# 4  bonus $.20    false     67  0.731
# 5  bonus $.20     true     76  0.842
# 6  bonus $.50    false     85  0.812
# 7  bonus $.50     true     70  0.871
# 8     control    false     72  0.778
# 9     control     true     79  0.722

# %% [markdown]
# ### By purchase frequency
#
# Finds:
# - people who purchase less frequently more likely to share (have less to share?)

# %%
Q = 'Q-amazon-use-how-oft'
print('%s'%codebook[Q]['Q'])
print('%s'%codebook[Q]['choices'])
fig,ax = plt.subplots(figsize=(3,1.5))
_ = df[Q].value_counts().sort_index().rename(codebook[Q]['choices']).plot.barh(ax=ax)
ax.set_title('Purchase frequency')
plt.show()
demo_df = (df[Q].value_counts()
          .sort_index().rename(codebook[Q]['choices'])
          .to_frame(name='count').reset_index()
          .assign(pct=lambda x: round(100*x['count']/N, 2)))
display(demo_df)
# Out:
# How often do you (+ anyone you share your account with) order deliveries from Amazon?
# {'1': 'Less than 5 times per month', '2': '5 - 10 times per month', '3': 'More than 10 times per month'}
#                           index  count    pct
# 0   Less than 5 times per month   2119  63.84
# 1        5 - 10 times per month    953  28.71
# 2  More than 10 times per month    247   7.44

# %%
colname = 'purchase frequency'
pf_share_df = get_share_rate_by_Q_df(Q, colname)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(pf_share_df)))
plot_share_by_demo(pf_share_df, colname, ax)
pf_share_df
# Out:
#   Q-amazon-use-how-oft     n  share rate            purchase frequency
# 0                    1  2119       0.817   Less than 5 times per month
# 1                    2   953       0.816        5 - 10 times per month
# 2                    3   247       0.822  More than 10 times per month

# %%
colname = 'purchase frequency'
pf_share_df = get_share_rate_by_Q_df(Q, colname, df=control_df)
fig,ax = plt.subplots(1,1, figsize=(4, 0.5*len(pf_share_df)))
plot_share_by_demo(pf_share_df, colname, ax, control_only=True)
pf_share_df
# Out:
#   Q-amazon-use-how-oft    n  share rate            purchase frequency
# 0                    1  419       0.831   Less than 5 times per month
# 1                    2  192       0.745        5 - 10 times per month
# 2                    3   47       0.830  More than 10 times per month

# %%
figsize=(6,4)
choices = codebook[Q]['choices']
fig,axes = plt.subplots(len(choices),1,figsize=(figsize[0],figsize[1]*len(choices)))
plt.subplots_adjust(hspace=0.35)
for i, (k,v) in enumerate(codebook[Q]['choices'].items()):
    demo_df = df[df[Q]==k]
    demo_agg_share_df = get_aggregate_share_df(demo_df)
    #display(demo_agg_share_df)
    ax = axes[i]
    plot_share_rate(demo_agg_share_df, ax)
    ax.set_title(v)

# %% [markdown]
# ### Real vs hypothetical
#
# On average, how does the hypothetical amount of money participants *say they would* accept in exchange for their data compare to the amount that participants *do accept* as bonus payment for their data, when presented with the real opportunity?
# Hypothesis: on average participants are willing to accept a lower amount than they report they would in the hypothetical scenario.

# %%
fig,ax = plt.subplots(1,1, figsize=(6,4))#, dpi=300)
ax.set_title('Share rate by experimental arm')
plot_share_rate(agg_share_df, ax)

# %%
# take just the participants in the control arm who answered no

control_no_share_df = df[(df['incentive']=='control') & (df['share']==0)]
control_no_share_showdata1_df = control_no_share_df[control_no_share_df['showdata']=='true']
control_no_share_showdata0_df = control_no_share_df[control_no_share_df['showdata']=='false']
print('n=%s participants in incentive:control arm who did not share data' % len(control_no_share_df))
print('n=%s participants in incentive:control, showdata:true arm who did not share data' 
      % len(control_no_share_showdata1_df))
print('n=%s participants in incentive:control, showdata:false arm who did not share data' 
      % len(control_no_share_showdata0_df))
# control_no_share_df.head()
# Out:
# n=128 participants in incentive:control arm who did not share data
# n=60 participants in incentive:control, showdata:true arm who did not share data
# n=68 participants in incentive:control, showdata:false arm who did not share data

# %%
# data value Qs
data_value_Qs = [
    'Q-data-value-05','Q-data-value-20', 'Q-data-value-50', 
    'Q-data-value-100', 'Q-data-value-any', 'Q-data-value-any_1_TEXT'
]
control_no_share_df[data_value_Qs].head()
# Out:
#     Q-data-value-05 Q-data-value-20 Q-data-value-50 Q-data-value-100  \
# 18                0               0               0                0
# 56                0               0               0                0
# 81                0               1             NaN              NaN
# 133               0               0               1              NaN
# 144               0               0               0                0
#
#     Q-data-value-any Q-data-value-any_1_TEXT
# 18                 1                   30.00
# 56                 1                      50
# 81               NaN                     NaN
# 133              NaN                     NaN
# 144                0                     NaN

# %% [markdown]
# First focus on just showdata=true
#
# What is the difference in the share rate for incentive=$0.50 vs control?
#
# Count everyone in the control group that did not share their data, who said they would hypothetically share their data for value of \\$0.05, \\$0.20, or \$0.50

# %%
control_showdata1_share_rate = agg_share_df.set_index(
    ['incentive','showdata']
).loc[('control','true')]['mean']
print('control share rate:', control_showdata1_share_rate)
bonus50_showdata1_share_rate = agg_share_df.set_index(
    ['incentive','showdata']
).loc[('bonus $.50','true')]['mean']
print('bonus $.50 share rate:', bonus50_showdata1_share_rate)
share_rate_diff = bonus50_showdata1_share_rate - control_showdata1_share_rate
print('share rate difference: %0.2f' % share_rate_diff)
# Out:
# control share rate: 0.826
# bonus $.50 share rate: 0.905
# share rate difference: 0.08

# %% [markdown]
# Here's the approach taken below:
#
# (restricted to showdata=true)
#
# - (a) We compute the fraction of people who would *truly share* for \$0.50 or less
# - (b) We compute the fraction of people who *say they would hypothetically share* for \$0.50 or less
#
# We compare (a) and (b)
#
# We compute these quantities as follows:
#
# (a)
# For people in the experiment arm: bonus $0.50
#
# - We count the number of people who shared their data.
# - And the number of people who did not share their data.
# - We compute the fraction
#
# (b)
# We consider the experiment arm: control equivalent to offering $0.
#
# For people in the experiment arm: control
# - we count the number of people who did share
# - and the number of people who did not share but then said they would hypothetically share for either \\$0.05, \\$0.20, \\$0.50
# - we add these quantities and consider this the number of people who would hypothetically share for $0.50 or less
# - we count the number of people who did not share and would not hypothetically share for \$0.50 or less
# - we compute the fraction
#
# (We know there is a problem with this way of thinking about this, because our results show that people in the control arm are more likely to share their data than people offered \$0.05.)
#
#
# Make a table:
#
# control_shares:
#
# ```
# amount, share count, cumulative share count, total count, cumulative share rate
#
# ```

# %%
s1 = df[(df['incentive']=='control') & (df['showdata']=='true')][[
    'share',
    'Q-data-value-05','Q-data-value-20', 'Q-data-value-50', 
    'Q-data-value-100', 'Q-data-value-any'
]]
# rename columns to represent amounts offered
s1.columns=['$0','$0.05','$0.20','$0.50','$1.00','> $1.00']
s1.head(3)
# Out:
#      $0 $0.05 $0.20 $0.50 $1.00 > $1.00
# 18  0.0     0     0     0     0       1
# 23  1.0   NaN   NaN   NaN   NaN     NaN
# 28  1.0   NaN   NaN   NaN   NaN     NaN

# %%
control_showdata1_shares_df = (s1.astype(float).fillna(0).apply(sum)
                               .to_frame(name='share count'))
control_showdata1_shares_df.index.names = ['amount']
control_showdata1_shares_df['cumulative count'] = control_showdata1_shares_df['share count'].cumsum()
control_showdata1_shares_df['total'] = len(s1)
control_showdata1_shares_df['cumulative share rate'] = (
    control_showdata1_shares_df['cumulative count']/control_showdata1_shares_df['total']
).round(3)
control_showdata1_shares_df
# Out:
#          share count  cumulative count  total  cumulative share rate
# amount
# $0             284.0             284.0    344                  0.826
# $0.05            9.0             293.0    344                  0.852
# $0.20            1.0             294.0    344                  0.855
# $0.50            4.0             298.0    344                  0.866
# $1.00            4.0             302.0    344                  0.878
# > $1.00         32.0             334.0    344                  0.971

# %% [markdown]
# Compare this to:

# %%
real_shares_showdata1 = (
    agg_share_df.set_index(['showdata','incentive'])
    .loc['true']
    .rename(columns={'mean':'share rate'})
    .rename({'control':'$0', 'bonus $.05':'$0.05', 'bonus $.20':'$0.20', 'bonus $.50':'$0.50'})
    .loc[['$0', '$0.05', '$0.20', '$0.50']]
)
real_shares_showdata1
# Out:
#            count  share rate
# incentive
# $0           344       0.826
# $0.05        316       0.807
# $0.20        326       0.871
# $0.50        327       0.905

# %% [markdown]
# Do the same for showdata=false

# %%
control_showdata0_share_rate = agg_share_df.set_index(
    ['incentive','showdata']
).loc[('control','false')]['mean']
print('control share rate:', control_showdata0_share_rate)
bonus50_showdata0_share_rate = agg_share_df.set_index(
    ['incentive','showdata']
).loc[('bonus $.50','false')]['mean']
print('bonus $.50 share rate:', bonus50_showdata0_share_rate)
share_rate_diff = bonus50_showdata0_share_rate - control_showdata0_share_rate
print('share rate difference: %0.2f' % share_rate_diff)
# Out:
# control share rate: 0.783
# bonus $.50 share rate: 0.867
# share rate difference: 0.08

# %%
s0 = df[(df['incentive']=='control') & (df['showdata']=='false')][[
    'share',
    'Q-data-value-05','Q-data-value-20', 'Q-data-value-50', 
    'Q-data-value-100', 'Q-data-value-any'
]]
# rename columns to represent amounts offered
s0.columns=['$0','$0.05','$0.20','$0.50','$1.00','> $1.00']
control_showdata0_shares_df = (s0.astype(float).fillna(0).apply(sum)
                               .to_frame(name='share count'))
control_showdata0_shares_df.index.names = ['amount']
control_showdata0_shares_df['cumulative count'] = control_showdata0_shares_df['share count'].cumsum()
control_showdata0_shares_df['total'] = len(s0)
control_showdata0_shares_df['cumulative share rate'] = (
    control_showdata0_shares_df['cumulative count']/control_showdata0_shares_df['total']
).round(3)
control_showdata0_shares_df
# Out:
#          share count  cumulative count  total  cumulative share rate
# amount
# $0             246.0             246.0    314                  0.783
# $0.05            6.0             252.0    314                  0.803
# $0.20            2.0             254.0    314                  0.809
# $0.50            2.0             256.0    314                  0.815
# $1.00           10.0             266.0    314                  0.847
# > $1.00         32.0             298.0    314                  0.949

# %%
print('compare to:')
real_shares_showdata0 = (
    agg_share_df.set_index(['showdata','incentive'])
    .loc['false']
    .rename(columns={'mean':'share rate'})
    .rename({'control':'$0', 'bonus $.05':'$0.05', 'bonus $.20':'$0.20', 'bonus $.50':'$0.50'})
    .loc[['$0', '$0.05', '$0.20', '$0.50']]
)
real_shares_showdata0
# Out:
# compare to:
#            count  share rate
# incentive
# $0           314       0.783
# $0.05        340       0.726
# $0.20        340       0.779
# $0.50        332       0.867

# %% [markdown]
# If this seems like the right kind of comparison to make, result:
#
# When looking at \$0.50 incentive:
# - people more likely to actually share (a) vs say they would share (b)
# - for both showdata=true,showdata=false
# - (hypothesis confirmed)
#
# This is also the case for the \$0.20 incentive
#
# But when looking at \\$0.05 incentive, this is not the case
# - for both showdata=true, showdata=false: Fewer people actually share than say they would share

# %% [markdown]
# Plot it

# %%
black_alpha = 0.5
fig,ax = plt.subplots(1,1, figsize=(6,4), dpi=150)
# showdata:true
ax.plot(control_showdata1_shares_df['cumulative share rate'], 
        'o',#--', 
        color='purple', markersize=8,
       label='hypothetical (showdata:true)')
ax.plot(real_shares_showdata1['share rate'], 
        's',#-', 
        alpha=black_alpha,
        color='purple', markersize=8,
       label='real (showdata:true)')

ax.plot(control_showdata0_shares_df['cumulative share rate'], 
        'o',#--', 
        color='black', markersize=8,
       label='hypothetical (showdata:false)')
ax.plot(real_shares_showdata0['share rate'], 
        's',#-', 
        alpha=black_alpha,
        color='black', markersize=8,
       label='real (showdata:false)')
ax.set_ylim([0.5,1])
ax.set_ylabel('share rate')
ax.set_xlabel('($) amount offered')
_ = ax.legend()

# %% [markdown]
# # Questions about data use
#
# At the end of the survey we ask:
#
# - Do you think Amazon should be able to sell YOUR purchase data to other companies?
# - Do you think companies should be able to sell consumer purchase data to other companies?
# - Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?
# - Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?
# - Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?
#
# The order of these questions is randomized.

# %%
data_use_Qs = {
    'Q-sell-YOUR-data': {
        'Q':'Do you think Amazon should be able to sell YOUR purchase data to other companies?',
        'choices': {'1': 'Yes','2':'No','3':'Yes if I get part of the profit','4':"I don't know"},
    },
    'Q-sell-consumer-data': {
        'Q':'Do you think companies should be able to sell consumer purchase data to other companies?',
        'choices': {'1': 'Yes','2':'No','3':'Yes if consumers get part of the profit','4':"I don't know"},
    },
    'Q-small-biz-use': {
        'Q':'Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?',
        'choices': {'1': 'Yes','2':'No','3':"I don't know"},
    },
    'Q-census-use': {
        'Q':'Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?',
        'choices': {'1': 'Yes','2':'No','3':"I don't know"},
    },
    'Q-research-society': {
        'Q':'Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?',
        'choices': {'1': 'Yes','2':'No','3':"I don't know"},
    }, 
}

# %% [markdown]
# Overall what were the answers to these questions?

# %%
Q = 'Q-sell-YOUR-data'
for Q in data_use_Qs.keys():
    answers_df = (df[Q].value_counts()
              .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
              .to_frame(name='count')
              .assign(pct=lambda x: round(100*x['count']/N, 2)))
    print(data_use_Qs[Q]['Q'])
    fig,ax = plt.subplots(1,1, figsize=(3,0.4*len(answers_df)), dpi=150)
    ax.set_xlabel('(%) percent')
    ax.barh(answers_df.index, answers_df['pct'], color='black')
    #display(answers_df)
    plt.show()
# Out:
# Do you think Amazon should be able to sell YOUR purchase data to other companies?
# Do you think companies should be able to sell consumer purchase data to other companies?
# Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?
# Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?
# Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?

# %% [markdown]
# How do the answers differ by whether participant shared?

# %%
no_share_df = df[df['share']==0]
yes_share_df = df[df['share']==1]
for Q in data_use_Qs.keys():
    n_choices = len(data_use_Qs[Q]['choices'])
    print(data_use_Qs[Q]['Q'])
    fig,ax = plt.subplots(1,1,figsize=(3,0.5*n_choices), dpi=150)
    a0_df = (no_share_df[Q].value_counts()
                  .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
                  .to_frame(name='count')
                  .assign(pct=lambda x: round(100*x['count']/len(no_share_df), 2)))
    a1_df = (yes_share_df[Q].value_counts()
                  .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
                  .to_frame(name='count')
                  .assign(pct=lambda x: round(100*x['count']/len(yes_share_df), 2)))
    width = 0.35
    a0_df['pct'].plot(
        kind='barh', ax=ax, color='black', edgecolor='black', 
        width=width, position=0, label='no share'
    )
    a1_df['pct'].plot(
        kind='barh', ax=ax, color='lightgray', edgecolor='black', 
        width=width, position=1, label='did share'
    )
    ax.set_xlabel('(%) percent')
    ax.set_ylim([-0.5,(n_choices - 0.5)])
    ax.legend(facecolor='white', framealpha=0.95)#, loc='upper right')
    plt.show()
#     display(a0_df)
#     display(a1_df)
# Out:
# Do you think Amazon should be able to sell YOUR purchase data to other companies?
# Do you think companies should be able to sell consumer purchase data to other companies?
# Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?
# Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?
# Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?

# %% [markdown]
# #### Did the random assignment to an experimental arm impact the participants' responses to these questions?
#
# For each question, make a separate plot for each response, separating by incentive on the x-axis.

# %%
def plot_answer_rate(pdf, ax, N, overall_rate=None):
    width = 0.4
    (pdf[pdf['showdata']=='true']['pct']
     .plot(
        kind='barh', color='lightgray', edgecolor='black',
        label='show data = true',
        ax=ax, width=width, position=1
    ))
    (pdf[pdf['showdata']=='false']['pct']
     .plot(
        kind='barh', color='black', 
        edgecolor='black', 
        label='show data = false',
        ax=ax, width=width, position=0)
    )
    ax.set_xlabel('Answer rate (N=%s)' % N)
    ax.set_ylim([-0.5,4.5])
    #ax.set_xlim([0,1])
    _ = ax.set_yticklabels(pdf[pdf['showdata']=='true']['incentive'])

# %%
for q, Q in enumerate(data_use_Qs.keys()):
    n_choices = len(data_use_Qs[Q]['choices'])
    #print(Q)
    print(data_use_Qs[Q]['Q'])
    fig,axes = plt.subplots(1,n_choices,figsize=(3*n_choices,3), sharex=True, sharey=True, dpi=150)
    plt.subplots_adjust(wspace=0.1)
    for i, (choice_code, choice_text) in enumerate(data_use_Qs[Q]['choices'].items()):
        ax = axes[i]
        c_df = df[(df[Q]==choice_code)]
        c_N = len(c_df)
        ax.set_title('%s' % (choice_text))
        #print(i, choice_text)
        #print('N=%s'%c_N)
        c_by_exp_arm_df = (
            c_df.groupby(['incentive','showdata'])['ResponseId'].agg(['count'])
             .merge(
                df.groupby(['incentive','showdata'])['ResponseId'].agg(['count']),
                on=['incentive', 'showdata'],
                how='outer', suffixes=["","_all"]
             ).reset_index()
             .assign(pct=lambda x: (x['count']/x['count_all']).round(3)))
        #display(c_by_exp_arm_df)
        plot_answer_rate(c_by_exp_arm_df, ax, c_N)
        if q==0 and i==0:
            ax.legend(facecolor='white', framealpha=0.98, loc='lower right')
    plt.show()
# Out:
# Do you think Amazon should be able to sell YOUR purchase data to other companies?
# Do you think companies should be able to sell consumer purchase data to other companies?
# Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?
# Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?
# Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?

# %%
# by experimental arm

no_share_df = df[df['share']==0]
yes_share_df = df[df['share']==1]
for Q in data_use_Qs.keys():
    n_choices = len(data_use_Qs[Q]['choices'])
    print(data_use_Qs[Q]['Q'])
    fig,axes = plt.subplots(2,5,figsize=(5*3.5,2*0.5*n_choices),sharey=True,sharex=True, dpi=150)
    plt.subplots_adjust(wspace=0.05, hspace=0.3)
    for i, showdata in enumerate(['true','false']):
        for j, incentive in enumerate(sorted(df['incentive'].unique())):
            ax = axes[i][j]
            a0_df = (no_share_df[(
                (no_share_df['showdata']==showdata) & (no_share_df['incentive']==incentive)
            )][Q].value_counts()
                          .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
                          .to_frame(name='count'))
            a0_df['pct'] = (100*a0_df['count']/a0_df['count'].sum()).round(2)
            a1_df = (yes_share_df[
                ((yes_share_df['showdata']==showdata) & (yes_share_df['incentive']==incentive))
            ][Q].value_counts()
                          .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
                          .to_frame(name='count'))
            a1_df['pct'] = (100*a1_df['count']/a1_df['count'].sum()).round(2)
            width = 0.35
            a0_df['pct'].plot(
                kind='barh', ax=ax, color='black', edgecolor='black', 
                width=width, position=0, label='no share'
            )
            a1_df['pct'].plot(
                kind='barh', ax=ax, color='lightgray', edgecolor='black', 
                width=width, position=1, label='did share'
            )
            ax.set_xlabel('(%) percent')
            ax.set_ylim([-0.5,(n_choices - 0.5)])
            if i==0 and j==0:
                ax.legend(facecolor='white', framealpha=0.95)#, loc='upper right')
            ax.set_title('%s; showdata:%s' % (incentive, showdata))
            #     display(a0_df)
            #     display(a1_df)
    plt.show()
# Out:
# Do you think Amazon should be able to sell YOUR purchase data to other companies?
# Do you think companies should be able to sell consumer purchase data to other companies?
# Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?
# Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?
# Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?

# %%
# show same as above but in the other orientation
# by experimental arm

no_share_df = df[df['share']==0]
yes_share_df = df[df['share']==1]
for Q in data_use_Qs.keys():
    n_choices = len(data_use_Qs[Q]['choices'])
    print(data_use_Qs[Q]['Q'])
    fig,axes = plt.subplots(5,2,figsize=(2*5, 5*0.5*n_choices),sharey=True,sharex=True, dpi=150)
    plt.subplots_adjust(wspace=0.05, hspace=0.3)
    for j, incentive in enumerate(sorted(df['incentive'].unique())):
        for i, showdata in enumerate(['true','false']):
            ax = axes[j][i]
            a0 = no_share_df[(
                (no_share_df['showdata']==showdata) & (no_share_df['incentive']==incentive)
            )]
            a0_df = (a0[Q].value_counts()
                          .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
                          .to_frame(name='count'))
            a0_df['pct'] = (100*a0_df['count']/a0_df['count'].sum()).round(2)
            a1 = yes_share_df[
                ((yes_share_df['showdata']==showdata) & (yes_share_df['incentive']==incentive))
            ]
            a1_df = (a1[Q].value_counts()
                          .sort_index(ascending=False).rename(data_use_Qs[Q]['choices'])
                          .to_frame(name='count'))
            a1_df['pct'] = (100*a1_df['count']/a1_df['count'].sum()).round(2)
            width = 0.35
            a0_df['pct'].plot(
                kind='barh', ax=ax, color='black', edgecolor='black', 
                width=width, position=0, label='no share (n=%s)'%len(a0)
            )
            a1_df['pct'].plot(
                kind='barh', ax=ax, color='lightgray', edgecolor='black', 
                width=width, position=1, label='did share (n=%s)'%len(a1)
            )
            ax.set_xlabel('(%) percent')
            ax.set_xlim([0,100])
            ax.set_ylim([-0.5,(n_choices - 0.5)])
            ax.legend(facecolor='white', framealpha=0.95)#, loc='upper right')
            ax.set_title('%s; showdata:%s' % (incentive, showdata))
            #     display(a0_df)
            #     display(a1_df)
    plt.show()
# Out:
# Do you think Amazon should be able to sell YOUR purchase data to other companies?
# Do you think companies should be able to sell consumer purchase data to other companies?
# Big companies currently collect and sell consumer purchase data. Do you think that small businesses should be able to access this data for free in order to help them compete with the big companies?
# Do you think the U.S. Census Bureau should use purchase data to supplement their existing surveys?
# Do you think researchers should be able to use purchase data to understand societal changes (e.g. due to COVID-19)?

# %%
d = df[(df['incentive']=='control')&(df['Q-research-society']=='2')&(df['share']==1)]
d['Q-sell-YOUR-data'].value_counts().rename(data_use_Qs['Q-sell-YOUR-data']['choices'])
# Out:
# No                                 67
# Yes if I get part of the profit    24
# Name: Q-sell-YOUR-data, dtype: int64

# %%
d['Q-sell-consumer-data'].value_counts().rename(data_use_Qs['Q-sell-consumer-data']['choices'])
# Out:
# No                                         65
# Yes if consumers get part of the profit    25
# Yes                                         1
# Name: Q-sell-consumer-data, dtype: int64

# %% [markdown]
# # Comments

# %%
print('%s comments' % len(df['Q-comments'].dropna().values))
for c in df['Q-comments'].dropna().values:
    print('--------')
    print(c)
# Out:
# 410 comments
# --------
# I recently became part of the Amazon Vine Voices program.
# --------
# this was interesting
# --------
# None
# --------
# No
# --------
# those 2 gift cards for video games was when my account got HACKED. Never got a refund for them either. The mouse I got (the fancy one) got stolen and had to be resent. I usually use it for sending gifts.
# --------
# thanks
# --------
# I redacted my address, name, zip code, and credit card information from the excel sheet I sent in. I made sure to keep everything you said you needed for the survey. Thanks!
# --------
# I promise I'm not as freaky as my order history would suggest.
# --------
# none
# --------
# I hope I did this correctly!
# --------
# A bonus of like $1 or more would be highly appreciated compared to 5 cents
# --------
# pay a real bonus
# --------
# very annoying
# --------
# none
# --------
# I would have liked to have been presented with more questions about data sharing. Perhaps ones that contrast US policies with those in other countries, the EU for example.
# --------
# a most interesting survey with "food for thought" concerning consumer data and sales thereof.
# --------
# No.
# --------
# Sorry I took so long, for some reason the order report took forever. I removed my personal information from the CSV file.
# --------
# I have no idea if I'm in some outlier area. I have this feeling my history is some kind of outlier though. Which might impact my other feelings on this.
# --------
# I don't really feel comfortable with the fact that I shared this data. I am questioning whether I should have done it.
# --------
# thank you for including me in your research
# --------
# interesting questions!
# --------
# None
# --------
# No one should be able to sell or access anyone's data. I get this is the world we live in but I think it's a crappy thing to do.
# --------
# Very interesting study. Good luck with the research!
# --------
# thank you
# --------
# Thank you
# --------
# no comments
# --------
# none
# --------
# none
# --------
# I got to admit I hated that I actually had to share actual file with you and I have to just trust that you don't keep a copy? Seems shady. Cmon MIT, if I said I don't want to share why do I have to upload the file anyway? I guess I will just have to trust the MIT IRB on this one. Not happy about it though.
# --------
# Everything worked well, thank you
# --------
# Please don't use an all white background for the survey
# --------
# :)
# --------
# none
# --------
# honest opinion. If that data shows what happened during the pandemic and its for economical research, Im all for it. but on the versus for companies of any sort, big or small im not gonna budge. with internal data usage Amazon uses for Analytics, Im barely ok with that.
# --------
# Sorry for not giving consent to save my data, I'm wary of sharing it even anonymously. Good luck with your study! :)
# --------
# I thought the directions were very clear and easy to understand.
# --------
# None.
# --------
# The study basically forced me to share the data because the arrow key did not display when I checked do not share.
# --------
# A better answer is that big companies SHOULD NOT be able to sell consumer data, but since they are doing it anyways regardless, consumers should get some profit from their personal data being sold.
# --------
# Thanks for letting me help!
# --------
# I had a hell of a time uploading. I'm not sure what you were looking for in the excel, but when I left the information you said you were collecting, it wouldn't allow me to upload. I had to keep quite a bit of info and I was getting worried I'd need to either decline or give my very personal information. Luckily I found a medium where I could remove the personal addresses and emails but needed to keep a lot of the extra info you said you didn't need.
# --------
# Thank you
# --------
# For my answers where I think it should be allowed if people get part of the profit, I also think it should be 'opt-in' only.
# --------
# nope
# --------
# none
# --------
# Thank you!
# --------
# Do we have a deal?  1k?  Just kidding!
# --------
# no comments
# --------
# I have no additional comments to add at this time.
# --------
# None
# --------
# Our personal information is already too shared without our permission or knowledge.
# --------
# It would have been helpful to be able to explain why we think a small company should or shouldn't be able to see similar data in order to compete with big companies. I chose "no" only because I don't think they should access the information free of charge. If they pay for it, then they definitely should.
# --------
# Thanks!
# --------
# none- easy enough.
# --------
# none
# --------
# I appreciate the dark font
# --------
# I like it
# --------
# If companies ask my consent, remove my ID and pay me for my data, then they may use my data
# --------
# None
# --------
# My yes, no, and I-don't-know answers on the previous page were only tentative because I haven't yet thought about these issues thoroughly.
# --------
# Thank you for the survey. Please consider me for additional surveys.
# --------
# I didn't want to share my data because the file that came out had a lot more information in it than what was requested. I tried to remove the extra information, but then it didn't save for whatever reason.
# --------
# In the CVS Amazon Order History file, I only kept the information that was requested as needed, as to better protect my privacy. if that's not acceptable, let me know and I'll decide if I feel comfortable giving you the file has information that would link to me in the real world.
# --------
# None
# --------
# lol don't judge my amazon shopping
# --------
# none
# --------
# Thank you
# --------
# i KNOW IT HAPPENS( shared data) but it still makes me uncomfotable.
# --------
# the questions about selling data didn't really have any shades of grey so I wasn't able to say that I think that consumers should be able to opt in to sharing their data with companies instead of US privacy law right now which is pretty much opt out
# --------
# I hope you really don't use my purchase history as I did not consent to that!
# --------
# No comments
# --------
# It was fun
# --------
# None.
# --------
# no comments
# --------
# None
# --------
# none, tysm!
# --------
# none
# --------
# I edited out my personal data FYI.
# --------
# enjoy looking at the shit i bought i guess
# --------
# TOS Violation and will be reported to Prolific
# --------
# no
# --------
# Consumer consent and profit sharing should be implement if laws permit data to be sold. Thank you.
# --------
# thank you
# --------
# none
# --------
# Great study. Thank you.
# --------
# Interesting study thank you very much
# --------
# There was an issue with the survey when we were asked to either share or decline to share our data. You had to upload a file either way before you could proceed. I think it would have been better if the proceed button had been activated either by uploading and agreeing to share the data OR declining to share the data. It doesn't make sense to me to upload the data and then decline to share it.
# --------
# This took much longer than promised because of the report download process.
# --------
# I manually deleted rows / columns from the excel sheet.  I removed name / email and street address.  Please let me know if you have any questions.
# --------
# This was an eye opener & a little scary.
# --------
# No additional comments, thank you.
# --------
# None at all, thank you and godspeed MIT!
# --------
# none
# --------
# This is upsetting. In the 70's and 80's, nobody had lists of what people bought. I miss privacy.
# --------
# Thanks, Be well
# --------
# My name was on the download. Just curious, will that be deleted from your research along with any of my account information? I am a firm believer in research and want to help, but I'm sure you realize that I'm taking a risk with your honesty here.
# --------
# how much information am i giving out, i wonder a lot lately
# --------
# I want that $20 :)
# --------
# I wish I had the option to delete the columns with my name, address, method of payment, etc. before I uploaded the report.
# --------
# none.
# --------
# Pretty eye- opening seeing just how much we spent these last 4 years on Amazon. Wow!
# --------
# Good survey
# --------
# none
# --------
# I do work where I get Amazon gift cards, so much of my purchases show up as $0.Just FYI
# --------
# none
# --------
# In general, I feel privacy violations deserve compensation.  Regardless of the reason.
# --------
# I like the subject content and the length of the survey
# --------
# I’m a little nervous about sharing this data with you…
# --------
# None
# --------
# I don't know exactly how this works with Amazon, but I have been shopping with them since I was a college student for textbooks. I'm surprised only my most recent purchases came up for you.
# --------
# Thanks
# --------
# no
# --------
# Nothing to add thanks.
# --------
# Nothing
# --------
# You didn't mention that my credit card information was included in that file. I had to strip that out before uploading. I'm pretty sure this kind of violation of privacy is against Prolific's policies.
# --------
# Interesting study, thank you.
# --------
# n/a. Thanks!
# --------
# There were no issues.
# --------
# I answered 'maybe' to most sharing questions.  A differenciation wasn't made between sharing my data identifying me vs sharing deidentified data in bulk
# --------
# Enjoy my purchase list
# --------
# None
# --------
# none
# --------
# Go MIT!!
# --------
# My report took forever to download.
# --------
# Hi I hope this worked for you, Happy Thanksgiving
# --------
# Thanks
# --------
# none
# --------
# My answers of "yes but only if we get part of the profit" are only partly true. We also must CONSENT to our data being sold. If we get part of the profit but don't consent to our data being sold, then I disagree.
# --------
# The only reason I chose to share this personal data is because the researcher was MIT
# --------
# I did a lot of buying earlier this year (due to an international move in Dec, 2021), but that is exceptional. Stating this as an adjustment to my answer of 5 or less buys per month.
# --------
# Love being part of democratizing data!
# --------
# Interesting and thank you!
# --------
# Thanks. I think
# --------
# none
# --------
# idk if it matters but i deleted my address off the amazon sales history thing, i didnt change anything else and i left the state there for ya guys
# --------
# Thank you for the survey.
# --------
# What's the purpose of this study? Were you really going to use the data or just trying to see who would say yes?
# --------
# In had to upload a file, it would let me decline. I removed identifying info from the file I uploaded..
# --------
# Thank you for making the download instructions so easy to follow! Happy Thanksgiving!
# --------
# none
# --------
# Please adhere to your promise and do not share my information "willy nilly" and delete once you have finished your study.
# --------
# Someone stole my previous Amazon account and I was not able to get it back. I had to remake one in 2019.
# --------
# I think the ability/option to exclude certain categories/subsets of purchase data might be an interesting factor that could impact willingness to share, or even being able to obfuscate some data more than others (ie. sharing date of purchase for grocery items but only the month of purchase for supplements, or the full ASIN item number for electronics, but only the title/category for personal care). I also imagine people might prefer excluding certain categories entirely (underwear, personal hygiene, sexual health, etc.).
# --------
# add a progress bar
# --------
# Think I omitted any personal detail from the data file before uploading based on the requested data below the upload link. So it should be ready to go, it's just missing the unique responder ID.
# --------
# None
# --------
# Interesting
# --------
# none
# --------
# I need to stop spending so much money. Seeing that CSV was a real eye-opener into my spending habits.
# --------
# Jesus loves you
# --------
# Thank you!
# --------
# none
# --------
# none
# --------
# None
# --------
# No comments.
# --------
# I deleted some of the PII from my report but kept the specified data
# --------
# none
# --------
# I think a company can do whatever they want with most things they collect from a consumer, because we as a consumer choose to do our business there. That being said, I don't think it is right, but it just means I can choose not to shop there if it really bothers me and/or if companies do something terrible with it.
# --------
# Data is knowledge, and knowledge is expensive. I had multiple opinions on the previous page. Thanks!
# --------
# Thank you for the opportunity.
# --------
# Addendum to the questions about companies selling consumer purchase data - YES to profit sharing, only if 1. Personal information is kept anonymous and 2. Consumers are allowed to opt-in and opt-out.
# --------
# No
# --------
# Researchers should pay for access to a company's data like anyone else.
# --------
# I've been purchasing from Amazon from way before 2018, although I don't see any 2018 purchases on the download. I don't purchase frequently from Amazon, and try to avoid it now unless I've received a gift certificate.
# --------
# I'm the type of person that rejects sharing of data in TOS, and restricts permissions on their phone
# --------
# Fun and interesting study.
# --------
# The reason I did not consent to share my purchase data file is that, although you stated that only you were interested in only certain data from the file, the file contains personal information that would be included in the upload. Regardless of your intentions, I have no way to know how secure the data would be.
# --------
# Thank you for the survey and stay safe.
# --------
# thank you!
# --------
# :)
# --------
# None.
# --------
# I’m answering those questions assuming data would be aggregated as it was for the survey,
# --------
# Thank you for using my data responsibly.
# --------
# thank you
# --------
# I suggest potentially adding another choice to the questions about "should companies be able to use/purchase data": Only if the users opt in to an optional data sharing program.
# --------
# none
# --------
# I understand that you said you would strip out all identifying data, but I removed my name, email, and street address from the CSV file before uploading.
# --------
# None
# --------
# This was a cool and interesting survey
# --------
# This survey has major privacy issues with the data that is contained in the file I was asked to upload. I scrubbed it myself before doing so, but others may not know to do that. You should be able to decline sharing without uploading the file. I could not proceed with the survey declining without uploading the file. I will report this to Prolific.
# --------
# Interesting! Sorry I can't share it, looking at the file, it has my name and address and all kinds of information that I'm not super-comfortable with sharing!
# --------
# Nothing comes to mind.
# --------
# I stripped PII from the document - name, email, address, tracking number as it wasn't indicated that infor was needed for the study. Please feel free to reach out to me if that information is needed
# --------
# I deleted my name and address from the spreadsheet as you stated you didn't need that.  I kept the state.
# --------
# Not at this time.
# --------
# Interesting survey, I think companies should be able to sell purchase data so long as consumers get a part of the profit for every single other company to whom said data is sold!
# --------
# I have been using my Amazon account since before 2018 (I checked and I made purchases in 2017), I just happened to not make any purchases for a period of time. Since I had a functioning Amazon account during the whole time period, and I've made purchases on it at least occasionally over the entire time period, I count it as active. Apologies if this doesn't fit your definition of active and my data isn't good for this study.
# --------
# none currently
# --------
# They track our phones and all our devices with ads.  If something is free you're the product and even if it's not, there is bloatware and other ways for big corporations to infringe on privacy.
# --------
# None
# --------
# Thank you
# --------
# none
# --------
# I really enjoyed the survey and found it to be interesting and structured very well.
# --------
# That's an interesting study and I hope it gets put to good use.
# --------
# Interesting survey…
# --------
# na
# --------
# I am intrigued by the concept being floated around by some advocates of blockchain technology that an individual's data is their's first since they are responsible for its creation. In any event, an individual should receive some compensation from companies that wish to have access to their data.
# --------
# Enjoyed participating
# --------
# I haven't given much thought to who buys my purchase histories and who can access them.
# --------
# no
# --------
# To whom it may concern, I just wanted to say thank you for allowing me to participate in this study. Thank you.
# --------
# Thanks
# --------
# Since there's a lot of personal information, I deleted the unneeded columns from the spreadsheet.
# --------
# Thank you for the opportunity to take part in your research.
# --------
# none
# --------
# I have none.
# --------
# No comments.
# --------
# I couldn't open the downloaded file, so was less inclined to share than if I knew what was in it. Doubt there was anything super embarrassing. With all its data collection, why does Amazon keep showing ads for long-lasting items I have already purchased?
# --------
# You wont use or keep credit card data, correct?
# --------
# This is a big privacy violation. Completely shameful.
# --------
# Thank you!
# --------
# I deleted my personal info such as my name and address from the file - I did not feel comfortable sharing that.
# --------
# Hope the file comes through.  It is a LOT of data :- )
# --------
# Most of these items were gifts.
# --------
# no comments
# --------
# Help people like me get paid by companies for selling my data.
# --------
# Did remove some personal ID columns from my data
# --------
# none
# --------
# I think companies should ask permission before selling a person's shopping data. But I understand why businesses would want that data. It benefits them, but also benefits the consumers in the long run.
# --------
# People should have total control over their own data. I selectively removed the personal data from the data I sent you. No company should be able to sell anyone's personal data.
# --------
# none
# --------
# none
# --------
# Great study!
# --------
# I think I did it right. If I didn't just message me and I will do it properly
# --------
# Thanks
# --------
# i don't mind sharing browsing history with big companies but not purchases
# --------
# na
# --------
# Note that I recently was invited to join an Amazon program where I can order from a list of items and receive the items for free as long as I write reviews for most of the items.
# --------
# none
# --------
# Thank you
# --------
# Interesting and slightly odd survey.
# --------
# Thank you for the study, I answered honestly and to the best of my abilities.
# --------
# I don't believe Amazon is the most ethical company and so I try my very best never to buy from them which explains why I have so few purchases. Also I was asked if I do surveys on mturk; I said no but I have done some in the past but I am no longer active participant and I haven't for a long time now.
# --------
# Please don't judge my Amazon purchases LOL
# --------
# none
# --------
# I agree that small businesses should be able to if large ones can. But I don’t agree with the whole thing.
# --------
# i think a lot of it is about transparency. if companies communicated more instead of doing shaedy things
# --------
# I stripped most of the identifying info. The state is gone but it is Ohio.
# --------
# No comment.
# --------
# none
# --------
# none
# --------
# Interesting study!
# --------
# Redid the survey per researcher's request while uploading my file.
# --------
# Please don't laugh at my purchases
# --------
# None
# --------
# An interesting survey, thank you.
# --------
# I’d never thought of using purchase data for research by orgs that aren’t trying to sell something; I think it’s a really interesting idea
# --------
# Easy to complete, no errors, time estimate was accurate - thank you!
# --------
# I redacted some of the personal data from the spreadsheet.  Feel free to delete the bonus if this doesn't meet your criteria.
# --------
# I was initially opened to sharing but looking at the file there was just too much information, full name, address, last card digits. I didn't want to risk allowing it.
# --------
# I don't consent to my Amazon data being saved. Thanks.
# --------
# I think they should be able to sell data if it doesn't have any personally identifying information. Otherwise, no.
# --------
# none
# --------
# I really enjoy getting to participate in studies and I hope my responses are beneficial to the research.
# --------
# i'm curious what the objective of this survey is
# --------
# None
# --------
# Important research, we need to understand this shift.  Regarding role of Census, I am very ambivalent.  I am very familiar with Consumer Spending Survey.  It needs to be accurate but people also need to feel that they are benefitting directly from any data collected by the government.  Otherwise it just feeds into "deep state" storyline.
# --------
# Thanks
# --------
# none
# --------
# none
# --------
# Have a good day.
# --------
# Great survey
# --------
# Thank you for the interesting survey, and good luck with your research!  :)
# --------
# I wouldn't mind them using my data if they asked first, I could easily opt out of it, and I got a part of the profit.
# --------
# I hate capitalism
# --------
# thanks
# --------
# I enjoyed participation and wish you well with your research.
# --------
# I deleted data not requested from the Amazon download (i.e. name, address, etc), but left everything else
# --------
# Amazon is just another dirty, creepy, greedy compaany like all the rest.
# --------
# none
# --------
# i would have chosen to share, but looking at the file it has all of my information all of it
# --------
# nope
# --------
# No
# --------
# I redacted the name, email, shipping and payment information like Prolific tells us to do.
# --------
# none, thank you
# --------
# I said no to a lot of questions asking if I think they should have access or sell it, I would like to specify that it should be an option and consumers should be told directly about it before they decide.
# --------
# there is an entire industry selling data, and I use data in my business that I purchse, but do I want MY data sold?  Not really, but it happens anyway, and a lot can be learned with data.  I would just really like to know my data is completely anonomous - that is where my concern is.
# --------
# None at this time - Thanks!
# --------
# i don't know enough about the debate on the last few questions, but it's something Id be interested in learning about.
# --------
# No comments
# --------
# You have the option to decline to use data but still have to upload the file to continue in the survey. It should be changed because I feel like my data will be used anyways.
# --------
# I really do hope that the information you showed is all that you collected from my file :)
# --------
# I don't like sharing personal data. I hope that you will destroy the data that I shared, even though I declined to allow its use. We need to be more careful with data. My brother is a computer science professional, and he said never to hover over a FB link. So this made me nervous.
# --------
# It's good to define exactly what kind of research will be done and by whom.  In some cases, "researchers" are driven by profit motives. So in my mind who gets to use my data is important to me.
# --------
# Interesting survey. Thanks for allowing me to participate. Best wishes.
# --------
# Nothing much. Hope the data is helpful.
# --------
# I don't mind getting part of the profit, from *my* data, in this profit-driven, forsaken world we live in.
# --------
# I don't really think companies should be able to sell purchase data, but I also don't really have strong feelings about it. It doesn't seem to do material harm, but it does feel like a symptom of a capitalistic society that treats people like products. And it does feel like it further advantages already big corporations over smaller businesses.
# --------
# Just FYI, I did want to share my data for a .20 bonus but I accidentally clicked the wrong thing. Not sure if you can go ahead and use the data and send the bonus payment or not but I'm giving you my permission, if you can.
# --------
# Please be respectful with my data.
# --------
# Nothing else to add.  Thanks.
# --------
# I think consumers should be paid for their data being sold. Companies make so much money off this info.
# --------
# I do not trust you (or Amazon).  Before uploading, I deleted all the columns from the CSV file that I didn't want you to see.
# --------
# 100% do not believe anyone should make money off consumer data without explicit permission from the consumer in addition to fair compensation for that data, as well.
# --------
# you told me to take it again via prolific messages thats why you have two copies of my ID. You need to make it WAY clearer that if you decline you will not have the data uploaded. As is I am very uncomfortable with this
# --------
# None
# --------
# thanks
# --------
# None
# --------
# I think data sharing should be acceptable with explicit consent, not just in very long legal privacy and use agreement contracts that no one uses. Customers should be able to dictate to whom their data is sold or if they want to exclude certain companies from using their data. They should also be able to dictate why type and how much data is shared and share in the profits from that data if they so choose.
# --------
# None
# --------
# I think this survey raises very valid questions, and I definitely feel that selling consumer purchase data should only occur with explicit consent (beyond simply use of the platform/vendor, buried in ToS).
# --------
# none
# --------
# No additional comments at this time.
# --------
# none
# --------
# none
# --------
# great survey
# --------
# Well put together study!
# --------
# Data privacy is a huge issue. Honestly even uploading it to this survey makes me feel spooked as shit but i'm broke AF and need money to buy shit for people for xmas.
# --------
# na
# --------
# I do think companies are allowed to sell user data, because we are using their product or service. They already have the data what we do and do not do. Everyone has the power to avoid using the service if they don't like their data being sold. Although I do think its better for companies to ask us if we want our data to be sold to.
# --------
# I had no idea this information was being sold to other companies. I swear, doing anything online means having everyone knowing your business at all times pretty much. It’s sad that it’s even legal to be able to buy and sell so much information about people.
# --------
# Interesting study
# --------
# None
# --------
# You said I could decline, but the survey doesn't actually allow that. (The continue arrow doesn't appear if you don't upload a file and agree to share data.) Luckily I trust MIT, though this survey might change that a bit. Doing surveys has made me (an academic myself) pretty cynical about the practices at Research I institutions.
# --------
# I think that researchers and the census bureau should be able to get anonymized data, not personalized data
# --------
# None
# --------
# none
# --------
# Small companies have no use for consumer data. Making this data "available to small companies" seems like a false justification for sharing people's private data, just like serving a difficult to read privacy policy that allows such sharing of such private data.
# --------
# none
# --------
# Raw data doesn't always tell a whole story so I'm not sure how this data should be used
# --------
# Data should be private unless consent is given.
# --------
# I have cut back on purchasing from Amazon. I have only used it in recent months because of the holiday season approaching. I could take it or leave it.
# --------
# Define frequently when asking about alcohol
# --------
# Myself, like a lot of people, believe that if anyone is going to sell and be paid for my data it will be me. My data not some corp.
# --------
# none
# --------
# This was an interesting survey.
# --------
# None.
# --------
# I apologize for the time taken to complete the survey if it was longer than average I had my boyfriend's account open and had to go back and log into mine.
# --------
# Thanks!
# --------
# Interesting study.
# --------
# The report took longer than expected- it might be helpful to let participants know that they should wait 5 minutes or so. I almost reported it as an issue, then decided to give it some more time.
# --------
# None, thank you.
# --------
# thanks
# --------
# n/a - thanks!
# --------
# Companies have gotten by for hundreds of years without this data. There is no need for them to harvest our information for their benefit.
# --------
# none
# --------
# This study was interesting, thank you for allowing me to participate!
# --------
# NO
# --------
# None
# --------
# If I had just been asked for data for the last month or so, I'd feel more in control and more willing to share, but since 2018 just seemed too vast. I purchase too much on Amazon to feel comfortable with that.
# --------
# Data is very personal. The only reason I declined to share my data in this study is that names and addresses were included in the downloaded CSV file. No matter how much you, MIT, promises to not share this PII, slip-ups can and do occur. I don't want my name, the names of my family members, and our addresses attached to purchase data, circulated for all to see around the internet. If there was a way for you just to collect the purchase data without the PII inside of the file, I would be more apt to allow your team to share it. Thanks for the opportunity to inform your research, anyhow.
# --------
# The CSV that you request they download contains much more information that you're not asking for, specifically sensitive information.  Perhaps you could instruct users on how to remove your data.  To note, I downloaded my data and deleted data I deemed too sensitive (none of this survey's requested data was deleted/or modified), saved it and uploaded that new file. I hope this doesn't DQ me.
# --------
# Hey sorry this took so long to complete. I got distracted waiting for the download. Good luck with your research.
# --------
# none
# --------
# Thank you for the study!
# --------
# Interesting I would love to know more about the database if possible
# --------
# Very well done and very good job telling me how to do all this.
# --------
# I really hope you don't collect my data even though I declined. I find it odd that I had to upload it to continue.
# --------
# The only thing I think that I would add is people, even if they choose to share the data for a portion of the profit, should be told exactly what portion that will be prior to accepting.  For example I don’t think a company making 90% of the profit and giving customers 10% of the profit would be acceptable to me. I believe the customer should receive the greater portion of the profit from that sharing and I believe that should be disclosed immediately when you are asked for permission. I mean I don’t think it will ever happen that way because I think for some customers you mention profit and they go “OK!” Whereas I would want to know what that profit would be how much they would share and if any personally identifying information would be included. If I didn’t have full disclosure on that I would automatically check no. I’m clarifying that because I said that on the survey but there would be some parameters under which I would not agree and since I only had a checkbox I couldn’t make that clear. So I would say possibly allow an explanation Other than just “yes”, “no” or “ yes, if I receive a portion of the profits” in order to understand completely a customers perspective on this. Thank you for the opportunity to participate in the study. Happy New Year!
# --------
# I do believe that data SHOULD be sold but ONLY WITH CONSENT of the consumer. Whether the consumer wants to be paid for the data or not, companies should not have the right unless stated in terms of service to sell data unknowingly.
# --------
# interesting, had no idea I could have access to this form
# --------
# Thank you
# --------
# I didn't know I could download this information, so I learned something today! Thank you for the opportunity.
# --------
# none
# --------
# This was very fun. Thank you so much and happy new year!!!
# --------
# Thank You.
# --------
# Interesting research!
# --------
# I removed my personal information from the file that I uploaded.
# --------
# In a few cases, had it been available, my answer might have been "maybe, with my informed consent"
# --------
# Super interesting study, best of luck!
# --------
# I don't agree with companies sharing data, If I could avoid them i would however it's not easy to know.
# --------
# I downloaded the report, it contains all thesensitive information including my name, address, email. That's way too much info, so I will not share it.
# --------
# I only declined to share after seeing personal data on the report. I tried to delete some of the columns that I wasn't comfortable sharing (credit card, shipping address, etc), but it wouldn't let me upload that version to you so I had to decline.
# --------
# Interesting survey
# --------
# Very interesting study!
# --------
# Good luck with your research!
# --------
# I was willing to share my data but was not comfortable sharing my address information and removed it from the excel sheet before uploading. Hopefully what was included is/was enough.
# --------
# No comments
# --------
# all my answers were my initial gut feeling but im not 100% more like 70%
# --------
# I removed my name & street address before uploading the file.  Also, it would help to expand the time allowed to get this all done.
# --------
# I try not to use amazon very much so I don't think I have much on there
# --------
# I am re-submitting this study. Thank you for your quick reply! I wish you luck with your research!
# --------
# no
# --------
# none
# --------
# While you offer the opportunity to decline the submission of purchase info, there is no way to continue in the survey without it nor are directions provided to circumvent the system to move on. That said, I submitted the information to continue after going into the report itself and deleting most of the data not listed as being required from the report. I understand that as research studies cannot release personalized data without consent (I have a background working with IRBs in the past), the fact that things could move forward at that one point in the collection of data (i.e., the submission of the report), weakens the integrity of what is being done. Something to consider for the future and indeed, this may impact your data if others feel the same as me.
# --------
# Thanks!
# --------
# cool study
# --------
# Thanks!
# --------
# None
# --------
# Please respect my privacy and not share my data
# --------
# I've made regular amazon purchases since 2018 but I switched accounts. It only lets me upload one report so thats what I did. If you would like me to return please message me, I would like to avoid a rejection at all costs.
# --------
# Obviously I don't totally object to selling data because I participate in paid surveys, but I think companies should have to be more transparent about selling your data and pass some of that profit to the people they are profiting off.
# --------
# thank you
# --------
# Those are tricky questions and I don't know who has the answers...
# --------
# i declined to share data since I'm also a vendor w/a product line on amazon. just makes me a little uncertain to do that as a result (p.s. my dad got his undergrad degree & PhD at MIT)
# --------
# Please add me to future surveys.
# --------
# I lived in New Hampshire last year. I was just unable the make that selection when asked due to a technical glitch.
# --------
# This was an interesting study in that I didn't realize the value of the kind of information about me that could be sold, but I'm glad that I was presented with this information. :-)
# --------
# if I get paid for consent than, fpr the most part, I will participate!  chances are, is that this stuff is already happening...
# --------
# Thanks for your time, I appreciate it.
# --------
# None
# --------
# I don't have any comments. Thanks.
# --------
# No comments
# --------
# thank you
# --------
# no
# --------
# I would have shared my data had my address not been part of it. Just FYI!
# --------
# Thanks for the opportunity to participate.
# --------
# Please do not access the Amazon data. I am trusting you, researcher!
# --------
# none
# --------
# None at this time.
# --------
# My opinion on companies sharing data would be influenced on exactly what data they would be sharing.
# --------
# Thank you!
# --------
# Good luck!
# --------
# No problems.
# --------
# I took out names, card numbers, and addresses just to be safe
# --------
# I would have shared my shopping report except I couldn't figure out how to remove my address and payment information
# --------
# thank you
# --------
# I sanitized my report to remove names and emails.
