# %% [markdown]
# # Prescreen preprocessing
#
# Raw prescreen data is private. We preprocess to output a public version.
#
# The preprocessing does:
# - Deduplicates by Prolific/Worker IDs (there could have been some multiple submissions)
#
# - Merges survey datasets across Qualtrics prescreen surveys
#
# - Merges Qualtrics data with Prolific demographic data
#
# - Inserts column indicating data source & survey version
#
# - Strips out Prolific / Worker IDs and separates comments from IDs (for privacy)

# %%
from datetime import date
import os

from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

PROLIFIC_PARTICIPANT_ID = 'PROLIFIC_ID'

data_path = r'../../data/prescreen-survey/'
input_data_path = data_path + 'raw/'
output_data_path = data_path

# %% [markdown]
# ## Qualtrics survey data
#
# There were multiple versions of the survey.
#
# A mapping of column ID to question is saved in an output 'fields' csv file.
#
# We merge survey data into one file.

# %%
# Set up reading in the data files

cloudresearch_name = 'qualtrics-prescreen-cloudresearch'
v1_name = 'qualtrics-prescreen-v1'
v2_name = 'qualtrics-prescreen-v2'

# %% [markdown]
# ### Handle the fields and values mappings
# Save the fields

# %%
# Example to show intuition of what this looks like
input_fname = input_data_path + 'qualtrics-prescreen-v1.csv'
df = pd.read_csv(input_fname)
df.drop(['PROLIFIC_PID', 'Q-prolific-ID'], axis=1).head()
# Out:
#                   PASS_PRESCREEN                 FAILED_ATTN_CHECK
# 0                 PASS_PRESCREEN                 FAILED_ATTN_CHECK  \
# 1  {"ImportId":"PASS_PRESCREEN"}  {"ImportId":"FAILED_ATTN_CHECK"}
# 2                            NaN                              true
# 3                            NaN                               NaN
# 4                           true                               NaN
#
#                                         RecordedDate
# 0                                      Recorded Date  \
# 1  {"ImportId":"recordedDate","timeZone":"America...
# 2                                2022-11-01 14:49:05
# 3                                2022-11-01 14:50:03
# 4                                2022-11-01 14:51:21
#
#                         Q-requirements-1
# 0  Do you have an active Amazon account?  \
# 1                   {"ImportId":"QID90"}
# 2                                    Yes
# 3                                    Yes
# 4                                    Yes
#
#                                     Q-requirements-2
# 0  Have you been making purchases on your Amazon ...  \
# 1                               {"ImportId":"QID91"}
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#                                       Q-attn-check-1
# 0  Since you have made purchases on your Amazon a...  \
# 1                              {"ImportId":"QID108"}
# 2                                                Yes
# 3                                                NaN
# 4                                                 No
#
#                                     Q-prolific-mturk
# 0  Do you also complete surveys (or HITs) using A...  \
# 1                              {"ImportId":"QID107"}
# 2                                                NaN
# 3                                                NaN
# 4                                                 No
#
#                                      Q-mturk-account
# 0  Is the Amazon.com account that you use to comp...  \
# 1                               {"ImportId":"QID96"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q-attn-check-2
# 0  The following question is very simple. When as...  \
# 1                              {"ImportId":"QID109"}
# 2                                                NaN
# 3                                                NaN
# 4                                                 No
#
#                                           Q-comments    Duration (in seconds)
# 0  Thank you for participating.\n\nComments? (opt...    Duration (in seconds)  \
# 1                          {"ImportId":"QID48_TEXT"}  {"ImportId":"duration"}
# 2                                                NaN                       19
# 3                                                NaN                       10
# 4                                                NaN                       28
#
#                  ResponseId
# 0               Response ID
# 1  {"ImportId":"_recordId"}
# 2         R_V4kBfIAJNlFM7Kh
# 3         R_1FmFw7Ov1Cu784g
# 4         R_2VDWJck9MB1JQTu

# %%
print('Extracting and saving mapping of column keys to semantic values')

for name in [cloudresearch_name, v1_name, v2_name]:
    print('\n%s:' % name)
    input_fname = input_data_path + name +'.csv'
    output_fields_fname = output_data_path + name + '-fields' + '.csv'
    df = pd.read_csv(input_data_path + name +'.csv')
    fields_df = df.loc[0].rename('value').to_frame()
    display(fields_df)
    # Save fields
    print('saving to %s' % output_fields_fname)
    fields_df.to_csv(output_fields_fname, index_label='column')
# Out:
# Extracting and saving mapping of column keys to semantic values
#
# qualtrics-prescreen-cloudresearch:
#                                                                    value
# connect                                                          connect
# PASS_PRESCREEN                                            PASS_PRESCREEN
# FAILED_ATTN_CHECK                                      FAILED_ATTN_CHECK
# RecordedDate                                               Recorded Date
# Q-worker-id                                      What is your worker ID?
# hitId                                                              hitId
# assignmentId                                                assignmentId
# Duration (in seconds)                              Duration (in seconds)
# ResponseId                                                   Response ID
# workerId                                                        workerId
# Q-requirements-1                   Do you have an active Amazon account?
# Q-requirements-2       When did you start using your current Amazon a...
# Q-attn-check-2         The following question is very simple. It is a...
# Q-followup-study       This is a pre-screen for another study that re...
# Q-comments             Thank you for participating.\n\nComments? (opt...
# saving to ../../data/prescreen-survey/qualtrics-prescreen-cloudresearch-fields.csv
#
# qualtrics-prescreen-v1:
#                                                                    value
# PASS_PRESCREEN                                            PASS_PRESCREEN
# FAILED_ATTN_CHECK                                      FAILED_ATTN_CHECK
# RecordedDate                                               Recorded Date
# Q-prolific-ID                                   What is your Prolific ID
# Q-requirements-1                   Do you have an active Amazon account?
# Q-requirements-2       Have you been making purchases on your Amazon ...
# Q-attn-check-1         Since you have made purchases on your Amazon a...
# Q-prolific-mturk       Do you also complete surveys (or HITs) using A...
# Q-mturk-account        Is the Amazon.com account that you use to comp...
# Q-attn-check-2         The following question is very simple. When as...
# Q-comments             Thank you for participating.\n\nComments? (opt...
# Duration (in seconds)                              Duration (in seconds)
# ResponseId                                                   Response ID
# PROLIFIC_PID                                                PROLIFIC_PID
# saving to ../../data/prescreen-survey/qualtrics-prescreen-v1-fields.csv
#
# qualtrics-prescreen-v2:
#                                                                    value
# PASS_PRESCREEN                                            PASS_PRESCREEN
# FAILED_ATTN_CHECK                                      FAILED_ATTN_CHECK
# Q-prolific-ID                                   What is your Prolific ID
# Duration (in seconds)                              Duration (in seconds)
# RecordedDate                                               Recorded Date
# ResponseId                                                   Response ID
# Q-requirements-1                   Do you have an active Amazon account?
# Q-requirements-2       When did you start using your current Amazon a...
# Q-attn-check-2         The following question is very simple. It is a...
# Q-followup-study       This is a pre-screen for another study that re...
# Q-comments             Thank you for participating.\n\nComments? (opt...
# PROLIFIC_PID                                                PROLIFIC_PID
# saving to ../../data/prescreen-survey/qualtrics-prescreen-v2-fields.csv

# %% [markdown]
# ### Handle the survey data
#
# When dropping duplicates, keep the last.

# %% [markdown]
# #### v1

# %%
v1_df = (
    pd.read_csv(input_data_path + v1_name + '.csv')
    .drop([0,1]) # First 2 rows are Qualtrics metadata
    .drop(['PROLIFIC_PID'], axis=1)
    .rename({'Q-prolific-ID': PROLIFIC_PARTICIPANT_ID}, axis=1)
)
print('%s rows of data' % len(v1_df))
print('columns:', list(v1_df.columns))
# v1_df.head()
# Out:
# 416 rows of data
# columns: ['PASS_PRESCREEN', 'FAILED_ATTN_CHECK', 'RecordedDate', 'PROLIFIC_ID', 'Q-requirements-1', 'Q-requirements-2', 'Q-attn-check-1', 'Q-prolific-mturk', 'Q-mturk-account', 'Q-attn-check-2', 'Q-comments', 'Duration (in seconds)', 'ResponseId']

# %% [markdown]
# #### v2

# %%
v2_df = (
    pd.read_csv(input_data_path + v2_name + '.csv')
    .drop([0,1]) # First 2 rows are Qualtrics metadata
    .drop(['PROLIFIC_PID'], axis=1)
    .rename({'Q-prolific-ID': PROLIFIC_PARTICIPANT_ID}, axis=1)
)
print('%s rows of data' % len(v2_df))
print('columns:', list(v2_df.columns))
# v2_df.head()
# Out:
# 17411 rows of data
# columns: ['PASS_PRESCREEN', 'FAILED_ATTN_CHECK', 'PROLIFIC_ID', 'Duration (in seconds)', 'RecordedDate', 'ResponseId', 'Q-requirements-1', 'Q-requirements-2', 'Q-attn-check-2', 'Q-followup-study', 'Q-comments']

# %% [markdown]
# Merge Prolific data

# %%
v1_df['version'] = 'v1'
v2_df['version'] = 'v2'
prolific_df = pd.concat([v1_df, v2_df]).sort_values('RecordedDate')
print('%s total rows of Prolific data' % len(prolific_df))
# prolific_df.head()
# Out:
# 17827 total rows of Prolific data

# %%
# Drop duplicates: Keep the last
print('Dropping %s duplicate prolific IDs' % (len(prolific_df) - len(prolific_df.drop_duplicates(PROLIFIC_PARTICIPANT_ID, keep='last'))))
prolific_df = prolific_df.drop_duplicates(PROLIFIC_PARTICIPANT_ID, keep='last')
print('%s remaining rows' % len(prolific_df))
# Out:
# Dropping 359 duplicate prolific IDs
# 17468 remaining rows

# %%
# Drop invalid IDs
print('Dropping rows with invalid prolific IDs (length != 24)')
prolific_df = prolific_df[prolific_df[PROLIFIC_PARTICIPANT_ID].apply(lambda s: len(str(s).strip()) == 24)]
print('%s remaining rows' % len(prolific_df))
# Out:
# Dropping rows with invalid prolific IDs (length != 24)
# 17464 remaining rows

# %% [markdown]
# #### Cloudresearch

# %%
cloudresearch_df = (
    pd.read_csv(input_data_path + cloudresearch_name + '.csv')
    .drop([0,1]) # First 2 rows are Qualtrics metadata
    .drop(['hitId', 'assignmentId', 'workerId'], axis=1)
)
print('%s rows of data' % len(cloudresearch_df))
cloudresearch_df['version'] = 'cloudresearch'
# cloudresearch_df.head()
# Out:
# 4508 rows of data

# %% [markdown]
# Drop rows with bad worker ID value.

# %%
# Remove anything with test
cloudresearch_df = cloudresearch_df[cloudresearch_df['Q-worker-id'].apply(lambda s: not 'test' in str(s))]

# %%
# What should we expect from a worker ID? A given length.
print('Worker id length')
print(cloudresearch_df['Q-worker-id'].apply(lambda s: len(str(s).strip())).describe().round())
cloudresearch_df['Q-worker-id'].apply(lambda s: len(str(s).strip())).value_counts().head(6)
# Out:
# Worker id length
# count    4505.0
# mean       22.0
# std         9.0
# min         3.0
# 25%        14.0
# 50%        14.0
# 75%        32.0
# max        44.0
# Name: Q-worker-id, dtype: float64
# Q-worker-id
# 32    1927
# 14    1903
# 13     620
# 12      19
# 24      12
# 20       4
# Name: count, dtype: int64

# %%
# Remove any without expected length
expected_lengths = [12,13,14,32]
print('dropping worker ids without length in', expected_lengths)
def expected_length(s):
    return len(str(s).strip()) in expected_lengths
cloudresearch_df = cloudresearch_df[cloudresearch_df['Q-worker-id'].apply(expected_length)]
print('%s remaining rows' % len(cloudresearch_df))
# Out:
# dropping worker ids without length in [12, 13, 14, 32]
# 4469 remaining rows

# %%
# Drop any duplicate worker IDs
print('Dropping %s duplicate worker ids' % (len(cloudresearch_df) - len(cloudresearch_df.drop_duplicates(['Q-worker-id']))))
cloudresearch_df = cloudresearch_df.drop_duplicates(['Q-worker-id'])
print('%s remaining rows' % len(cloudresearch_df))
# Out:
# Dropping 37 duplicate worker ids
# 4432 remaining rows

# %% [markdown]
# ## Merge Cloudresearch and Prolific data

# %%
prescreen_df = pd.concat([prolific_df, cloudresearch_df])
print('%s rows for merged prescreen data' % len(prescreen_df))
# Out:
# 21896 rows for merged prescreen data

# %%
# Remove rows with test in the comment
prescreen_df = prescreen_df[prescreen_df['Q-comments'].apply(lambda s: not 'test' in str(s))]
print('%s rows after removing tests' % len(prescreen_df))
# Out:
# 21892 rows after removing tests

# %% [markdown]
# ## Prolific demographic data
#
# Merge demographic data exports from prolific

# %%
prolific_demos_fname_prefix = 'demos-export-prolific-prescreen-'
prolific_demo_export_files = [input_data_path+f for f in os.listdir(input_data_path) if f.endswith('.csv') and prolific_demos_fname_prefix in f]
print('%s prolific demographic data export files to read' % len(prolific_demo_export_files))
sorted(prolific_demo_export_files)
# Out:
# 9 prolific demographic data export files to read
# ['../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v0.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v1.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v2.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v3.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v4.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v5.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v6.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v7.csv',
#  '../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v8.csv']

# %%
demos_df = None
for fi, fpath in enumerate(sorted(prolific_demo_export_files)):
    ddf = pd.read_csv(fpath)[[
        'Participant id',
        'Age', 'Sex', 'Ethnicity simplified', 
        'Country of birth', 'Nationality', 
        'Student status', 'Employment status'
    ]].rename({
        'Participant id': PROLIFIC_PARTICIPANT_ID,
    }, axis=1)
    print('%s: %s participants for file %s' % (fi, len(ddf), fpath))
    demos_df = ddf if demos_df is None else pd.concat([demos_df, ddf])

print('%s total rows' % len(demos_df))
demos_df.drop([PROLIFIC_PARTICIPANT_ID], axis=1).head()
# Out:
# 0: 10 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v0.csv
# 1: 406 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v1.csv
# 2: 5785 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v2.csv
# 3: 514 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v3.csv
# 4: 7887 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v4.csv
# 5: 926 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v5.csv
# 6: 2166 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v6.csv
# 7: 61 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v7.csv
# 8: 52 participants for file ../../data/prescreen-survey/raw/demos-export-prolific-prescreen-v8.csv
# 17807 total rows
#                Age              Sex Ethnicity simplified Country of birth
# 0  CONSENT_REVOKED  CONSENT_REVOKED      CONSENT_REVOKED  CONSENT_REVOKED  \
# 1               35             Male                White    United States
# 2               28             Male                Other    United States
# 3               27             Male                White    United States
# 4               35             Male                White    United States
#
#        Nationality   Student status Employment status
# 0  CONSENT_REVOKED  CONSENT_REVOKED   CONSENT_REVOKED
# 1    United States              Yes      DATA_EXPIRED
# 2    United States               No         Full-Time
# 3    United States     DATA_EXPIRED      DATA_EXPIRED
# 4    United States     DATA_EXPIRED      DATA_EXPIRED

# %% [markdown]
# Drop potential duplicate participant ids.
#
# Which we keep/drop from the Prolific demo data shouldn't matter

# %%
print('dropping %s duplicate participant ids' % (len(demos_df) - len(demos_df.drop_duplicates([PROLIFIC_PARTICIPANT_ID]))))
demos_df = demos_df.drop_duplicates([PROLIFIC_PARTICIPANT_ID])
print('%s remaining rows' % len(demos_df))
# demos_df.drop([PROLIFIC_PARTICIPANT_ID], axis=1).head()
# Out:
# dropping 354 duplicate participant ids
# 17453 remaining rows

# %% [markdown]
# ## Merge in Prolific demographic data
#
# Note this will leave many rows without demographic data

# %%
prescreen_df = prescreen_df.merge(demos_df, how='left', on=PROLIFIC_PARTICIPANT_ID)

# %% [markdown]
# #### Handle comments
#
# As per the IRB protocol, comments connected to survey participants are not published. They are removed from the cleaned data but printed below disconnected from participant IDs.

# %%
comments = prescreen_df['Q-comments'].rename('comments').dropna()

# %%
print('%s comments:' % len(comments))
for c in comments.to_list():
    print('"%s"'%c)
# Out:
# 1714 comments:
# "I do have an active amazon account, I just misclicked. "
# "This was stupid. I abhor having to lie to qualify for a stupid survey like this."
# "Thanks for the invite!"
# "Thanks for the opportunity to participate "
# "I have been making 4+ years of purchases my apologies"
# "No"
# "thanks for the opportunity"
# "this was great. "
# "none"
# "No"
# "I do have a Mturk profile up and running, but I prefer Prolific by a long shot.  The ethics of Mturk HITs are questionable at best and Prolific does a much better job of ensuring the quality of data."
# "I inadvertantly selected 'No.' I do have an active Amazon account. Sorry!"
# "Hope you are having a beautiful day!"
# "None. Thank you."
# "I hope this is a study about how Amazon flagrantly violates the privacy of mturk workers."
# "Sorry i do have an Amazon account "
# "Thanks!"
# "Thank you!"
# "Thank you!"
# "Thank you."
# "no."
# "I accidentally hit no instead of yes and couldn't go back :("
# "No comments."
# "I used a family member’s Amazon account until recently."
# "Just to clarify:  I use the same password.  I do have to sign into the accounts eparately."
# "nice attention checks. I hate buying stuff off of Amazon. My mturk account is OLD. I've been doing mturk for years. 1.6 million hits approved and counting. It's been useful for my lifestyle."
# "na"
# "If I could sign into my Amazon account on my phone and answer questions for you on my laptop I would, but for security I won't click links asking me to sign into anything. "
# "Thank you"
# "To my knowledge, my MTurk and Amazon accounts have nothing to do with each other!  Different websites and logins."
# "none"
# "everything was clear and easy to understand."
# "no"
# "to personal"
# "What I saw logging onto Amazon was not one of your choices.  Good luck!"
# "No but thank you."
# "i dont like my amazon account too much. i always recieve late packages and their  prices are high and they treat employess bad .h "
# "I have no additional comments."
# "No comments"
# "This seems like a way to access someone's account and feels un"
# "good luck with your research"
# "It's kinda sketch to ask people to login to an account outside of Prolific for this survey."
# "I don’t feel comfortable signing into my account through any external link, sorry. "
# "none"
# "Not sure what you were wanting "
# "Great"
# "Thanks"
# "none"
# "I am just wondering how much the other survey pays. Thanks!"
# "I had no idea that was a thing ."
# "I logged in via my phone and could not get my Amazon to show that page "
# "No"
# "Amazon!"
# "Great short study"
# "Participated in MTurk when it first began = mot in the lst 10 years"
# "No thanks "
# "thanks"
# "thanks"
# "na"
# "Thanks for letting me participate!"
# "no"
# ":)"
# "Actually when i went to my account>my order, the space after that is just blank so the question doesn’t have valid answer"
# "none. I only trusted this because it is MIT :)"
# "n"
# "I'm pretty sure the violates TOS. "
# "No."
# "None."
# "none"
# "No, good luck "
# "No additional comments -- thanks!"
# "none"
# "Worried about my privacy"
# "No"
# "What was with the Mturk questions? Were you attempting to exclude people who might have (potentially) taken your survey on Mturk already?"
# "no"
# "no comments"
# "Thanks for the opportunity."
# "N/a"
# "Thanks for this"
# "Thank you for the chance to help with this study "
# "Having someone sign into their account Amazon account to do a survey on Prolific is suspect. "
# "thank you"
# "thank you"
# "none"
# "NONE"
# "no"
# "n/A"
# "no"
# "Good luck with your research! :)"
# "none"
# "Forgot password "
# "This was a pleasant survey.  Hope to continue participating!"
# "I hope my data will not be compromised."
# "The MIT logo was huge and took up the whole page and the survey questions were really small on the bottom of the screen "
# "thanks"
# "no issues"
# "None "
# "Thank you"
# "none"
# "nope"
# "none"
# "none"
# "Might be interesting... Thanks for doing this."
# "Thank you!"
# "none"
# "I like Amazon"
# "Thanks for the opportunity to participate, good luck with your research and stay safe!"
# "Thank you for your time"
# "no problems"
# "Interesting! Good luck w/ the study!"
# "I appreciate the dark font"
# "Easy and entreating survey"
# "I love amazon I shop online all the time I would love to do this study thank you so much."
# "-"
# "Thank you!"
# "Sorry not interested in logging into my Amazon "
# "I only use the app, so I couldn't see the website link."
# "no comments"
# "The page that is linked is not functioning "
# "not sure if i did something wrong? or right? it says ORDER HISTORY REPORTS  though lol"
# "That is not what my page looks like. US? Tp the right of those on mine is Cart. "
# "none"
# "none"
# "Thanks!"
# "I have no additional comments to add at this time."
# "None at this time"
# "Thank you for the opportunity. I can't wait to participate if I'm chosen!"
# "when is the main study? "
# "Took me a bit to find my log in info so It took a little longer to finish the last part of the survey"
# "none"
# "no"
# "no comment"
# "Thank you "
# "I’d love to join your study! I’ve been using Amazon and Prime for over at least 12 years, probably more. I just checked and my impact score is 20,000, and I have written 56 reviews; I love Amazon and shop there constantly. Regardless of your decision, thanks for the opportunity!"
# "Thank you."
# "I hope to be invited to the main study"
# "No comments"
# "This study is very nice."
# "Did not feel comfortable clicking an unknown link."
# "Thank you"
# "Thanks."
# "thanks"
# "Thanks"
# "What are you gonna use the data for?"
# "thank u"
# "Not logging into my account through this"
# "I would log on to my Amazon account but I don't want to access my account through a link you provide. I don't feel safe about that. "
# "cool"
# "I have been using amazon since 2007 and prime for over 5 years at least."
# "Everything went fine with no issues"
# "It was interesting"
# "thank you"
# "na"
# "no comments"
# "You better be paying significant amounts of compensation for the information you're planning on getting from these reports. This is a massive violation of privacy regardless of what information you claim you'll be keeping vs. deleting."
# "Thank you"
# "Great study. Thank you."
# "Thank you"
# "No"
# "none"
# "I am concerned about privacy issues -- who will be looking at my Amazon account information."
# "I try not to use Amazon at all but keep my account open in case I need to refer to past purchases."
# "none"
# "I have Amazon but don't pay for Amazon Prime"
# "no comments"
# "Thank you for allowing me to take part in your study."
# "Thank you"
# "Easy! Looking forward to the follow up study"
# "Curious what that was for honestly."
# "no comments, happy Thanksgiving to you and your family "
# "No"
# "I have had an amazon account for years but even tho I am a sole proprietor it is listed as a business account so the page you wanted me to find looks different.  But I have a real account!"
# "None at this time "
# "i don't want to give you access to my amazon account, super sketchy"
# "add a progress bar to the survey"
# "No additional comments, thank you."
# "Everything was clear, thank you."
# "none"
# "Interesting survey! Would love to participate in the follow up study! "
# "no"
# "Thank you"
# "Awesome study! "
# "Pretty simple"
# "None."
# "Thanks"
# "No comments"
# "None! :) "
# "None."
# "I had no clue this page existed...or even what it's for...and I have had an account, and been a Prime member, since June of 2014. !!!"
# "Nope"
# "no"
# "na"
# "I would prefer that you don't use Google Drive as holding your Consent to participate in research.  Google likely combines the IP address of the participant with their known information, and this forces any participant who wants to do your study in having Google know that they have done this study. "
# "none"
# "Too many problems with studies that require even second-hand account access"
# "no"
# "Thanks!"
# "Good offer"
# "None "
# "Do you now have access to my Amazon account?"
# "Seems suspicious sorry"
# "Thanks for letting me participate and thanks for adding to our body of knowledge. :)"
# "Holy asking for personal info"
# "marry me!"
# "Good survey"
# "nothing"
# "none"
# "no"
# "My phone lagged and I submitted the wrong answer and now it won't let me go back. I have an Amazon account and have used it for many years."
# "I did not know about the Order History Report!"
# "I am not giving any access to my personal account. Thank you"
# "Good luck"
# "Thanks"
# "Thanks for the opportunity to participate!"
# "had me worried there for a moment when you said i had to log into my account like this is how they scam my account"
# "No"
# "I want to participate. My amazon page doesn’t have that info. Is it because I use amazon smile so that my purchases support a charity?"
# "Thank you for the opportunity to engage in this survey"
# "Thank you."
# "cowabunga dudes"
# "Thanks"
# "I have no additional comments."
# "none"
# "Nothing to add thanks"
# "Thanks "
# "Thank you for this opportunity!"
# "Thank you for allowing me to participate!"
# "None. Thank you. "
# "Nothing I can think of."
# "n/a. Thanks!"
# "Thank you for this opportunity!"
# "I picked the wrong answer. It was order history reports! Sorry "
# "Keep up the good work"
# "Thanks"
# "This isn’t worth my privacy "
# "none"
# "Go MIT!!"
# "I clicked the wrong option and can’t go back"
# "No comment "
# "Id love to be able to participate in this study"
# "The study os nice."
# "The study os nice."
# "There were no issues. "
# "Maybe it would be have been better if you mentioned that we'd have to sign in to out Amazon account in your initial invitation (before clicking on it). Maybe I am still qualified for the first part though? Thanks."
# "looking forward to the study"
# "should tell actual time to do study, not 1 min and then take 5"
# "'=)"
# "I hope the next study doesn't involve any tracking by some app of yours. "
# "Hmmmm"
# "Your welcome"
# "Thanks!"
# "It was blank after "Your orders" "
# "None, thank you "
# "no"
# "Just one question?"
# "none"
# "Thanks!"
# "No comment "
# "Hope you have a wonderful day! :)"
# "No"
# "No comments"
# "No comments. Thanks."
# "Seems sketchy"
# "none"
# "none"
# "Good survey."
# "No"
# "Good survey"
# "N/A."
# "Logging into my account via your link gives you my account information..I think. You don't say go to your account in another browser window so it seemed a bit suspicious. Sorry I couldn't complete survey"
# "No"
# "Thanks for the opportunity. "
# "I have another account that I used pre-2018 but I had to switch accounts to receive another student discount. "
# "I Think I may have been making purchases sine 2018 but I know I have since 2019"
# "No comments"
# "fun stuff thank you"
# "Thanks! "
# "Can't allow access to my account"
# "No"
# "No comments."
# "No."
# "Have a nice day!"
# "Thank you for the survey and stay safe."
# "no"
# "The information was clearly presented and the questions were easy to understand.  Also, there were no technical errors. Good luck with your research."
# "none"
# "None."
# "Thank you "
# "Thanks for such an easy study"
# "none"
# "none"
# "Nope"
# "link went to business analytics/reports"
# "My home web page using chrome displayed differently than the page you provided. I had to access my orders to see what would come next or fill in the blank you provided."
# "No comments at this time. Thank you! Have a great weekend!"
# "Thanks for the opportunity!"
# "It is possible that I’ve had an Amazon account back in 2018, but I just can’t remember "
# "Thanks. Interested in future participation."
# "none"
# "Na"
# "Made Amazon account in 2018 but didn't start using it until 2020"
# ":)"
# "Thank you for the opportunity. "
# "none"
# "Thank you for the survey opportunities, have a great day..Looks Like I have been using Amazon.com since 2017 and going strong as I love Amazon and Get 98 percent of my orders from them."
# "crazy to request someone log into an account for a survey"
# "No thank you."
# "I was getting delivery before the pandemic, 2018 I think or 2019. I had Amazon Prime with the free videos in 2018 or before actually but only started receiving grocery delivery in 2019."
# "good study"
# "thank you.. This sounds interesting and i'm looking forward to doing this survey"
# "no comments thanks for asking though ;)"
# "Not at the moment. "
# "Nope"
# "i do not trust signing in or giving access to my private accounts"
# "Thank you "
# "Should we be worried about privacy?"
# "jesus loves you"
# "Purpose?"
# "N/a"
# "great study"
# "Thanks"
# "None at this time - Thanks!"
# "have a great day!"
# "this study seems like a privacy risk"
# "none"
# "thank you"
# "Thank you for the opportunity!"
# "no comment"
# "My samsung smartphone did not want to display this page in a mobile site. It kept forwarding me to the amazon app"
# "I am an Amazon Prime member. I order from Amazon at least twice a month."
# "Everything was good, thank you!"
# "Good survey "
# "Have a great day and thanks for the possibility of this opportunity! 😬"
# "Amazon has gone too WOKE!  Closed to non-woke books.  Amazon is very closed minded."
# "I used the link and got to the page, but the area from the screenshot was not there."
# "No"
# "Hope I get in the next round."
# "none thank you"
# "I hope to complete the full survey soon, if possible!"
# "no, thanks"
# "Thank you!"
# "Look forward to follow up surveys. Thanks "
# "No comments"
# "Nah"
# "None, thank you"
# "Easy!"
# "privacy concerns"
# "none"
# "no"
# "What if we sign in to Amazon on app? "
# "none"
# "610aaf651f5e36d3a76b199f"
# "Thank you"
# "none"
# "Thank you!"
# "Sorry I do have an Amazon account however I have been wondering if I should close it since I don't use it very much."
# "I went to the "M.I.T. of the West Coast", Eastern Washington University. But in our case, it stands for the "Michigan Institute of Trucking". 😜"
# "I can access that place and data but if you're asking me to share purchase data, then that should be up front in the requirements here and I'll consider it.  Thank you"
# "none"
# "Worried about privacy/"
# "I feel you will have a hard time getting info if you have someone use your link to log into a personal account. That is why I chose not to."
# "Jesus is King"
# "Nothing comes to mind. "
# "Great survey "
# "Great!"
# "Thanks."
# "I would like to participate in the follow up survey"
# "Thanks for allowing me to participate! Have a great day!"
# "For whatever it's worth, I will NOT be willing to forward an order history.  You don't mention this, but given the page you had us load, I presume you will."
# "The study was easy to follow and understand. "
# "No comments "
# "We love Amazon!"
# "Must be different on mobile site"
# "I hope to be a part of this study."
# "none"
# "I use Amazon to buy things, but I do NOT have a prime account."
# "none"
# "not sure what this is about"
# "none"
# "I meant to click yes "
# "No comments."
# "none"
# "none"
# "thank you"
# "Thanks for the study."
# "I will be happy to participate. Thanks."
# "Seems sketchy"
# "none"
# "I was hesitant to click the link, perhaps include a disclaimer that the link is safe for people to click"
# "no"
# "Interesting!"
# "Pretty straightforward. Thanks for the opportunity to inform your research. "
# "Privacy event "
# "It'd be nice to know more about how much personal information we need to provide before we take the next survey to judge whether or not we want to paricipate. If I just need to have access to the page for experience sure I'll do that. May be more wary if you're asking me to send you files. "
# "No"
# "Thank you"
# "N/a"
# "none"
# "Good luck on the study!"
# "I do have a amazon account i hit hit the wrong button "
# "knowing the pay for the other study would be helpful for future recruitments "
# "none"
# "it seems unsafe to give your amazon account information"
# "no"
# "Thank you for the survey, I answered honestly and to the best of my abilities."
# "good survey"
# "thank you"
# "Easy to complete, instructions were clear, no errors encountered. Time estimate accurate, thank you. "
# "Great study!"
# "I joined Amazon when they first started as a bookseller. I order almost weekly from them. Customer service told me I've made more than 2,200 purchases on Amazon.com!"
# "No"
# "Very short and easy survey."
# "Quick and simple, thank you."
# "looking forward to it!"
# "My cats name is spungle "
# "I've been a Prime member for several years."
# "I hope I haven't just been hacked somehow."
# "Hope I get selected for a longer survey, I have an active aged Amazon account that I shop with all the time. :)"
# "thanks"
# "No"
# "personal info required, nope"
# "no"
# "Look forward to participating."
# "none"
# "it shows stuff from 2016 and 2017, so I am not sure what that means"
# "Amazon account since 1997!"
# "Everything went fine; thank you for the opportunity."
# "Not really. What was that about? I thought it was a survey. "
# "I would be uncomfortable signing in to a website that has my address and payment info for a survey"
# "I look forward to participating. Thank you!"
# "I got B2B"
# "no comments"
# "Thank you"
# "No comments, thank you, and have happy holidays and new year."
# "thanks"
# "To whom it may concern, I just wanted to say thank you for allowing me to participate in this study. Thank you."
# "Thank you! "
# "Too personal for the pay. "
# "Thank you for letting me participate! "
# "no comments"
# "Nothing comes to mind thanks."
# "Link was in a different language. "
# "none"
# "Thank you for your time "
# "I hope I'll be able to participate, but if not, thank you for your kindness"
# "Hope you have a good day"
# "No"
# "weird"
# "I rarely make purchases on Amazon or anything that involves physical delivery since all that is handled by my parent."
# "I enjoy getting to participate in these studies."
# "It was really short"
# "Uncomfortable entering my Amazon password"
# "Thank you"
# "This is super sketchy"
# "no?"
# "People's online accounts are personal information"
# "none"
# "none"
# "Short and sweet"
# "Everything went well."
# "Did you run this study once before?"
# "Thanks"
# "No."
# "It seems kind of suspicious"
# "FUCK JOE BIDEN"
# "I have nothing to add here"
# " Peace"
# "I accidentally clicked the wrong option. I meant to click yes."
# "cool!"
# "I love Amazon and use Amazon prime a lot"
# "I just don't want to enter a confidential website as part of a survey. All the best with your research."
# "none"
# "thank you"
# "I don't do things for studies that involve personal online information."
# "No."
# "Keep up the good work."
# "no"
# "I was going to open a separate link to get to that site. Not signing in my amazon account through a link that could get my password. "
# "Just spent $300 on Amazon today!  I live there."
# "No comments."
# "Thank you. "
# "Enjoyable survey. Survey was clear and understood."
# "Thank you"
# "None, thanks 👍"
# "Love shopping on Amazon I literally did all my Christmas shopping there this year"
# "Thank you!"
# "none of the above. I see "Your Account > Your Orders""
# "no"
# "My wife has an Amazon account and she orders all of our stuff through Amazon. We also have Amazon prime TV"
# "Nothing to add, thanks."
# "Have a good day."
# "Na"
# "No"
# "none"
# "I don't want to login to my account"
# "no"
# "Look forward to main survey!"
# "No "
# "none"
# "Nothing else to put down really.  Thanks for the opportunity to take the survey."
# "I don't think I have data in this section of my Amazon account"
# "No comments really.  Love shopping at Amazon!"
# "It was neat that I can access a history of my orders and create a report. I was unaware of this feature."
# "Works for me"
# "No"
# "I enjoyed participating and wish you well with your research."
# "thanks"
# "No"
# "none"
# "great"
# "None at this time"
# "My Amazon account page did not have the same information as the survey"
# "Nothing at the moment.. "
# "I use amazon a lot."
# "I would love to do more surveys like this!"
# "None."
# "I didn't want to log into my Amazon account."
# "Thank you "
# "none"
# "thanks"
# "Nothing further.  Thank you."
# "im unclear on what you are going to ask of us information wise. i dont want to give you access to my full purchases?"
# "none"
# "I didn’t have anything like that on my amazon account. and I can screen shot for proof that I wasn’t lying "
# "none"
# "I would love to help you and work hard for your study! "
# "Nothing."
# "Thanks"
# "THANKS"
# "good study"
# "None, thank you"
# "no"
# "No"
# "not interested to share personal info."
# ":)"
# "Thank you"
# "This is collecting personal information "
# "I love Amazon."
# "I don't trust signing into Amazon via a random survey. "
# "Cool"
# "Thanks!"
# "Thanks "
# "Thank you this study was user friendly."
# "No"
# "War Eagle"
# "Thank you for the opportunity to participate in your research."
# "None, quite yet... "
# "Thank you for the opportunity and Happy Holidays!"
# "Fun"
# "Nothing further to add. Thank you."
# "Best of luck with your research!"
# "None."
# "nice"
# "Merry Christmas!! "
# "Good luck with your research data collection. Publish in the best journal possible.  "
# "NA."
# "Thank you "
# "nah"
# "Thanks guys"
# "I answered when did I started using Amazon account in 2020 but that is incorrect. I started using Amazon in 2018"
# "Thank you"
# "mmm a bit dodgy"
# "okay"
# "interesting"
# "None "
# "I hope this wasn’t some scam to get me to login to my Amazon so some scammer can make purchases using my information. This was a weird survey. It only wanted me to login to my Amazon account through some link and that was it???"
# "no comments"
# "No additional comments at this time."
# "thanks "
# "No comments"
# "I do not want to share my amazon history. I am sorry"
# "Thank you"
# "good survey"
# "none"
# "thank you"
# "I have no comments at this time."
# "Thank you!"
# "no"
# "asking too much to do for such little pay out"
# "I don't fill safe giving you access to see my amazon account"
# "none"
# "Nope!"
# "n/a - thanks!"
# "I'm not comfortable signing in to a third party account through this site. Sorry."
# "none"
# "I would want to know if I need to share my orders or personal info before doing it"
# "thank you"
# "Thanks!"
# "i clicked the wrong button. i have an active account and have had since the onset of Amazon"
# "Thank you for the study, I enjoyed answering all questions with integrity to the best of my ability. I look forward to future studies with you giving and entering honest opinions."
# "No comment. "
# "Thank you!"
# "Happy Holidays"
# "There was not another line after your account/your orders on my order page. You did not offer a choice for nothing after your orders."
# "Will people be notified when the regular study is happening?"
# "No"
# "no"
# "These days I shop online with whomever packages their products the best. Tired of broken items just tossed in a box without bubble wrap, etc. "
# " "
# "Not at this time, thank you"
# "all good. "
# "none"
# "Thanks for the very quick study, have a wonderful Christmas!"
# "none"
# "Sounds like this might be an interesting study. "
# "interesting study"
# "No"
# "No"
# "none"
# "It isn't my own account, we share it with my in-laws"
# "You should be aware that not all amazon accounts will have the "Order History Reports" thing there. When I first tried I was signed in with my enterprise account for my organization, and the page is dramatically different and does not have that header. I only figured it out when I switched to my personal amazon account."
# "Have a nice day!"
# "I use amazon app and it said your orders and also your list"
# "OMG I MEANT TO PUT YES THIS IS SO SAD"
# ":)"
# "hi"
# "ok"
# "none."
# "Mobile was allowed on this survey - I have an Amazon account and will be able to verify. I was not able to find the answer you were looking for because the mobile app isn’t set up that way. Thank you"
# "good"
# "None of the answers completely matched "
# "A bit sketchy to make us sign in"
# "Good luck!"
# "thank you"
# "I wish I could have participated using the Amazon app on my mobile device instead of having to log in through my browser "
# "Thank you for allowing me to participate!"
# "I am definitely curious about the study!"
# "This is a scammy way to get people to participate and you should reconsider how you conduct research."
# "There's no way i'm going through a third party site to literally sign into my personal amazon account which contains all sorts of personal information including payment information."
# "That is a pretty tricky task you guys have.  Almost gave up up"
# "Thank you for the study!"
# "have a good day"
# "did not want to access amazon account for study"
# "The screenshot looked nothing like my Amazon account. I have a business account: There's no breadcrumb navigation at all, it just goes to my business analytic reports. "
# "I use my account often but not from this device."
# "5b97386d8e5b7b00010e1a8e"
# "none"
# "None, thank you."
# "Everything seemed to work fine for me."
# "Thank you for the opportunity!"
# "none"
# "my amazon page didnt show an additional tab only "your account" and "your orders""
# "I'm not logging into a personal account to do a survey."
# "ive had older accounts but they deactivate if you havent ordered anything"
# "Your link wants my password and I don't trust it. I wanted to access the link by signing in first myself and it won't allow me to do that"
# "This was the pre-screening?"
# "I am too concerned about being phished to participate, but good luck with your research!"
# "Nothing that comes to mind."
# "Wait I clicked the wrong button- I do have Amazon! "
# "I have none, thanks"
# "I have a business account. It pulled up business analytics. Not sure if that's a different thing than what you were looking for. Best of luck!"
# "I'm not opening my Amazon account on this site."
# "No"
# "What is the purpose of that random link? I was suppose to fill in the blank at the bottom, but what does this link have to do with Account > Orders. It's rather confusing."
# "I am not condors clicking on links that want me to log into accounts where i have credit card numbers saved. "
# "No thanks "
# "None! "
# "Thank you"
# "I look forward to the opportunity! Thank you very much and happy 2023!"
# "rock on baby beaver"
# "Good luck wih your study! Happy New Year!"
# "None at this time."
# "Your welcome!"
# "Thanks for having me "
# "Thank you "
# "none"
# "This ended soon.  Did I do something wrong?"
# "Thanks!"
# "Thanks! "
# "I hope I can do the follow up survey!"
# "Thank you for the chance to participate "
# "Thank you"
# "Thank you! Happy new year :)"
# "So far, so good..."
# "Very interesting prescreen "
# "easy to do "
# "none"
# "no"
# "I've had an Amazon account since 2013."
# "I can't access my account because the link brings me to my Amazon AMALfi account. Thanks for the opportunity "
# "My account didnt have anything after my orders. "
# "Didn't want to share personal info "
# "Thank You."
# "thanks "
# "Please say before hand about signing into my Amazon account."
# "That was easy, trying to save money for the 14 things waiting in my cart!"
# "Easy"
# "I am not comfortable signing into my Amazon account from a third party link."
# "Thank you"
# "No comments"
# "I feel this is a privacy issue to log into my Amazon account through your link"
# "I have had the account since 2018, but looking at my archived orders, the first I have listed is 2019. Also, if you are looking at purchase behavior during and after the pandemic, mine would be a really good example of how it developed, I used amazon exclusively. "
# "too much personal info needed"
# "Thank You!"
# "I definitely had to check my Amazon account to check and it was 2020 when I first made a purchase! :)"
# "Thanks for the opportunity to participate. Best of luck with your research!"
# "Good Study!"
# "None."
# "None."
# "sorry, it's 'Order History Reports' I have zero idea why I looked at it and said your reports, when I double checked I was wrong."
# "My Amazon business app opened so it wasn't the same as shown"
# "none"
# "I closed my account due to  unauthorized purchases"
# "I doesn’t look like that through my phone. FYI "
# "Pick me! "
# "I forgot my password to my amazon account"
# "no, nothing to add"
# "all good"
# "Good luck!"
# "None, thank you."
# "none"
# "Was unsure about the safety of opening up my account from the previous link. "
# "No"
# "You are requesting information that I consider private."
# "none"
# "Thank you"
# "Getting too personal"
# "Thank you"
# "na"
# "Thank you!"
# "Thank you."
# "Nothing to add"
# "Not comfortable signing in, seems unsafe and not protecting my data"
# "None at this time. Thank you!"
# "thank you"
# "didn't want to give out information"
# "Not willing to provide personal information per Prolific guidelines."
# "I am not comfortable with signing into my amazon account for this purpose."
# "weird"
# "Thanks?"
# "Curious what the study wants with this imformation"
# "I have no additional comments."
# "None at this time"
# "maybe I'm just paranoid, but it's a little suspicious for us to have to link our amazon accounts with our credit card info for your survey. I dont know if yall have thought of that yet. "
# "Thanks"
# "Thanks for this opportunity and your time."
# "Thanks -- hope to participate."
# "Thanks!"
# "i'm not signing into my account via a link,  sorry.  It's not safe or wise to do.  I was interested in the study up to that point. "
# "No comments"
# "thanks"
# "Thanks! "
# "Haven’t purchased at all recently "
# "Asking people to click a link to sign into an account with personal information is against Prolific tos. Or it should be. "
# "No comment"
# "Thank you!"
# "no"
# "Pick me"
# "Thanks for the offer but it is too invasive."
# "could ask if we have prime"
# "No additional comments, thanks!"
# "Thank you"
# "."
# "none"
# "nothing to report"
# "No"
# "I'm concerned about privacy if selected for the follow-up study."
# "Interesting study. Looking forward to the next "
# "no comments"
# "No"
# "Apologies, anything that is personal information I feel uncomfortable with. Thank you"
# "I am not interested in logging into any account that contains payment information."
# "Sign me up. Let’s do this !"
# "Thank you."
# "should say on the screener on prolific you need to sign in to your amazon, felt a bit shady..."
# "No way am I sharing my Amazon history."
# "Just not interested in providing my data. Good luck"
# "No"
# "no"
# "I work for Amazon and refuse to buy from them. You need to make it clear what sort of account you mean"
# "Nope"
# "Don't want to link personal information to any studies."
# "Order history reports will be unavailable after March 20, 2023"
# "Amazon had a note about order history reports ending 2/20"
# "Looking forward to participate in this study"
# "Have a great day!"
# "No comments"
# "?"
# "Requiring amazon log in may be violating Prolific's anonymity rules"
# "Thanks!"
# "no"
# "Thank you"
# "none"
# "Thank you "
# "Everything was fine"
# "Asking for personal info. "
# "no"
# "no"
# "THANK YOU "
# "No"
# "Thanks"
# "Thank you!"
# "Cannot access the link yhrough the app, i don't feel like changing my password for this"
# "Thank you!"
# "na"
# "This does not appear to be a link that appears within my Amazon Account.  I suspect that it would provide MIT the ability to examine my account, and that would violate my privacy."
# "none"
# "Thank you for the opportunity."
# "none"
# "No"
# "none at this time"
# "afraid this study would capture by amazon passcode"
# "Great survey, no issues."
# "no"
# "Thank you!"
# "no"
# "none"
# "Thanks"
# "No"
# "I like the study! Tks!"
# "ask me to log into my amazon account, im not willing to do that "
# "Thank you."
# "is this a phishing scam?"
# "none"
# "Thank you"
# "thank you"
# "No everything goes well."
# "I Love Prime, Jesus Loves You"
# "Thanks, but I will pass."
# "Thank you."
# "none"
# "Easy enough can't wait for the invite for the study thank you"
# "Thanks."
# "Since this is a business amazon account they are using 'Business analytics dashboard' graph reports page "
# "It says "Order History Reports will be unavailable after March 20, 2023""
# "Thank you "
# "When I went to the amazon page, I noticed that it says that order history reports will be unavailable after March 20th. Will this affect your research at all?"
# "Don’t like signing into Amazon account with a link like this"
# "My amazon account did not show anything after your orders but underneath it was all the orders I have recently placed so I chose history "
# "Nope "
# "It’s my wife’s account. I will tell her to do study "
# "Thank you "
# "KP"
# "No, none."
# "none"
# "No"
# "Thank you for allowing me to participate!"
# "nope"
# "I am not willing to open any account that may provide access to my ordering and payment methods."
# ":P"
# "Nice. Thanks."
# "thank you"
# "none "
# "Thank you"
# "Thanks for the opportunity"
# "Thanks :0"
# "Seems interesting. Thank you!"
# "I enjoyed this survey. Thank you!"
# "no"
# "No comments."
# "Am I screened out because I have not account on Amazon?  I do use my daughter's all the time."
# "I did not feel comfortably singing into Amazon through that link "
# "I DO HAVE AN AMAZON ACCOUNT, I ACCIDENTALLY PRESSED NO"
# "no"
# "no"
# "No comments, it is a straight forward pre-screen. All the best to you at MIT!"
# "Sorry I won't sign into my personal accounts for any studies because I did that once before and was hacked no study should require anyone to do that. Now if they do follow through it's because they themselves have an Amazon dummy account that's not their main account."
# "I hope that any information I provide from my Amazon account will be confidential. "
# "Order History Reports will be unavailable after March 20, 2023"
# "On the page I was asked to navigate to on Amazon, there is a banner saying "Order History Reports will be unavailable after March 20, 2023""
# "no thank you"
# "Sorry"
# "No"
# "none"
# "The state of Wyoming only has two escalators."
# "The site does not open on mobile as described.  "
# "No comment"
# "Thanks! "
# "No willing to sign in to my Amazon account through your link."
# "The page is telling me that 'Order History Reports will be unavailable after March 20, 2023'; I hope this doesn't disrupt your research"
# "Interested to see what the follow up is about."
# "Actually the answer was "Your Orders" an option not given. "
# "none"
# "Thanks"
# "none"
# "sorry, for privacy reasons I don't want to log into my amazon account as part of a study"
# "none"
# "Very clear"
# "Just in case you didn't see, it says "Order History Reports will be unavailable after March 20, 2023.""
# "no additional comments"
# "Thank You"
# "none"
# "It seems weird to sign into my Amazon account like it’s maybe a scam sorry."
# "none"
# "This site triggers repeated security errors on my device. Shady?"
# "Can't live W/O Amazon"
# "none"
# "none"
# "NONE"
# "no"
# "Sad "
# "I didn't notice any errors or typos and had no issues at all, thanks!"
# "thank you"
# "Account showed: Your Account › Your Orders and nothing else. My order history did show though"
# "none"
# "Didn't get to finish"
# "There is a very large orange disclaimer that this feature will end after March 20th"
# "I didn't have any problems. Thanks!"
# "None."
# "Thanks!"
# "no comments"
# "interesting"
# "none"
# "I dont feel secure entering my user name and password to get into my amazon account through this study"
# "none"
# "thanks"
# "Thank you but I do not feel comfortable signing into my account from a link"
# "Thanks!"
# "No"
# "No comments"
# "i was clicking too fast and assumed the "yes" button was on the top... apparently not.."
# "Order history reports was after Your Account>Your Orders"
# "nope"
# "The password I always use for that website would not work on this link."
# "It also reads: "Order History Reports will be unavailable after March 20, 2023""
# "No, thank you."
# "none"
# "Amazon is telling me that order history reports are going to be unavailable soon. "
# "no thank you"
# "No. "
# "I'm a little nervous about following a link to enter my password several times."
# "thanks"
# "Thank you!"
# "no"
# "I don't trust a link to my Amazon from a survey, sorry."
# "Check out Boy Hero"
# "none"
# "none"
# "nada"
# "Everything worked as intended! Thank you so much for the opportunity! "
# "Interesting Survey.  Thank you for the opportunity to participate."
# "none"
# "None."
# "it was fun to do thanks for the opportunity"
# "Unclear instructions on the question "
# "N/A thank you for the survey!"
# "Great website, very easy to navigate"
# "Thank you!"
# "I don't wish to sign into a personal account while doing a survey. Thank you"
# "Very easy exercise."
# "It was a good survey"
# "simple but good"
# "thank you"
# "Order History Reports will be unavailable after March 20, 2023."
# "I'm not sure if you are allowed to do that. Are you trying to hack my account? "
# "Nothing further. Thank you so much and I hope you have a wonderful day!"
# "idk if it matters but the top of the page has a warning "Order History Reports will be unavailable after March 20, 2023""
# "Have a nice day :)"
# "I don't want to give access to my account."
# "No"
# "Only comment is that survey was very short!"
# "I didn’t see anything pop up next to Your Orders but the page it takes me to is my order history "
# "Nothing to note."
# "NONE, THANK YOU"
# "FYI, Amazon has a notice at the top of that linked page that says it will no longer be available after March 20,2023, so you only have a couple weeks left to use it for the study screener!"
# "Nothing "
# "Thank you for the opportunity!"
# "Looking forward to more!"
# "This doesn't feel safe to me, sorry."
# "it says the reports will be unavailable after march 20"
# "Does Amazon business account count?"
# "No, thanks."
# "Thank you for the opportunity. "
# "No comments"
# "How do I know if I'm eligible?"
# "None!"
# "Thanks for the fun and easy survey. I really enjoyed it."
# "My Amazon page says that I will no longer be able to access these reports after March 20th, just FYI"
# "I assume this wasn't a scam, but I still didn't want to log into my account..."
# "Easy peesy "
# "I applied to MIT for the 2023-2024 school year!"
# "thank you"
# "Found this there as a warning by Amazon "Order History Reports will be unavailable after March 20, 2023""
# "Thank you :)"
# "can’t tell if i got selected or not "
# "Make an answer for the app?"
# "Why"
# "“Track and Manage Your Orders” was the following statement after following the steps of this study, but it wasn’t an available option."
# "none"
# "Pretty sure part 2 is in violation of prolific terms of service. "
# "Nope."
# "No."
# "The headings you asked about don’t appear when using the mobile app, or when using the website when it is adapted for mobile use."
# "Thank you"
# "My page also says Order History Reports will be unavailable after March 20, 2023"
# "Sorry, I didn't realize I was going to have to potentially connect my Amazon account. "
# "I do not feel comfortable giving access to my Amazon account."
# "Thanks"
# "5d9ce1981ecfd60012ccca92"
# "I am interested in follow up participation"
# "no"
# "I picked the wrong one, it was supposed to be Order History Reports"
# "Thank you!"
# "none"
# "Seems fine"
# "Thank you"
# "No comments"
# "None."
# "Just so you know the page says: Order History Reports will be unavailable after March 20, 2023"
# "If you expect me to send you a list of everything I've ever bought on Amazon then please don't consider me for the follow up study."
# "Order History Reports will be unavailable after March 20, 2023"
# "I see that order history will no longer be available after March 20.  Very disappointing!"
# "At the top of my Amazon Order History Reports page, there is a text box stating that Order History Reports will no longer be available after March 20. Just FYI in case you are requesting that or related info for the study."
# "Will not sign into personal accounts for a survey."
# "thank you!"
# "none"
# "This survey should mention a need of an amazon account so the appropriate people may click on it."
# "thank you for the study"
# "no"
# "None."
# "No way I'm going to log into my account via your link. "
# "I also see, "Order History Reports will be unavailable after March 20, 2023""
# ":)"
# "it was a pain to login"
# "ty"
# "No, thanks"
# "Order History Reports will be unavailable after March 20, 2023"
# "Suspicious about having me sign in while this study is open. Seems like it could be a method for a criminal to gain access to our passwords."
# "No please."
# "no"
# "Good luck with the study!"
# "No comment"
# "PLEASE ACCEPT ME INTO MIT PLEASE"
# "It's against ToS to require sign in as it breaches the personal information rules. "
# "Thanks for your time!"
# "none"
# "Order History Reports with be unavailable after March 20 2023?! Wow..."
# "Actually, none of those options appeared, but I did access that page."
# "it says this page will be unavailable after march 20 "
# "Thank you!"
# "to much info in my amazon account"
# "Everything went smoothly"
# "Order History Reports will be unavailable after March 20, 2023 is on that page"
# "I did not not sign in through your link, but through another tab. How do we know that you are really MIT?"
# "My page said order history reports will be unavailable after March 20th, 2023"
# "Thanks always buying from Amazon "
# "none"
# "I consider my privacy"
# "insightful study"
# "Thank you"
# "na"
# "Good survey"
# "The webpage tells me the link this screener had me to go will no longer be available after March 20, 2023 in case you need to update anything in your study."
# "Your attention check violated Prolific policies. Do better."
# "A message says Order History Reports will be unavailable after March 20, 2023"
# "No comment."
# "none"
# "none"
# "didnt see anything next to your orders"
# "Didn't really trust the whole link thing, but get it how you live."
# "i wish therr was competition for amazon   they have a hold on the industry too much there needs to be more competion and there should be at least 2 other big business retaulers like amazon for competion   amazon has the markeyt by the balls"
# "good luck with your research "
# "na"
# "I chose to be selected out because I am unsure about the security of my personal information. Unclear what information would be collected in actual servey."
# "no"
# "It doesn't actually say anything there when you navigate to that page."
# "I will not give my amazon account info to you people. That is disgusting you sked that."
# "peace"
# "none"
# "it says the reports will be unavailable March 20th"
# "Thanks"
# "Have a great day!!"
# "I don’t want to log into my amazon account for strangers"
# "Thank you"
# "na"
# "None :)"
# "When I went to that page, I got a note that "Order History Reports will be unavailable after March 20, 2023" -- hopefully you can get your study done soon!"
# "None at this time"
# "Pre-screeners should not have Attention Check questions. Prolific guidelines do not allow them"
# "You should not be asking for our personal information. This would include seeing anything about our Amazon accounts. Please check the Prolific guides. Thank you."
# "Hard to answer that question because on mobile the Amazon page looks different "
# "interesting"
# "I only have regular Amazon, not Prime."
# "none"
# "no"
# "I miss clicked. I do have an amazon account"
# "thanks!!"
# "Prolific surveys should not require logging into external accounts."
# "no"
# "none for now - looking forward to the study!"
# "The man waved at me on the Amazon website. "
# "No"
# "none"
# "You're welcome "
# "Going to the link at the end of the screening gives me a warning, "Order History Reports will be unavailable after March 20, 2023""
# "i have an Amazon account. I pressed the wrong button i’m very sorry. "
# "Thank you."
# "Thank you"
# "Very interesting study...again what exactly are you trying to find/learn from this study? If people pay attention or follow specific instructions is it how many ppl have an Amazon account "
# "I may have signed up for this study in the past"
# "None "
# "none"
# "short survey"
# "Thanks for the opportunity!"
# "no comments at this time"
# "A little weird asking someone to sign in to their Amazon account"
# "I also got this message: Order History Reports will be unavailable after March 20, 2023"
# "Thank you for the survey and God Bless!"
# "none"
# "Take care."
# "none"
# "none"
# "Thank you for the survey!"
# "No comment"
# "thanks!"
# "none"
# "sounds fun thanks for thinking i might help with your studies"
# "Directions were easy to follow."
# "hope I qualify "
# "thanks."
# "nope"
# "fast so fast im confused lol "
# "Thanks"
# "Thank you."
# "no"
# "Good luck"
# "none"
# "I have had an amazon account for many years but I use it extremely rarely. I think my last purchase was in 2019. I don't know if I qualify or not"
# "not comfortable copy pasting a strange link"
# "I share and Amazon account with family."
# "No comments"
# "No"
# "Thank you"
# "Thanks"
# "nah"
# "You should also ask about etsy/shein/etc!"
# "None at this time."
# "Thank you!"
# "im not logging into my personal Amazon account "
# "I have used this account since 2020 but had an account prior i got locked out of and wasnt able to retrieve. I have had amazon account since 2003"
# "All good!"
# "It says Order History Reports will be unavaliable after March 20th so I hope that's not actually relevant to the study."
# "Per Amazon; Order History Reports will be unavailable after March 20, 2023"
# "noope"
# "None i can think of, thank you"
# "Thank you"
# "N/a"
# "I was uncomfortable opening the URL yet, survey being an MIT, I chose to risk it while still being uncomfortable doing so. "
# "You shouldn't be asking people to sign into personal accounts. It's a security risk and against Prolific guidelines. "
# "No"
# "The format for my account may have been different than the wording of the survey due to it being a US account and/or on my mobile phone when I accessed it."
# "It shouldnt require people to log into their amazon accounts through a link. Very sketchy"
# "I have multiple Amazon accounts, including sharing one with my relatives"
# "Amazon states that order history reports will no longer be available after 3/30. Better hurry with this study. "
# "Amazon says "Order History Reports will be unavailable after March 20, 2023" if that's going to mess with your data collection"
# "Thank you."
# "No problems."
# "Nope"
# "Thanks "
# "Website says order history reports will not be available after 3/20/23"
# "No"
# "I do have an Amazon account, I didn’t mean to click “no”."
# "NONE"
# "Apparently they're suspending Order History Reports on March 20 so I'd like to do this asap if qualified."
# "The Amazon page says the order history reports will be unavailable after 3/20/23"
# "none"
# "Have a great day!"
# "No"
# "no"
# "Sorry I am not comfortable logging in my amazon account."
# "Interesting potential study."
# "it would be cool if you gave directions for how to access it in the amazon app"
# "Good luck with your study!"
# "No"
# "When I clicked on the link it kept taking me to a business analytic page. I'm assuming its because I have a business account, but either way the "account > your orders > ___" thing was nowhere on the page. I wasn't sure what option to put because none of them fit this situation so I just educated guessed based on what I saw. "
# "The page I went to also says the reports won’t be available after March 20, 2023. "
# "I'm confused, I definitely have been using Amazon for years but Order History Reports is in fact what comes next on the site, except there is a new warning on the site saying that these order history reports will not be available after March 20 something any longer. I'm not sure if this is what made my answer something other than what your expecting or not. "
# "I will not utilize an internal link to access Amazon. Potential sensitive information is risked doing so. "
# "It's technically my wife's account if that matters."
# "thank you"
# "it says "Order History Reports will be unavailable after March 20, 2023""
# "They said the reports are ending on March 23rd"
# "Thank you for your consideration"
# "I don’t know what value this had"
# "To much personal info."
# "That was quick.  "
# "you cant have people clicking a link and providing a password. this 100% looks like phishing"
# "I used my business Amazon first and it went to a completely different looking page. I had to use my personal to get the answer."
# "There actually isn't anything after "Your account>Your orders" it is blank for me but the main heading of the page is "Your Orders""
# "none"
# "Just a heads up, as I don't know if this is common or not, but there's a message on the Order History Reports page as follows: Order History Reports will be unavailable after March 20, 2023."
# "Amazon says "Order History Reports will be unavailable after March 20, 2023""
# "I intentionally don't shop on Amazon, because there are much better businesses to support financially."
# "None "
# "The amazon question was confusing "Cart" is next on the page the way you worded it."
# "Amazon is garbage"
# "No Comment"
# "Unless this study happens soon, there will be problems accessing reports. Amazon is deprecating the service: Order History Reports will be unavailable after March 20, 2023"
# "it states: Order History Reports will be unavailable after March 20, 2023, for what that is worth in your study"
# "Short survey."
# "I didn't know that page existed, cool!"
# "Just an FYI, that page says "Order History Reports will be unavailable after March 20, 2023""
# "I used this section yesterday "
# "amazon page says my order history reports will be unavailable after March 20, 2023, if that is relevant to the next study"
# "no"
# "Easy study thanks!"
# "Thanks!"
# "Thanks !"
# "I will not give acceaa to another account."
# "none"
# "Thanks"
# "not reliable"
# "Nope"
# "It says your order history reports will be unavailable March 20 2023"
# "none"
# ...
# "no comment"
# "This was a great survey. Thanks for everything."
# "This was a nice study, thank you!"
# "none"
# "none"
# "no comments "
# "Great"
# "none"
# "This is a security risk. "
# "Don’t want to enter my code because of security "
# "That would make me feel a bit uncomfortable"
# "thank you"
# "None."
# "No further comments. Thank you for the opportunity to participate in your study."
# "My reports seem to end in four days."
# "different"
# "No."
# "good"
# "none"
# "I'm not clicking on a link that asks me to sign in to Amazon. That's how you get your account hacked."
# "no"
# "No"
# "none"
# "Order History Reports will be unavailable after March 20, 2023 it says this on the top  of the page"
# "Thank you for allowing me to participate."
# "My Amazon account is a business account so it looks a little different than the example given."
# "none"
# "None. Thank you."
# "smoke weed"
# "I would never give my Amazon credentials out in a survey. "
# "Thank you for the opportunity."
# "Nice"
# "good survey"
# "Thank you for allowing me to participate."
# "No issues with task."
# "So we would have to be logging in to our Amazon Prime accounts for the longer study? I hope we will be able to maintain our privacy and not reveal our email address or any other personal information in the course of that study. Right? "
# "Smooth Study! Thank You! "
# "Everything seemed pretty straightforward to me. My Amazon MTurk ID#: A2I8YALVTOJN49. Have a great day!"
# "A2L53B1MI02U0W"
# "all good"
# "Interesting n Good"
# "I have a business prime account - didn't realize it was structured so differently."
# "I don’t trust this site going to my amazon account"
# "I have no further comments."
# "should be an alert that Amazon members will be asked to log into their account"
# "Thank you for allowing me to participate!"
# "None, thanks."
# "The screen described in you study did not seem to be accurate."
# "easy"
# "No,sir"
# "Nothing to add, thanks for the time"
# "What is your research attempting find or validate?"
# ":)"
# "none"
# "no"
# "Thanks"
# "Kind of scared logging in from that link but I think it worked"
# "none"
# "None at this time. "
# "No additional comments."
# "No comments."
# "Thank You"
# "Thanks for this opportunity.  May I please have a bonus to help with groceries?"
# "none"
# "No comments."
# "Thank you!"
# "message says order history reports will be unavailable after March 20, 2023"
# "No commment, Thanks!"
# "Thanks"
# "no"
# "Not trusting of links that ask you to log in to personal accounts"
# "none"
# "Already took part in this study on prolific."
# "none"
# "thanks for letting me take your survey. Looking at seeing you in the future"
# "none"
# "thank you"
# "Very interested in participating; thank you for this opportunity!"
# "NO"
# "none"
# "no comments"
# "none"
# "none"
# "N/a"
# "no"
# "It was great"
# "Thank you!"
# "Thanks for the survey!"
# "I'm glad to take screenshots of my account but I'm nervous about using a link to log into it. "
# "I hope my account doesn't get hacked by MIT"
# "Amazon is stopping access to order history reports on this page on March 20th, so I hope you plan to do this survey before then."
# "Thanks for the opportunity to participate and good luck with your research."
# "Thanks for an engaging experience. "
# "Sort of interesting screen -- not sure what's being examined here, but good luck with your research."
# "Thanks for having me participate."
# "No"
# "am interested in continuing "
# "Have a fantastic day! Smile! You are one of a kind. "
# "serious privacy concerns"
# "none"
# "none"
# "none"
# "none, thanks."
# "No comments, thank you. "
# "Its good"
# "Link did not work "
# "I think this is a bit too personal "
# "none"
# "Nice survey."
# "I'll take more surveys if you will give me the work."
# "no comments thank you"
# "I am interested in the next phase. "
# "thanks alot"
# "clear and direct"
# "Thank you"
# "thank you"
# "Thank you!"
# "Do you need to actually see my order history for the full survey?"
# "I don't feel comfortable signing into my amazon account in a survey.  I worry about my private information be compromised"
# "enjoyed"
# "na"
# "thank you"
# "I assume you're talking about a seller account, correct?"
# "i havent done anything "
# "I got this message when I went to the order history reports "Order History Reports will be unavailable after March 20, 2023""
# "This was very well-designed."
# "Everything was fine"
# "no"
# "This seems like it will be an interesting survey. Thank you for the opportunity."
# "Thank you for allowing me to participate!"
# "No comments."
# "It says it will be unavailable after March 20th. "
# "None I can think of"
# "n.b.: website says "Order History Reports will be unavailable after March 20, 2023""
# "I did not want to sign into my Amazon account from with Qualtrics."
# "ty"
# "I WAS GETTING OUT OF ADDICTION AND POVERTY. LUCKILY I HAVE A RICH 1%ER FAMILY HELPING ME AND GUIDING ME ALONG THE WAY WITH WHAT I NEED TO DO. I HELPED PROPEL THEM TO SUCCESS BY TEACHING MY COUSIN JOHNNY QUACH AND JAMES CAO ABOUT THE BODYBUILDING.COM MISC AND THEY LEARNED A LOT ABOUT INVESTING THAT HELPED MAKE OUR FAMILY MILLIONS. I COULDNT MAKE USE OF THE INFORMATION BECAUSE I WAS A DRUG ADDICT TRYING TO GO TO SCHOOL, BUT THEY READ ALMOST EVERY SINGLE THREAD I READ. THEY PUT A KEYLOGGER/VIRUS ON MY COMPUTER AND WATCHED MY HABITS FROM AGE 13 TO PRESENT DAY, SO THEY LEARNED ABOUT SILVER WHEN IT WAS ONLY AT 3 TO 5 DOLLARS AN OZ... THEY ALSO READ MORE INTO LTC WHEN IT WAS AT .03 CENTS A COIN. IT MADE OUR FAMILY A TON OF MONEY BECAUSE WE HAVE 22 AUNTS AND UNCLES WHO RELIED ON THEM TO INVEST. THEY LEARNED ABOUT ALL OF THAT AROUND 2003 WHEN I WAS 13 EDUCATING MYSELF ON HOW TO GAIN MUSCLE AND LOSE FAT."
# "It should say you want people to sign into Amazon account in the description. "
# "The page gives the message: "Order History Reports will be unavailable after March 20, 2023""
# "I don't like being asked to log into my accounts from a survey, I feel its a trap."
# "Thank you"
# "no"
# "none"
# "Okay, ready to move to the next phase"
# "Thanks"
# "none"
# "There is a banner on the page that reads "Order History Reports will be unavailable after March 20, 2023" .. act fast I guess"
# "n"
# "none"
# "NIL"
# "Picture guidance may help"
# "Thank you for the opportunity."
# "Underneath it says: Order History Reports will be unavailable after March 20, 2023"
# "thank you"
# "none"
# "Order History Reports will be unavailable after March 20, 2023 You can continue accessing your order history on Your Orders ."
# "So, did I get the answer right? Do you leave the workers hanging and don't say anything?"
# "Just an FYI, Amazon has a report showing for everyone that says that Order History reports will go away permanently for everyone after March 20, 2023. Hoping your survey goes up before then"
# "I participated in an Amazon study from MIT recently where I installed a browser extension and added items to a wishlist. If this is the same study I would be happy to participate again, but I thought you should know."
# "States 'Business Analytics' as that main title with boards of everything that you listed in graphs. Don't think that qualifies."
# "You should not ask people for their info for only 40 cents. Thanks! "
# "THANKS"
# "Thank you so much for the chance to participate. I hope I'm chosen for the longer study! All of your instructions were clear and easy to follow."
# "No"
# "Sorry, I'm just not comfortable accessing my Amazon page through the link on your study. You might want to consider providing people with the steps necessary to get to the information on their own in a completely different page opened by them."
# "Order history reports"
# "thanks"
# "no comments"
# "It says reports will no longer be available after March 20th 2023, hope the next survey comes before then."
# "none"
# "it says they won't be available after march 20th"
# "Asking for too much account information. Security concerns."
# "its funny I just read they were doing away with this functionality so I downloaded my order history from 2006 to now (they could not include 2000-2005 for some reason)"
# "No (I don't have any comments to add here..other than thank you for actually doing a paid rather than "you get disqualified if you don't meet X or Y demographic" screener..it is nice to see there are still some researchers who care about being ethical out there.)"
# "none"
# "None."
# "On Amazon it says that:" Order History Reports will be unavailable after March 20, 2023" Sounds like it might be going away soon. What do I need to do if the study does not appear before the 21st?"
# "That was a random task! Curious what that was about."
# "Hope I can qualify for main study. Been long time amazon shopper, been a prime member for over a decade"
# "none"
# "says also that order history reports won't be available after march 20 2023"
# "I don't think it's cool that you would want to see a report of anyone's purchases"
# "Thank you"
# "No comments."
# "Thank you for this opportunity "
# "My orders page under my account only says this "Your Account › Your Orders" then under that is lists "Your Orders" and under that lists "Orders_Buy Again_ Not Yet Shipped_ Digital Orders_ Local Store Orders_Cancelled Orders" so I had to guess at how to answer the last question because my account doesn't have the same titles."
# "You are welcome!"
# "Thanks! "
# "I have never seen that page on Amazon before!"
# "Everything seemed to work fine for me.  I tried to give the best answers I could to help out.  Thank you for allowing me to participate.  Have a nice day."
# "I do not reveal personal information in surveys"
# "I would be interested in the next study but you won't get my login"
# "I don't use Amazon as much as I used to. Third party vendors are not fully vetted and there is a lot of fraud going on which Amazon is doing nothing about. "
# "I do hope you didn't track me to my log-in, which would be an invasion of my privacy.  Maybe not here, but it would be a violation of terms of service on MTurk to require me to sign in.  I'd certainly appreciate a note clarify what your intentions were to request same.!"
# "Under "Order History Reports" there is a warning banner that says, "Order History Reports will be unavailable after March 20, 2023  You can continue accessing your order history on Your Orders .""
# "none"
# "Thank you"
# "Thanks!"
# "Thank you."
# "I don't like to follow links that ask me to sign into an account for safety reasons."
# "thx"
# "What happened ?"
# "I have the following message  "Order History Reports will be unavailable after March 20, 2023""
# "Woot! Woot! Hope I'm in "
# "I do not give out access to my personal accounts"
# "Amazon says the reports will be unavailable after March 20th.  You want to consider this."
# "none.  Thank you."
# "none"
# "thanks, not sharing private info for pay."
# "No comments."
# "I'm currently lockedout of my Amazon account due to phone numbe and TFA issues - I think I hit the wrong selection on the last screen. I apologie."
# "I didn't have anything in the next spot on my Amazon account, but that answer was not an option."
# "I'm not revealing my person shopping history in order to participate in a study."
# "Thank you"
# "Interesting. Is that all?"
# "thank you"
# "no"
# "Thank you"
# "None."
# "There was actually nothing there where the blank was, but you didn't give that option. It was a page of my order history though, so that is what I chose."
# "Thanks"
# "I enjoyed this survey, and I love my Amazon account.  thank you"
# "none"
# "I hate Amazon"
# "None, thanks, it went well. "
# "This is a massive invasion of privacy and a Terms Of Service violation by MIT."
# "thank you"
# "Just being cautious. Don't want to possibly share account information."
# "I am not al all comfortable letting a third party have access to my Amazon account history, settings, etc."
# "Why would I ever let you see my order history?"
# "I believe I did a study for similar to this in November, as I have had to fill this out before and look at my order history.. If you don't want me to participate in the survey, if able, please let me know."
# "none at this time."
# "Thank you for considering me for your study. It would be my distinct honor to participate."
# "I'm not interested in sharing my order history or Amazon information but thank you"
# "It was a very short survey!"
# "I do not feel comfortable logging into my account which has my personal, identifiable information as well as my card information."
# "Stated reports will no longer be available after March 20"
# "The page also says "Order History Reports will be unavailable after March 20, 2023 You can continue accessing your order history on Your Orders ." Not sure if that will be an issue?"
# "Im a very active Prime shopper 😁"
# "When I go to that web address it says  Order History Reports will be unavailable after March 20, 2023"
# "Looking forawrd to participating "
# "I’m confused as to what this study is about? I hope my information is safe now? "
# "Thank you!"
# "THank you"
# "No"
# "no"
# "your welcome, have a good day"
# "Thank you"
# "The page that came up didn’t show anything like your example had. There was nothing in the space or anything showing orders so I wasn’t able to answer the question. "
# "too personal....thanks anyway"
# "No comments."
# "I initially resisted Amazon because I lived in a major city where anything I needed was within walking distance. during the pandemic I left the city and moved to a suburb. Now Amazon is essential as I don't have the same access. "
# "Nil. "
# "Thank you!"
# "I'm not comfortable giving access to my order history. Perhaps if the pay was more I would consider sharing that data. "
# "Amazon says they'll be discontinuing the feature after 03/20/2023"
# "No"
# "This seems suspicious"
# "n/a "
# "You're welcome"
# "no"
# "no"
# "The questions were clear and I experienced no problems."
# "seems like Amazon is ending order history reports: Order History Reports will be unavailable after March 20, 2023"
# "Thank you!"
# "It says the order history reports won't be available after this month."
# "Order History Reports will be unavailable after March 20, 2023"
# "Not comfortable clicking link to sign into my amazon account"
# "Going to your account -> orders does not lead to a sub category. It simply pulls up the order history, so the final question was a bit confusing."
# "i wont sign in via app or give you access to my account sorry"
# "That's not what it actually says at all. It says accounts and lists, returns and orders, and cart."
# "Thanks so much for the opportunity to participate."
# "Thank you. "
# "Thank you"
# "Sign me up"
# "do not want to give my Amazon information"
# "That was a little bit confusing, because on Amazon's page when you go there, it has a message that talks about those reports. You may want to clarify this for other participants. Thank you"
# "Maybe mention in the description that you will have to sign in."
# "thanks"
# "No"
# "no comments at this time other than I love amazon"
# "When you go to that page it actually reads, "Your Orders" but that wasn't an option?"
# "I don’t like the idea that I have to sign onto my active Amazon account. Too personal with identity theft the way it is nowadays. "
# "The page said "Order History Reports will be unavailable after March 20, 2023."   Also, if this is the study that has been going around that wants you to download and submit your Amazon history, I am not interested in participating in that one."
# "I didn't notice any errors or typos and had no issues at all, thanks!"
# "I didn't have any problems."
# "are you borrowing my purchase detail?  hmmm, feeling insecure "
# "Im not comfortable logging into my amazon account or any other account because of security reasons. "
# "ThanK YoU!!"
# "I think it said order history reports... Now idk for sure..:'("
# "I'm not going to log into my account and provide you data for 1.50."
# "none"
# "Jesus died for our sins."
# "It showed me the message that said "Order History Reports are no longer available." Thanks"
# "The page also said that order history is no longer available and provided a link to the correct page. "
# "D43F8F42AF394BA78396934D1332622A"
# "Amazon says "Order History Reports are no longer available." And I think I've already done this study for you. "
# "That contains too much personal information on it. "
# "none"
# "No"
# "Thank you."
# "says reports are no longer available see order history"
# "Thank you."

# %% [markdown]
# ## Save the cleaned data

# %%
fname = output_data_path + 'cleaned.csv'
prescreen_df.drop([PROLIFIC_PARTICIPANT_ID, 'Q-worker-id', 'Q-comments'], axis=1).to_csv(fname, index=False)
print('saving %s rows of data to %s' % (len(prescreen_df), fname))
# Out:
# saving 21892 rows of data to ../../data/prescreen-survey/cleaned.csv

# %%
pd.read_csv(fname).head()
# Out:
#   PASS_PRESCREEN FAILED_ATTN_CHECK         RecordedDate Q-requirements-1
# 0            NaN              True  2022-11-01 14:49:05              Yes  \
# 1            NaN               NaN  2022-11-01 14:50:03              Yes
# 2           True               NaN  2022-11-01 14:51:21              Yes
# 3           True               NaN  2022-11-01 14:56:22              Yes
# 4           True               NaN  2022-11-01 14:56:37              Yes
#
#   Q-requirements-2 Q-attn-check-1 Q-prolific-mturk Q-mturk-account
# 0              Yes            Yes              NaN             NaN  \
# 1               No            NaN              NaN             NaN
# 2              Yes             No               No             NaN
# 3              Yes             No               No             NaN
# 4              Yes             No               No             NaN
#
#   Q-attn-check-2  Duration (in seconds)  ... version Q-followup-study connect
# 0            NaN                     19  ...      v1              NaN     NaN  \
# 1            NaN                     10  ...      v1              NaN     NaN
# 2             No                     28  ...      v1              NaN     NaN
# 3             No                     40  ...      v1              NaN     NaN
# 4             No                     31  ...      v1              NaN     NaN
#
#                Age              Sex Ethnicity simplified Country of birth
# 0  CONSENT_REVOKED  CONSENT_REVOKED      CONSENT_REVOKED  CONSENT_REVOKED  \
# 1               35             Male                White    United States
# 2               28             Male                Other    United States
# 3               27             Male                White    United States
# 4               35             Male                White    United States
#
#        Nationality   Student status Employment status
# 0  CONSENT_REVOKED  CONSENT_REVOKED   CONSENT_REVOKED
# 1    United States              Yes      DATA_EXPIRED
# 2    United States               No         Full-Time
# 3    United States     DATA_EXPIRED      DATA_EXPIRED
# 4    United States     DATA_EXPIRED      DATA_EXPIRED
#
# [5 rows x 21 columns]
