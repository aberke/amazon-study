# %% [markdown]
# # Preprocessing for the responses data
#
# Processes the raw responses data that was exported from Qualtrics. Creates a "cleaned" version.
#
# Cleaned version can be committed to the repository; raw vesion is not.
#
# ###### Note: This is for the responses data, not the uploaded transactions data
#
#
# #### Handle comments
#
# As per the IRB protocol, comments connected to survey participants are not published. They are removed from the cleaned data.
#
# #### Drop extra rows
#
# When participants consent to share their data, the data file is uploaded to the same survey as a separate response. This generates an extra row of data for just that response, where only the fields for the data file (special hidden Qualtrics question) are filled.
#
# We drop these from the cleaned data.
# Note this does not lose the ability to link the data -- the uploaded files are named as the ResponseId of the participant who uploaded the file.
#
#
# #### Drops unused columns
#
# Columns automatically added by Qualtrics, not used by us
#
# Fields we added in order to hack on the Qualtrics APIs

# %%
import numpy as np
import pandas as pd

raw_data_filepath = '../data/survey-v0-sample-fake.csv'
# raw_data_filepath = '../data/survey-v0-sample-raw.csv'
cleaned_data_filepath = '../data/sample-preprocessed.csv'
fields_filepath = '../data/fields.csv'

# %%
pd.set_option('max_columns', None)

df = pd.read_csv(raw_data_filepath)
print('shape:', df.shape)
print('all fields:', df.columns)
df.head(2)
# df.head(10) # To peak but not commit
# Out:
# shape: (8, 72)
# all fields: Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'Q43_Id', 'Q43_Name', 'Q43_Size',
#        'Q43_Type', 'intro-1', 'intro-2', 'download', 'download-fail-expl',
#        'download-fail-screen_Id', 'download-fail-screen_Name',
#        'download-fail-screen_Size', 'download-fail-screen_Type', 'q-demos-age',
#        'Q-demos-hispanic', 'Q-demos-race', 'Q-demos-education',
#        'Q-demos-income', 'Q-demos-gender', 'Q-sexual-orientation',
#        'Q-demos-state', 'Q-amazon-use-howmany', 'Q-amazon-use-hh-size',
#        'Q-amazon-use-how-oft', 'Q-substance-use_1', 'Q-substance-use_2',
#        'Q-substance-use_3', 'Q-personal_1', 'Q-personal_2', 'Q-life-changes',
#        'Q-fast-completion', 'Q-control', 'Q-altruism', 'Q-bonus-05',
#        'Q-bonus-20', 'Q-bonus-50', 'Q-data-value-05', 'Q-data-value-20',
#        'Q-data-value-50', 'Q-data-value-100', 'Q-data-value-any',
#        'Q-data-value-any_1_TEXT', 'Q-sell-YOUR-data', 'Q-sell-consumer-data',
#        'Q-small-biz-use', 'Q-census-use', 'Q-research-society', 'Q-attn-check',
#        'Q-comments', 'SurveyID', 'ResponseID', 'FQID', 'API_TOKEN', 'showdata',
#        'incentive', 'RandomID'],
#       dtype='object')
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# 1  {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}
#
#                   Finished                                       RecordedDate  \
# 0                 Finished                                      Recorded Date
# 1  {"ImportId":"finished"}  {"ImportId":"recordedDate","timeZone":"America...
#
#                  ResponseId                 RecipientLastName  \
# 0               Response ID               Recipient Last Name
# 1  {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}
#
#                   RecipientFirstName                 RecipientEmail  \
# 0               Recipient First Name                Recipient Email
# 1  {"ImportId":"recipientFirstName"}  {"ImportId":"recipientEmail"}
#
#                       ExternalReference                 LocationLatitude  \
# 0               External Data Reference                Location Latitude
# 1  {"ImportId":"externalDataReference"}  {"ImportId":"locationLatitude"}
#
#                   LocationLongitude                 DistributionChannel  \
# 0                Location Longitude                Distribution Channel
# 1  {"ImportId":"locationLongitude"}  {"ImportId":"distributionChannel"}
#
#                   UserLanguage  \
# 0                User Language
# 1  {"ImportId":"userLanguage"}
#
#                                               Q43_Id  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                       {"ImportId":"QID47_FILE_ID"}
#
#                                             Q43_Name  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                     {"ImportId":"QID47_FILE_NAME"}
#
#                                             Q43_Size  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                     {"ImportId":"QID47_FILE_SIZE"}
#
#                                             Q43_Type  \
# 0  Hidden file upload question [QID47-UploadedFil...
# 1                     {"ImportId":"QID47_FILE_TYPE"}
#
#                                              intro-1  \
# 0  Amazon Purchases Survey    Introduction    Thi...
# 1                               {"ImportId":"QID20"}
#
#                                              intro-2  \
# 0  Survey questions and data collection     We wi...
# 1                               {"ImportId":"QID25"}
#
#                                             download  \
# 0  Start the data download process    Go to the f...
# 1                               {"ImportId":"QID26"}
#
#                                   download-fail-expl  \
# 0  Please explain below why you were not able to ...
# 1                          {"ImportId":"QID45_TEXT"}
#
#                              download-fail-screen_Id  \
# 0  Upload a screenshot displaying the issue here....
# 1                       {"ImportId":"QID46_FILE_ID"}
#
#                            download-fail-screen_Name  \
# 0  Upload a screenshot displaying the issue here....
# 1                     {"ImportId":"QID46_FILE_NAME"}
#
#                            download-fail-screen_Size  \
# 0  Upload a screenshot displaying the issue here....
# 1                     {"ImportId":"QID46_FILE_SIZE"}
#
#                            download-fail-screen_Type              q-demos-age  \
# 0  Upload a screenshot displaying the issue here....  What is your age group?
# 1                     {"ImportId":"QID46_FILE_TYPE"}     {"ImportId":"QID35"}
#
#                                   Q-demos-hispanic  \
# 0  Are you of Spanish, Hispanic, or Latino origin?
# 1                             {"ImportId":"QID76"}
#
#                                         Q-demos-race  \
# 0  Choose one or more races that you consider you...
# 1                               {"ImportId":"QID34"}
#
#                                    Q-demos-education  \
# 0  What is the highest level of education you hav...
# 1                               {"ImportId":"QID80"}
#
#                                       Q-demos-income  \
# 0  What was your total household income before ta...
# 1                               {"ImportId":"QID77"}
#
#                   Q-demos-gender  \
# 0  How do you describe yourself?
# 1           {"ImportId":"QID79"}
#
#                             Q-sexual-orientation  \
# 0  Which best describes your sexual orientation?
# 1                           {"ImportId":"QID89"}
#
#                      Q-demos-state  \
# 0  50 States, D.C. and Puerto Rico
# 1             {"ImportId":"QID88"}
#
#                                 Q-amazon-use-howmany  \
# 0  How many people do you share your Amazon accou...
# 1                               {"ImportId":"QID37"}
#
#                        Q-amazon-use-hh-size  \
# 0  How many people are in your "household"?
# 1                      {"ImportId":"QID38"}
#
#                                 Q-amazon-use-how-oft  \
# 0  How often do you (+ anyone you share your acco...
# 1                               {"ImportId":"QID39"}
#
#                                    Q-substance-use_1  \
# 0  Are any of the following the case for:  You or...
# 1                             {"ImportId":"QID36_2"}
#
#                                    Q-substance-use_2  \
# 0  Are any of the following the case for:  You or...
# 1                             {"ImportId":"QID36_3"}
#
#                                    Q-substance-use_3  \
# 0  Are any of the following the case for:  You or...
# 1                             {"ImportId":"QID36_4"}
#
#                                         Q-personal_1  \
# 0  Are any of the following the case for:  You or...
# 1                             {"ImportId":"QID81_1"}
#
#                                         Q-personal_2  \
# 0  Are any of the following the case for:  You or...
# 1                             {"ImportId":"QID81_5"}
#
#                                       Q-life-changes  \
# 0  In 2021 did you, or someone you share your Ama...
# 1                               {"ImportId":"QID40"}
#
#                                    Q-fast-completion  \
# 0  Click to insert the file from Amazon below.   ...
# 1                               {"ImportId":"QID24"}
#
#                                            Q-control  \
# 0  Click to insert the file from Amazon below.   ...
# 1                               {"ImportId":"QID43"}
#
#                                           Q-altruism  \
# 0  Click to insert the file from Amazon below.   ...
# 1                               {"ImportId":"QID68"}
#
#                                           Q-bonus-05  \
# 0  Click to insert the file from Amazon below.   ...
# 1                               {"ImportId":"QID69"}
#
#                                           Q-bonus-20  \
# 0  Click to insert the file from Amazon below.   ...
# 1                               {"ImportId":"QID70"}
#
#                                           Q-bonus-50  \
# 0  Click to insert the file from Amazon below.   ...
# 1                               {"ImportId":"QID71"}
#
#                                      Q-data-value-05  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID59"}
#
#                                      Q-data-value-20  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID60"}
#
#                                      Q-data-value-50  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID61"}
#
#                                     Q-data-value-100  \
# 0  Would you hypothetically consent to share your...
# 1                               {"ImportId":"QID62"}
#
#                                     Q-data-value-any  \
# 0  How much would you share your data for? - Sele...
# 1                               {"ImportId":"QID64"}
#
#                              Q-data-value-any_1_TEXT  \
# 0  How much would you share your data for? - More...
# 1                        {"ImportId":"QID64_1_TEXT"}
#
#                                     Q-sell-YOUR-data  \
# 0  Do you think Amazon should be able to sell YOU...
# 1                               {"ImportId":"QID84"}
#
#                                 Q-sell-consumer-data  \
# 0  Do you think companies should be able to sell ...
# 1                               {"ImportId":"QID44"}
#
#                                      Q-small-biz-use  \
# 0  Big companies currently collect and sell consu...
# 1                               {"ImportId":"QID73"}
#
#                                         Q-census-use  \
# 0  Do you think the U.S. Census Bureau should use...
# 1                               {"ImportId":"QID74"}
#
#                                   Q-research-society  \
# 0  Do you think researchers should be able to use...
# 1                               {"ImportId":"QID75"}
#
#                                         Q-attn-check  \
# 0  This is an attention check. Help us find peopl...
# 1                               {"ImportId":"QID85"}
#
#                   Q-comments                 SurveyID  \
# 0       Comments? (optional)                 SurveyID
# 1  {"ImportId":"QID48_TEXT"}  {"ImportId":"SurveyID"}
#
#                       ResponseID                 FQID  \
# 0                     ResponseID                 FQID
# 1  {"ImportId":"QSEDResponseID"}  {"ImportId":"FQID"}
#
#                   API_TOKEN                 showdata  \
# 0                 API_TOKEN                 showdata
# 1  {"ImportId":"API_TOKEN"}  {"ImportId":"showdata"}
#
#                   incentive                 RandomID
# 0                 incentive                 RandomID
# 1  {"ImportId":"incentive"}  {"ImportId":"RandomID"}

# %%
cleaned_fields = [
    # Fields created by Qualtrics that we *DO NOT keep*
    #'StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
    #'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
    #'ExternalReference', 'LocationLatitude', 'LocationLongitude',
    #'DistributionChannel', 'UserLanguage', 
    
    # Fields created by Qualtrics that we *DO keep*
    'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
    
    # Fields to handle the uploaded file -- do not keep
    # 'Q43_Id', 'Q43_Name', 'Q43_Size', 'Q43_Type', 
    
    # Fields for setup that have consent and continue vs exit Qs
    'intro-1', 'intro-2', 
    
    # Fields for guiding the participant through the download process
    'download', 
    # Fields for download process failure
    'download-fail-expl', 'download-fail-screen_Id', 'download-fail-screen_Name',
    'download-fail-screen_Size', 'download-fail-screen_Type', 
    
    # Fields for personal Qs. e.g. demographics data, amazon usage, life changes
    'q-demos-age', 'Q-demos-hispanic', 'Q-demos-race', 'Q-demos-education',
    'Q-demos-income', 'Q-demos-gender', 'Q-sexual-orientation', 'Q-demos-state', 
    'Q-amazon-use-howmany', 'Q-amazon-use-hh-size', 'Q-amazon-use-how-oft', 
    'Q-substance-use_1', 'Q-substance-use_2', 'Q-substance-use_3', 
    'Q-personal_1', 'Q-personal_2', 
    'Q-life-changes',
    
    # Fields for Q asking if they will share data -- specific to experiment arm
    # 'Q-fast-completion', unused
    'Q-control', 'Q-altruism', 'Q-bonus-05',
    'Q-bonus-20', 'Q-bonus-50', 
    
    # Fields for Qs about perceived data value
    'Q-data-value-05', 'Q-data-value-20', 'Q-data-value-50', 'Q-data-value-100', 
    'Q-data-value-any', 'Q-data-value-any_1_TEXT', 
    
    # Fields for Qs about how your data should be used
    'Q-sell-YOUR-data', 'Q-sell-consumer-data', 'Q-small-biz-use', 
    'Q-census-use', 'Q-research-society', 'Q-attn-check',
    
    # Comments are not clean
    # 'Q-comments',
    
    # Fields for important embedded data set set
    # Used to indicate experiment arm:
    'showdata',
    'incentive', 
    # We set this to connect responses to mturk workers we pay
    'RandomID',
    # We set these to make the API hacks work -- do not need for analysis
    # 'SurveyID', 'ResponseID', 'FQID', 'API_TOKEN',
]

# %% [markdown]
# First save all fields before dropping some.

# %%
fields_df = df.loc[0].rename('field').to_frame()
fields_df['cleaned'] = fields_df['field'].isin(cleaned_fields)
fields_df.head(10)
# Out:
#                                        field  cleaned
# StartDate                         Start Date    False
# EndDate                             End Date    False
# Status                         Response Type    False
# IPAddress                         IP Address    False
# Progress                            Progress    False
# Duration (in seconds)  Duration (in seconds)     True
# Finished                            Finished     True
# RecordedDate                   Recorded Date    False
# ResponseId                       Response ID    False
# RecipientLastName        Recipient Last Name    False

# %%
fields_df.to_csv(fields_filepath)
print('saved all fields to file %s' % fields_filepath)
# Out:
# saved all fields to file ../data/fields.csv

# %% [markdown]
# Drop the Qualtrics metadata

# %%
df = df.drop([0,1])

# %% [markdown]
# Drop the rows generated for the file uploads

# %%
print('dropping %s rows generated for file uploads' % len(df[~df['Q43_Id'].isna()]))
df = df[df['Q43_Id'].isna()].head()
# Out:
# dropping 2 rows generated for file uploads

# %%
cleaned_df = df[cleaned_fields]
print('cleaned data', cleaned_df.shape)
cleaned_df.head()
# Out:
# cleaned data (4, 49)
#   Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 2                    45        1  2022-09-13 08:39:39  R_2ykJU7y9XoyCZTk
# 3                   288        1  2022-09-13 08:44:33  R_BV7CBQjtGOjHZF7
# 5                   239        1  2022-09-13 08:48:35  R_w4seX0QuU1Lz477
# 7                   335        1  2022-09-13 11:11:52  R_2rBGztPmiRoLHWj
#
#   intro-1 intro-2 download         download-fail-expl download-fail-screen_Id  \
# 2       4       2      NaN                        NaN                     NaN
# 3       4       1        2  test problem flow by alex       F_YVTItdPN6hSEAkp
# 5       4       1        1                        NaN                     NaN
# 7       4       1        1                        NaN                     NaN
#
#                   download-fail-screen_Name download-fail-screen_Size  \
# 2                                       NaN                       NaN
# 3  Screen Shot 2022-09-12 at 4.56.40 PM.png                     53964
# 5                                       NaN                       NaN
# 7                                       NaN                       NaN
#
#   download-fail-screen_Type q-demos-age Q-demos-hispanic Q-demos-race  \
# 2                       NaN         NaN              NaN          NaN
# 3                 image/png         NaN              NaN          NaN
# 5                       NaN           2                2          1,6
# 7                       NaN           2                2            1
#
#   Q-demos-education Q-demos-income Q-demos-gender Q-sexual-orientation  \
# 2               NaN            NaN            NaN                  NaN
# 3               NaN            NaN            NaN                  NaN
# 5                 4              2              2                    2
# 7                 4              2              1                    1
#
#   Q-demos-state Q-amazon-use-howmany Q-amazon-use-hh-size  \
# 2           NaN                  NaN                  NaN
# 3           NaN                  NaN                  NaN
# 5            22                    1                    1
# 7            22                    2                    2
#
#   Q-amazon-use-how-oft Q-substance-use_1 Q-substance-use_2 Q-substance-use_3  \
# 2                  NaN               NaN               NaN               NaN
# 3                  NaN               NaN               NaN               NaN
# 5                    1                 2                 2                 2
# 7                    2                 2                 2                 1
#
#   Q-personal_1 Q-personal_2 Q-life-changes Q-control Q-altruism Q-bonus-05  \
# 2          NaN          NaN            NaN       NaN        NaN        NaN
# 3          NaN          NaN            NaN       NaN        NaN        NaN
# 5            2            2              3       NaN        NaN        NaN
# 7            2            2            NaN       NaN        NaN          1
#
#   Q-bonus-20 Q-bonus-50 Q-data-value-05 Q-data-value-20 Q-data-value-50  \
# 2        NaN        NaN             NaN             NaN             NaN
# 3        NaN        NaN             NaN             NaN             NaN
# 5          1        NaN             NaN             NaN             NaN
# 7        NaN        NaN             NaN             NaN             NaN
#
#   Q-data-value-100 Q-data-value-any Q-data-value-any_1_TEXT Q-sell-YOUR-data  \
# 2              NaN              NaN                     NaN              NaN
# 3              NaN              NaN                     NaN              NaN
# 5              NaN              NaN                     NaN                4
# 7              NaN              NaN                     NaN                2
#
#   Q-sell-consumer-data Q-small-biz-use Q-census-use Q-research-society  \
# 2                  NaN             NaN          NaN                NaN
# 3                  NaN             NaN          NaN                NaN
# 5                    4              13            3                  3
# 7                    2               1            1                  1
#
#   Q-attn-check showdata incentive   RandomID
# 2          NaN    false  altruism        NaN
# 3          NaN     true  altruism        NaN
# 5        1,2,3    false  bonus-20  199989274
# 7        1,2,3    false  bonus-05  689693001

# %% [markdown]
# How long did the survey take people on average?
# (in minutes)

# %%
(cleaned_df['Duration (in seconds)'].astype(int).describe()/60).rename('minutes')
# Out:
# count    0.066667
# mean     3.779167
# std      2.122471
# min      0.750000
# 25%      3.175000
# 50%      4.391667
# 75%      4.995833
# max      5.583333
# Name: minutes, dtype: float64

# %% [markdown]
# Save cleaned data to file.

# %%
print('saving data (N=%s) to %s...' % (len(cleaned_df), cleaned_data_filepath))
cleaned_df.to_csv(cleaned_data_filepath, index=False)
print('...saved')
# Out:
# saving data (N=4) to ../data/sample-preprocessed.csv...
# ...saved

# %%
# reading from file
cleaned_df = pd.read_csv(cleaned_data_filepath)
print('N=%s responses' % len(cleaned_df))
cleaned_df.head(3)
# Out:
# N=4 responses
#    Duration (in seconds)  Finished         RecordedDate         ResponseId  \
# 0                     45         1  2022-09-13 08:39:39  R_2ykJU7y9XoyCZTk
# 1                    288         1  2022-09-13 08:44:33  R_BV7CBQjtGOjHZF7
# 2                    239         1  2022-09-13 08:48:35  R_w4seX0QuU1Lz477
#
#    intro-1  intro-2  download         download-fail-expl  \
# 0        4        2       NaN                        NaN
# 1        4        1       2.0  test problem flow by alex
# 2        4        1       1.0                        NaN
#
#   download-fail-screen_Id                 download-fail-screen_Name  \
# 0                     NaN                                       NaN
# 1       F_YVTItdPN6hSEAkp  Screen Shot 2022-09-12 at 4.56.40 PM.png
# 2                     NaN                                       NaN
#
#    download-fail-screen_Size download-fail-screen_Type  q-demos-age  \
# 0                        NaN                       NaN          NaN
# 1                    53964.0                 image/png          NaN
# 2                        NaN                       NaN          2.0
#
#    Q-demos-hispanic Q-demos-race  Q-demos-education  Q-demos-income  \
# 0               NaN          NaN                NaN             NaN
# 1               NaN          NaN                NaN             NaN
# 2               2.0          1,6                4.0             2.0
#
#    Q-demos-gender  Q-sexual-orientation  Q-demos-state  Q-amazon-use-howmany  \
# 0             NaN                   NaN            NaN                   NaN
# 1             NaN                   NaN            NaN                   NaN
# 2             2.0                   2.0           22.0                   1.0
#
#    Q-amazon-use-hh-size  Q-amazon-use-how-oft  Q-substance-use_1  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                   1.0                   1.0                2.0
#
#    Q-substance-use_2  Q-substance-use_3  Q-personal_1  Q-personal_2  \
# 0                NaN                NaN           NaN           NaN
# 1                NaN                NaN           NaN           NaN
# 2                2.0                2.0           2.0           2.0
#
#    Q-life-changes  Q-control  Q-altruism  Q-bonus-05  Q-bonus-20  Q-bonus-50  \
# 0             NaN        NaN         NaN         NaN         NaN         NaN
# 1             NaN        NaN         NaN         NaN         NaN         NaN
# 2             3.0        NaN         NaN         NaN         1.0         NaN
#
#    Q-data-value-05  Q-data-value-20  Q-data-value-50  Q-data-value-100  \
# 0              NaN              NaN              NaN               NaN
# 1              NaN              NaN              NaN               NaN
# 2              NaN              NaN              NaN               NaN
#
#    Q-data-value-any  Q-data-value-any_1_TEXT  Q-sell-YOUR-data  \
# 0               NaN                      NaN               NaN
# 1               NaN                      NaN               NaN
# 2               NaN                      NaN               4.0
#
#    Q-sell-consumer-data  Q-small-biz-use  Q-census-use  Q-research-society  \
# 0                   NaN              NaN           NaN                 NaN
# 1                   NaN              NaN           NaN                 NaN
# 2                   4.0             13.0           3.0                 3.0
#
#   Q-attn-check  showdata incentive     RandomID
# 0          NaN     False  altruism          NaN
# 1          NaN      True  altruism          NaN
# 2        1,2,3     False  bonus-20  199989274.0

# %% [markdown]
# ## Comments
#
# What did people have to say? Printed here without connection to participant Responses.

# %%
comments = df.set_index('ResponseId')['Q-comments'].rename('comments').dropna()
print('%s comments:' % len(comments))
for c in comments.to_list():
    print('\n"%s"'%c)
# Out:
# 2 comments:
#
# "test by alex. said yes for 0.20 incentive. showdata=false"
#
# "Test - Do the comments work?"
