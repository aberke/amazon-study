# %% [markdown]
# # Probe data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import statsmodels.formula.api as smf

# %%
pd.set_option('max_columns', None)

sample_df = pd.read_csv('../data/sample-preprocessed.csv', dtype='str')
print(sample_df.shape)
sample_df.head(3)
# Out:
# (17, 49)
#   Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 0                    45        1  2022-09-13 08:39:39  R_2ykJU7y9XoyCZTk
# 1                   288        1  2022-09-13 08:44:33  R_BV7CBQjtGOjHZF7
# 2                   239        1  2022-09-13 08:48:35  R_w4seX0QuU1Lz477
#
#   intro-1 intro-2 download         download-fail-expl download-fail-screen_Id  \
# 0       4       2      NaN                        NaN                     NaN
# 1       4       1        2  test problem flow by alex       F_YVTItdPN6hSEAkp
# 2       4       1        1                        NaN                     NaN
#
#                   download-fail-screen_Name download-fail-screen_Size  \
# 0                                       NaN                       NaN
# 1  Screen Shot 2022-09-12 at 4.56.40 PM.png                     53964
# 2                                       NaN                       NaN
#
#   download-fail-screen_Type q-demos-age Q-demos-hispanic Q-demos-race  \
# 0                       NaN         NaN              NaN          NaN
# 1                 image/png         NaN              NaN          NaN
# 2                       NaN           2                2          1,6
#
#   Q-demos-education Q-demos-income Q-demos-gender Q-sexual-orientation  \
# 0               NaN            NaN            NaN                  NaN
# 1               NaN            NaN            NaN                  NaN
# 2                 4              2              2                    2
#
#   Q-demos-state Q-amazon-use-howmany Q-amazon-use-hh-size  \
# 0           NaN                  NaN                  NaN
# 1           NaN                  NaN                  NaN
# 2            22                    1                    1
#
#   Q-amazon-use-how-oft Q-substance-use_1 Q-substance-use_2 Q-substance-use_3  \
# 0                  NaN               NaN               NaN               NaN
# 1                  NaN               NaN               NaN               NaN
# 2                    1                 2                 2                 2
#
#   Q-personal_1 Q-personal_2 Q-life-changes Q-control Q-altruism Q-bonus-05  \
# 0          NaN          NaN            NaN       NaN        NaN        NaN
# 1          NaN          NaN            NaN       NaN        NaN        NaN
# 2            2            2              3       NaN        NaN        NaN
#
#   Q-bonus-20 Q-bonus-50 Q-data-value-05 Q-data-value-20 Q-data-value-50  \
# 0        NaN        NaN             NaN             NaN             NaN
# 1        NaN        NaN             NaN             NaN             NaN
# 2          1        NaN             NaN             NaN             NaN
#
#   Q-data-value-100 Q-data-value-any Q-data-value-any_1_TEXT Q-sell-YOUR-data  \
# 0              NaN              NaN                     NaN              NaN
# 1              NaN              NaN                     NaN              NaN
# 2              NaN              NaN                     NaN                4
#
#   Q-sell-consumer-data Q-small-biz-use Q-census-use Q-research-society  \
# 0                  NaN             NaN          NaN                NaN
# 1                  NaN             NaN          NaN                NaN
# 2                    4              13            3                  3
#
#   Q-attn-check showdata incentive   RandomID
# 0          NaN    false  altruism        NaN
# 1          NaN     true  altruism        NaN
# 2        1,2,3    false  bonus-20  199989274

# %%
N = sample_df['ResponseId'].nunique()
print('N=%s total responses' % N)
# Out:
# N=17 total responses

# %%
codebook = {
    # intro-1, intro-2 ask for consent or early exit
    # intro-1
    'intro-2': {'1': 'Continue', '2': 'Exit'},
}

# %% [markdown]
# ### Meta data flow checks
#
# Check the data by counting useful things.
#
# How many did consent to the survey? (vs exited early)
#
# How many had a download failure? What was the problem? Let's fix it.
#
# How many failed the attention check?

# %%
# Consent

# There are two intro Qs asking about requirements and consent.
# intro-1 and intro-2
# If intro-2 resulted in early exit, intro-2 should be empty
n_did_consent_responses = sample_df[sample_df['intro-2']=='1']['ResponseId'].nunique()
print('%0.3f (%s/%s) did consent' % (n_did_consent_responses/N, n_did_consent_responses, N))
# Out:
# 0.353 (6/17) did consent

# %% [markdown]
# Download failure

# %%
download_cols = [c for c in sample_df.columns if c.startswith('download')]
download_fail_df = sample_df[['ResponseId', 'RandomID'] + download_cols]
download_fail_df = download_fail_df[download_fail_df['download']=='2']
n_download_fail = len(download_fail_df)
print('%0.3f (%s/%s) failed download step' % (n_download_fail/N, n_download_fail, N))
download_fail_df
# Out:
# 0.118 (2/17) failed download step
#            ResponseId   RandomID download              download-fail-expl  \
# 1   R_BV7CBQjtGOjHZF7        NaN        2       test problem flow by alex
# 15  R_2bOclY6yJ6uno5H  504695955        2  test if randomID will be shown
#
#    download-fail-screen_Id                 download-fail-screen_Name  \
# 1        F_YVTItdPN6hSEAkp  Screen Shot 2022-09-12 at 4.56.40 PM.png
# 15       F_2YXoy4cy2dLgd4T  Screen Shot 2022-09-14 at 2.17.45 PM.png
#
#    download-fail-screen_Size download-fail-screen_Type
# 1                      53964                 image/png
# 15                      3981                 image/png

# %% [markdown]
# Attention check
#
# 'Q-attn-check':
# > This is an attention check. Help us find people who are not paying attention. Select all answers to this question.

# %%
def did_pass_attn_check(resp):
    return True if len(str(resp).split(',')) == 3 else False

sample_df['passed_attn_check'] = sample_df['Q-attn-check'].apply(did_pass_attn_check)
print('%s passed the attention check' % sample_df['passed_attn_check'].sum())
sample_df.head()
# Out:
# 3 passed the attention check
#   Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 0                    45        1  2022-09-13 08:39:39  R_2ykJU7y9XoyCZTk
# 1                   288        1  2022-09-13 08:44:33  R_BV7CBQjtGOjHZF7
# 2                   239        1  2022-09-13 08:48:35  R_w4seX0QuU1Lz477
# 3                   335        1  2022-09-13 11:11:52  R_2rBGztPmiRoLHWj
# 4                  1321        1  2022-09-13 12:49:38  R_1OkQY5Lrzb43QtM
#
#   intro-1 intro-2 download         download-fail-expl download-fail-screen_Id  \
# 0       4       2      NaN                        NaN                     NaN
# 1       4       1        2  test problem flow by alex       F_YVTItdPN6hSEAkp
# 2       4       1        1                        NaN                     NaN
# 3       4       1        1                        NaN                     NaN
# 4       5     NaN      NaN                        NaN                     NaN
#
#                   download-fail-screen_Name download-fail-screen_Size  \
# 0                                       NaN                       NaN
# 1  Screen Shot 2022-09-12 at 4.56.40 PM.png                     53964
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
#
#   download-fail-screen_Type q-demos-age Q-demos-hispanic Q-demos-race  \
# 0                       NaN         NaN              NaN          NaN
# 1                 image/png         NaN              NaN          NaN
# 2                       NaN           2                2          1,6
# 3                       NaN           2                2            1
# 4                       NaN         NaN              NaN          NaN
#
#   Q-demos-education Q-demos-income Q-demos-gender Q-sexual-orientation  \
# 0               NaN            NaN            NaN                  NaN
# 1               NaN            NaN            NaN                  NaN
# 2                 4              2              2                    2
# 3                 4              2              1                    1
# 4               NaN            NaN            NaN                  NaN
#
#   Q-demos-state Q-amazon-use-howmany Q-amazon-use-hh-size  \
# 0           NaN                  NaN                  NaN
# 1           NaN                  NaN                  NaN
# 2            22                    1                    1
# 3            22                    2                    2
# 4           NaN                  NaN                  NaN
#
#   Q-amazon-use-how-oft Q-substance-use_1 Q-substance-use_2 Q-substance-use_3  \
# 0                  NaN               NaN               NaN               NaN
# 1                  NaN               NaN               NaN               NaN
# 2                    1                 2                 2                 2
# 3                    2                 2                 2                 1
# 4                  NaN               NaN               NaN               NaN
#
#   Q-personal_1 Q-personal_2 Q-life-changes Q-control Q-altruism Q-bonus-05  \
# 0          NaN          NaN            NaN       NaN        NaN        NaN
# 1          NaN          NaN            NaN       NaN        NaN        NaN
# 2            2            2              3       NaN        NaN        NaN
# 3            2            2            NaN       NaN        NaN          1
# 4          NaN          NaN            NaN       NaN        NaN        NaN
#
#   Q-bonus-20 Q-bonus-50 Q-data-value-05 Q-data-value-20 Q-data-value-50  \
# 0        NaN        NaN             NaN             NaN             NaN
# 1        NaN        NaN             NaN             NaN             NaN
# 2          1        NaN             NaN             NaN             NaN
# 3        NaN        NaN             NaN             NaN             NaN
# 4        NaN        NaN             NaN             NaN             NaN
#
#   Q-data-value-100 Q-data-value-any Q-data-value-any_1_TEXT Q-sell-YOUR-data  \
# 0              NaN              NaN                     NaN              NaN
# 1              NaN              NaN                     NaN              NaN
# 2              NaN              NaN                     NaN                4
# 3              NaN              NaN                     NaN                2
# 4              NaN              NaN                     NaN              NaN
#
#   Q-sell-consumer-data Q-small-biz-use Q-census-use Q-research-society  \
# 0                  NaN             NaN          NaN                NaN
# 1                  NaN             NaN          NaN                NaN
# 2                    4              13            3                  3
# 3                    2               1            1                  1
# 4                  NaN             NaN          NaN                NaN
#
#   Q-attn-check showdata incentive   RandomID  passed_attn_check
# 0          NaN    false  altruism        NaN              False
# 1          NaN     true  altruism        NaN              False
# 2        1,2,3    false  bonus-20  199989274               True
# 3        1,2,3    false  bonus-05  689693001               True
# 4          NaN    false   control        NaN              False

# %% [markdown]
# ## Data sharing
#
# How many did, vs did not, consent to share their data?
#
# Add boolean field: `share` coded as 1=share; 0=no share
#
# Make a table:
#
# ```
# incentive, yes, no, n
# ```
#
# And make RandomIDs retrievable for those who shared data and were in a bonus incentive experimental arm.

# %%
incentives_qs = ['Q-control', 'Q-altruism', 'Q-bonus-05', 'Q-bonus-20', 'Q-bonus-50']

def get_share(row):
    """Returns bolean indicated whether participant consented to share."""
    for incentive_q in incentives_qs:
        if row[incentive_q] in ['0', '1']:
            return int(row[incentive_q])
    return np.nan

sample_df['share'] = sample_df.apply(get_share, axis=1)
sample_df.head()
# Out:
#   Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 0                    45        1  2022-09-13 08:39:39  R_2ykJU7y9XoyCZTk
# 1                   288        1  2022-09-13 08:44:33  R_BV7CBQjtGOjHZF7
# 2                   239        1  2022-09-13 08:48:35  R_w4seX0QuU1Lz477
# 3                   335        1  2022-09-13 11:11:52  R_2rBGztPmiRoLHWj
# 4                  1321        1  2022-09-13 12:49:38  R_1OkQY5Lrzb43QtM
#
#   intro-1 intro-2 download         download-fail-expl download-fail-screen_Id  \
# 0       4       2      NaN                        NaN                     NaN
# 1       4       1        2  test problem flow by alex       F_YVTItdPN6hSEAkp
# 2       4       1        1                        NaN                     NaN
# 3       4       1        1                        NaN                     NaN
# 4       5     NaN      NaN                        NaN                     NaN
#
#                   download-fail-screen_Name download-fail-screen_Size  \
# 0                                       NaN                       NaN
# 1  Screen Shot 2022-09-12 at 4.56.40 PM.png                     53964
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
#
#   download-fail-screen_Type q-demos-age Q-demos-hispanic Q-demos-race  \
# 0                       NaN         NaN              NaN          NaN
# 1                 image/png         NaN              NaN          NaN
# 2                       NaN           2                2          1,6
# 3                       NaN           2                2            1
# 4                       NaN         NaN              NaN          NaN
#
#   Q-demos-education Q-demos-income Q-demos-gender Q-sexual-orientation  \
# 0               NaN            NaN            NaN                  NaN
# 1               NaN            NaN            NaN                  NaN
# 2                 4              2              2                    2
# 3                 4              2              1                    1
# 4               NaN            NaN            NaN                  NaN
#
#   Q-demos-state Q-amazon-use-howmany Q-amazon-use-hh-size  \
# 0           NaN                  NaN                  NaN
# 1           NaN                  NaN                  NaN
# 2            22                    1                    1
# 3            22                    2                    2
# 4           NaN                  NaN                  NaN
#
#   Q-amazon-use-how-oft Q-substance-use_1 Q-substance-use_2 Q-substance-use_3  \
# 0                  NaN               NaN               NaN               NaN
# 1                  NaN               NaN               NaN               NaN
# 2                    1                 2                 2                 2
# 3                    2                 2                 2                 1
# 4                  NaN               NaN               NaN               NaN
#
#   Q-personal_1 Q-personal_2 Q-life-changes Q-control Q-altruism Q-bonus-05  \
# 0          NaN          NaN            NaN       NaN        NaN        NaN
# 1          NaN          NaN            NaN       NaN        NaN        NaN
# 2            2            2              3       NaN        NaN        NaN
# 3            2            2            NaN       NaN        NaN          1
# 4          NaN          NaN            NaN       NaN        NaN        NaN
#
#   Q-bonus-20 Q-bonus-50 Q-data-value-05 Q-data-value-20 Q-data-value-50  \
# 0        NaN        NaN             NaN             NaN             NaN
# 1        NaN        NaN             NaN             NaN             NaN
# 2          1        NaN             NaN             NaN             NaN
# 3        NaN        NaN             NaN             NaN             NaN
# 4        NaN        NaN             NaN             NaN             NaN
#
#   Q-data-value-100 Q-data-value-any Q-data-value-any_1_TEXT Q-sell-YOUR-data  \
# 0              NaN              NaN                     NaN              NaN
# 1              NaN              NaN                     NaN              NaN
# 2              NaN              NaN                     NaN                4
# 3              NaN              NaN                     NaN                2
# 4              NaN              NaN                     NaN              NaN
#
#   Q-sell-consumer-data Q-small-biz-use Q-census-use Q-research-society  \
# 0                  NaN             NaN          NaN                NaN
# 1                  NaN             NaN          NaN                NaN
# 2                    4              13            3                  3
# 3                    2               1            1                  1
# 4                  NaN             NaN          NaN                NaN
#
#   Q-attn-check showdata incentive   RandomID  passed_attn_check  share
# 0          NaN    false  altruism        NaN              False    NaN
# 1          NaN     true  altruism        NaN              False    NaN
# 2        1,2,3    false  bonus-20  199989274               True    1.0
# 3        1,2,3    false  bonus-05  689693001               True    1.0
# 4          NaN    false   control        NaN              False    NaN

# %%
shares_count_df = sample_df.groupby(
    ['incentive']
)['ResponseId'].count().rename('allocated').to_frame()

shares_count_df['yes'] = shares_count_df.index.map(
    sample_df[sample_df['share']==1].groupby('incentive')['ResponseId'].count()
).fillna(0)
shares_count_df['no'] = shares_count_df.index.map(
    sample_df[sample_df['share']==0].groupby('incentive')['ResponseId'].count()
).fillna(0)
shares_count_df['n'] = shares_count_df.apply(lambda row: sum(row[['yes','no']]), axis=1)
shares_count_df.loc['total'] = [shares_count_df[c].sum() for c in shares_count_df.columns]
shares_count_df.astype(int)
# Out:
#            allocated  yes  no  n
# incentive
# altruism           5    0   1  1
# bonus-05           3    1   0  1
# bonus-20           3    1   0  1
# bonus-50           2    0   0  0
# control            4    0   1  1
# total             34    2   2  4

# %% [markdown]
# RandomID list for bonus payments

# %%
for bonus in ['Q-bonus-05', 'Q-bonus-20', 'Q-bonus-50']:
    print('bonus incentive list for %s:\n' % bonus)
    sample_df[sample_df[bonus]==1]['RandomID'].to_list()
# Out:
# bonus incentive list for Q-bonus-05:
#
# bonus incentive list for Q-bonus-20:
#
# bonus incentive list for Q-bonus-50:
